# %%
from pyspark.sql.functions import lit
# Out:
# StatementMeta(, 2db552ac-8876-4ac5-bf0e-3da40b84c41f, 13, Finished, Available, Finished)

# %%
#!/usr/bin/env python
# coding: utf-8

# ==============================================================================
# NB_UNION_CARATULAS - VERSIÓN CORREGIDA
# ==============================================================================

from pyspark.sql.functions import lit, col

# ==============================================================================
# PASO 1: CARGAR TODAS LAS TABLAS
# ==============================================================================
print("=== PASO 1: CARGANDO TODAS LAS TABLAS ===\n")

# Tabla 1: CLEAN
df_clean = spark.sql("SELECT * FROM LH_INTELLIGENT_VISIBILITY_CARATULAS.tbl_caratula_cdv_clean")
print(f"1. df_clean: {df_clean.count():,} registros")

# Tabla 2: FACTURADO
df_facturado = spark.sql("SELECT * FROM LH_INTELLIGENT_VISIBILITY_CARATULAS.tbl_caratula_cdv_facturado")
print(f"2. df_facturado: {df_facturado.count():,} registros")

# Tabla 3: FORECAST
df_frcst = spark.sql("SELECT * FROM LH_INTELLIGENT_VISIBILITY_CARATULAS.tbl_caratula_cdv_frcst")
print(f"3. df_frcst: {df_frcst.count():,} registros")

# Tabla 4: PLANIFICADOR cubo
df_planif_snp = spark.sql("SELECT * FROM LH_CARATULAS_PLNF.tbl_caratula_cdv_planificador")
print(f"4. df_planif_snp: {df_planif_snp.count():,} registros")

# Tabla 5: PLANIFICADOR facturado
df_planif_clean = spark.sql("SELECT * FROM LH_CARATULAS_PLNF.tbl_caratula_cdv_planificador_facturado")
print(f"5. df_planif_clean: {df_planif_clean.count():,} registros")

# Tabla 6: PLANIFICADOR FORECAST
df_planif_frcst = spark.sql("SELECT * FROM LH_CARATULAS_PLNF.tbl_caratula_cdv_planificador_frcst")
print(f"6. df_planif_frcst: {df_planif_frcst.count():,} registros")

print("\n✅ 6 tablas cargadas correctamente")

# ==============================================================================
# PASO 2: VERIFICAR Y AGREGAR COLUMNA PLANIFICADOR
# ==============================================================================
print("\n=== PASO 2: VERIFICANDO COLUMNA 'Planificador' ===\n")

# Verificar cada tabla
print(f"df_clean tiene 'Planificador': {'Planificador' in df_clean.columns}")
print(f"df_facturado tiene 'Planificador': {'Planificador' in df_facturado.columns}")
print(f"df_frcst tiene 'Planificador': {'Planificador' in df_frcst.columns}")
print(f"df_planif_snp tiene 'Planificador': {'Planificador' in df_planif_snp.columns}")
print(f"df_planif_clean tiene 'Planificador': {'Planificador' in df_planif_clean.columns}")
print(f"df_planif_frcst tiene 'Planificador': {'Planificador' in df_planif_frcst.columns}")

print("\n=== AGREGANDO COLUMNA 'Planificador' DONDE NO EXISTA ===\n")

# df_clean
if 'Planificador' not in df_clean.columns:
    df_clean = df_clean.withColumn("Planificador", lit("Todos"))
    print("✓ df_clean: Columna 'Planificador' agregada = 'Todos'")
else:
    print("✓ df_clean: Ya tiene 'Planificador'")

# df_facturado
if 'Planificador' not in df_facturado.columns:
    df_facturado = df_facturado.withColumn("Planificador", lit("Todos"))
    print("✓ df_facturado: Columna 'Planificador' agregada = 'Todos'")
else:
    print("✓ df_facturado: Ya tiene 'Planificador'")

# df_frcst
if 'Planificador' not in df_frcst.columns:
    df_frcst = df_frcst.withColumn("Planificador", lit("Todos"))
    print("✓ df_frcst: Columna 'Planificador' agregada = 'Todos'")
else:
    print("✓ df_frcst: Ya tiene 'Planificador'")

# df_planif_snp
if 'Planificador' not in df_planif_snp.columns:
    df_planif_snp = df_planif_snp.withColumn("Planificador", lit("Todos"))
    print("✓ df_planif_snp: Columna 'Planificador' agregada = 'Todos'")
else:
    print("✓ df_planif_snp: Ya tiene 'Planificador'")

# df_planif_clean
if 'Planificador' not in df_planif_clean.columns:
    df_planif_clean = df_planif_clean.withColumn("Planificador", lit("Todos"))
    print("✓ df_planif_clean: Columna 'Planificador' agregada = 'Todos'")
else:
    print("✓ df_planif_clean: Ya tiene 'Planificador'")

# df_planif_frcst
if 'Planificador' not in df_planif_frcst.columns:
    df_planif_frcst = df_planif_frcst.withColumn("Planificador", lit("Todos"))
    print("✓ df_planif_frcst: Columna 'Planificador' agregada = 'Todos'")
else:
    print("✓ df_planif_frcst: Ya tiene 'Planificador'")

print("\n✅ Todas las tablas tienen columna 'Planificador'")

# ==============================================================================
# PASO 3: CREAR TABLA UNIFICADA CON TODAS LAS TABLAS
# ==============================================================================
print("\n=== PASO 3: CREANDO TABLA UNIFICADA ===\n")

# Crear tabla unificada con la primera tabla (OVERWRITE)
print("Creando tabla base con df_clean...")
df_clean.write.mode("overwrite").saveAsTable("LH_INTELLIGENT_VISIBILITY_CARATULAS.tbl_caratula_cdv_unificada")
print(f"✓ Tabla creada: {df_clean.count():,} registros")

# Append df_facturado
print("\nAppend df_facturado...")
df_facturado.write.mode("append").saveAsTable("LH_INTELLIGENT_VISIBILITY_CARATULAS.tbl_caratula_cdv_unificada")
print("✓ Agregado")

# Append df_frcst
print("\nAppend df_frcst...")
df_frcst.write.mode("append").saveAsTable("LH_INTELLIGENT_VISIBILITY_CARATULAS.tbl_caratula_cdv_unificada")
print("✓ Agregado")

# Append df_planif_snp
print("\nAppend df_planif_snp...")
df_planif_snp.write.mode("append").saveAsTable("LH_INTELLIGENT_VISIBILITY_CARATULAS.tbl_caratula_cdv_unificada")
print("✓ Agregado")

# Append df_planif_clean
print("\nAppend df_planif_clean...")
df_planif_clean.write.mode("append").saveAsTable("LH_INTELLIGENT_VISIBILITY_CARATULAS.tbl_caratula_cdv_unificada")
print("✓ Agregado")

# Append df_planif_frcst
print("\nAppend df_planif_frcst...")
df_planif_frcst.write.mode("append").saveAsTable("LH_INTELLIGENT_VISIBILITY_CARATULAS.tbl_caratula_cdv_unificada")
print("✓ Agregado")

# ==============================================================================
# PASO 4: VERIFICACIÓN DE TABLA UNIFICADA
# ==============================================================================
print("\n=== PASO 4: VERIFICACIÓN DE TABLA UNIFICADA ===\n")

# Contar total de registros
total = spark.sql("SELECT COUNT(*) as total FROM LH_INTELLIGENT_VISIBILITY_CARATULAS.tbl_caratula_cdv_unificada").collect()[0][0]
print(f"✅ Total registros en tabla unificada: {total:,}")

# Distribución por Planificador
print("\n📊 Distribución por Planificador:")
spark.sql("""
    SELECT Planificador, COUNT(*) as registros
    FROM LH_INTELLIGENT_VISIBILITY_CARATULAS.tbl_caratula_cdv_unificada
    GROUP BY Planificador
    ORDER BY registros DESC
""").show(truncate=False)

# Distribución por Calculo
print("\n📊 Distribución por Calculo:")
spark.sql("""
    SELECT Calculo, COUNT(*) as registros
    FROM LH_INTELLIGENT_VISIBILITY_CARATULAS.tbl_caratula_cdv_unificada
    GROUP BY Calculo
    ORDER BY registros DESC
""").show(truncate=False)

# Distribución por Año
print("\n📊 Distribución por Año:")
spark.sql("""
    SELECT Ano, COUNT(*) as registros
    FROM LH_INTELLIGENT_VISIBILITY_CARATULAS.tbl_caratula_cdv_unificada
    GROUP BY Ano
    ORDER BY Ano
""").show(truncate=False)

# Distribución por Año y Mes
print("\n📊 Distribución por Año y Mes:")
spark.sql("""
    SELECT Ano, Mes, COUNT(*) as registros
    FROM LH_INTELLIGENT_VISIBILITY_CARATULAS.tbl_caratula_cdv_unificada
    GROUP BY Ano, Mes
    ORDER BY Ano, Mes
""").show(truncate=False)

print("\n✅ TABLA UNIFICADA COMPLETADA")

# ==============================================================================
# PASO 5: CREAR TABLA ESPEJO (TBL_001_CARATULAS_CONT)
# ==============================================================================
print("\n=== PASO 5: CREANDO TABLA ESPEJO ===\n")

# Cargar la tabla unificada completa
df_espejo = spark.sql("""
    SELECT * 
    FROM LH_INTELLIGENT_VISIBILITY_CARATULAS.tbl_caratula_cdv_unificada
""")

print(f"Registros a copiar al espejo: {df_espejo.count():,}")

# Guardar como tabla espejo
df_espejo.write \
    .mode("overwrite") \
    .option("overwriteSchema", "true") \
    .saveAsTable("LH_INTELLIGENT_VISIBILITY_CARATULAS.TBL_001_CARATULAS_CONT")

print("\n✅ Tabla espejo creada: LH_INTELLIGENT_VISIBILITY_CARATULAS.TBL_001_CARATULAS_CONT")

# Verificación final del espejo
total_espejo = spark.sql("SELECT COUNT(*) as total FROM LH_INTELLIGENT_VISIBILITY_CARATULAS.TBL_001_CARATULAS_CONT").collect()[0][0]
print(f"✅ Total registros en espejo: {total_espejo:,}")

# Verificar que ambas tablas tengan el mismo número de registros
if total == total_espejo:
    print("\n✅ VALIDACIÓN EXITOSA: La tabla unificada y el espejo tienen el mismo número de registros")
else:
    print(f"\n⚠️ ADVERTENCIA: Diferencia de registros - Unificada: {total:,} vs Espejo: {total_espejo:,}")

# Muestra de datos del espejo
print("\n📊 Muestra de datos del espejo:")
spark.sql("""
    SELECT Ano, Mes, PAIS, Familia, Planificador, Calculo, COUNT(*) as registros
    FROM LH_INTELLIGENT_VISIBILITY_CARATULAS.TBL_001_CARATULAS_CONT
    GROUP BY Ano, Mes, PAIS, Familia, Planificador, Calculo
    ORDER BY Ano, Mes
    LIMIT 20
""").show(truncate=False)

print("\n" + "="*80)
print("✅ PROCESO COMPLETADO EXITOSAMENTE")
print("="*80)
print("\nTablas creadas:")
print("1. LH_INTELLIGENT_VISIBILITY_CARATULAS.tbl_caratula_cdv_unificada")
print("2. LH_INTELLIGENT_VISIBILITY_CARATULAS.TBL_001_CARATULAS_CONT (ESPEJO)")
print("\nAmbas tablas contienen TODAS las 6 tablas originales unificadas")
print("="*80)
# Out:
# StatementMeta(, 2db552ac-8876-4ac5-bf0e-3da40b84c41f, 24, Finished, Available, Finished)
# === PASO 1: CARGANDO TODAS LAS TABLAS ===
# 1. df_clean: 82,730 registros
# 2. df_facturado: 82,730 registros
# 3. df_frcst: 82,730 registros
# 4. df_planif_snp: 380,620 registros
# 5. df_planif_clean: 380,620 registros
# 6. df_planif_frcst: 380,620 registros
#
# ✅ 6 tablas cargadas correctamente
#
# === PASO 2: VERIFICANDO COLUMNA 'Planificador' ===
#
# df_clean tiene 'Planificador': True
# df_facturado tiene 'Planificador': True
# df_frcst tiene 'Planificador': True
# df_planif_snp tiene 'Planificador': True
# df_planif_clean tiene 'Planificador': True
# df_planif_frcst tiene 'Planificador': True
#
# === AGREGANDO COLUMNA 'Planificador' DONDE NO EXISTA ===
#
# ✓ df_clean: Ya tiene 'Planificador'
# ✓ df_facturado: Ya tiene 'Planificador'
# ✓ df_frcst: Ya tiene 'Planificador'
# ✓ df_planif_snp: Ya tiene 'Planificador'
# ✓ df_planif_clean: Ya tiene 'Planificador'
# ...

# %%
#!/usr/bin/env python
# coding: utf-8

# ==============================================================================
# SCRIPT DE DIAGNÓSTICO: VERIFICAR AÑOS EN CADA TABLA ORIGEN
# ==============================================================================

from pyspark.sql.functions import col

print("="*80)
print("DIAGNÓSTICO: VERIFICANDO AÑOS EN CADA TABLA")
print("="*80)

# ==============================================================================
# TABLA 1: tbl_caratula_cdv_clean
# ==============================================================================
print("\n" + "="*80)
print("TABLA 1: LH_INTELLIGENT_VISIBILITY_CARATULAS.tbl_caratula_cdv_clean")
print("="*80)

df_clean = spark.sql("SELECT * FROM LH_INTELLIGENT_VISIBILITY_CARATULAS.tbl_caratula_cdv_clean")
total_clean = df_clean.count()
print(f"Total registros: {total_clean:,}")

print("\n📅 Distribución por Año:")
spark.sql("""
    SELECT Ano, COUNT(*) as registros
    FROM LH_INTELLIGENT_VISIBILITY_CARATULAS.tbl_caratula_cdv_clean
    GROUP BY Ano
    ORDER BY Ano
""").show(truncate=False)

print("\n📅 Distribución por Año y Mes:")
spark.sql("""
    SELECT Ano, Mes, COUNT(*) as registros
    FROM LH_INTELLIGENT_VISIBILITY_CARATULAS.tbl_caratula_cdv_clean
    GROUP BY Ano, Mes
    ORDER BY Ano, Mes
""").show(truncate=False)

# ==============================================================================
# TABLA 2: tbl_caratula_cdv_facturado
# ==============================================================================
print("\n" + "="*80)
print("TABLA 2: LH_INTELLIGENT_VISIBILITY_CARATULAS.tbl_caratula_cdv_facturado")
print("="*80)

df_facturado = spark.sql("SELECT * FROM LH_INTELLIGENT_VISIBILITY_CARATULAS.tbl_caratula_cdv_facturado")
total_facturado = df_facturado.count()
print(f"Total registros: {total_facturado:,}")

print("\n📅 Distribución por Año:")
spark.sql("""
    SELECT Ano, COUNT(*) as registros
    FROM LH_INTELLIGENT_VISIBILITY_CARATULAS.tbl_caratula_cdv_facturado
    GROUP BY Ano
    ORDER BY Ano
""").show(truncate=False)

print("\n📅 Distribución por Año y Mes:")
spark.sql("""
    SELECT Ano, Mes, COUNT(*) as registros
    FROM LH_INTELLIGENT_VISIBILITY_CARATULAS.tbl_caratula_cdv_facturado
    GROUP BY Ano, Mes
    ORDER BY Ano, Mes
""").show(truncate=False)

# ==============================================================================
# TABLA 3: tbl_caratula_cdv_frcst
# ==============================================================================
print("\n" + "="*80)
print("TABLA 3: LH_INTELLIGENT_VISIBILITY_CARATULAS.tbl_caratula_cdv_frcst")
print("="*80)

df_frcst = spark.sql("SELECT * FROM LH_INTELLIGENT_VISIBILITY_CARATULAS.tbl_caratula_cdv_frcst")
total_frcst = df_frcst.count()
print(f"Total registros: {total_frcst:,}")

print("\n📅 Distribución por Año:")
spark.sql("""
    SELECT Ano, COUNT(*) as registros
    FROM LH_INTELLIGENT_VISIBILITY_CARATULAS.tbl_caratula_cdv_frcst
    GROUP BY Ano
    ORDER BY Ano
""").show(truncate=False)

print("\n📅 Distribución por Año y Mes:")
spark.sql("""
    SELECT Ano, Mes, COUNT(*) as registros
    FROM LH_INTELLIGENT_VISIBILITY_CARATULAS.tbl_caratula_cdv_frcst
    GROUP BY Ano, Mes
    ORDER BY Ano, Mes
""").show(truncate=False)

# ==============================================================================
# TABLA 4: tbl_caratula_cdv_planificador
# ==============================================================================
print("\n" + "="*80)
print("TABLA 4: LH_CARATULAS_PLNF.tbl_caratula_cdv_planificador")
print("="*80)

df_planif_snp = spark.sql("SELECT * FROM LH_CARATULAS_PLNF.tbl_caratula_cdv_planificador")
total_planif_snp = df_planif_snp.count()
print(f"Total registros: {total_planif_snp:,}")

print("\n📅 Distribución por Año:")
spark.sql("""
    SELECT Ano, COUNT(*) as registros
    FROM LH_CARATULAS_PLNF.tbl_caratula_cdv_planificador
    GROUP BY Ano
    ORDER BY Ano
""").show(truncate=False)

print("\n📅 Distribución por Año y Mes:")
spark.sql("""
    SELECT Ano, Mes, COUNT(*) as registros
    FROM LH_CARATULAS_PLNF.tbl_caratula_cdv_planificador
    GROUP BY Ano, Mes
    ORDER BY Ano, Mes
""").show(truncate=False)

# ==============================================================================
# TABLA 5: tbl_caratula_cdv_planificador_clean
# ==============================================================================
print("\n" + "="*80)
print("TABLA 5: LH_CARATULAS_PLNF.tbl_caratula_cdv_planificador_clean")
print("="*80)

df_planif_clean = spark.sql("SELECT * FROM LH_CARATULAS_PLNF.tbl_caratula_cdv_planificador_facturado")
total_planif_clean = df_planif_clean.count()
print(f"Total registros: {total_planif_clean:,}")

print("\n📅 Distribución por Año:")
spark.sql("""
    SELECT Ano, COUNT(*) as registros
    FROM LH_CARATULAS_PLNF.tbl_caratula_cdv_planificador_facturado
    GROUP BY Ano
    ORDER BY Ano
""").show(truncate=False)

print("\n📅 Distribución por Año y Mes:")
spark.sql("""
    SELECT Ano, Mes, COUNT(*) as registros
    FROM LH_CARATULAS_PLNF.tbl_caratula_cdv_planificador_facturado
    GROUP BY Ano, Mes
    ORDER BY Ano, Mes
""").show(truncate=False)

# ==============================================================================
# TABLA 6: tbl_caratula_cdv_planificador_frcst
# ==============================================================================
print("\n" + "="*80)
print("TABLA 6: LH_CARATULAS_PLNF.tbl_caratula_cdv_planificador_frcst")
print("="*80)

df_planif_frcst = spark.sql("SELECT * FROM LH_CARATULAS_PLNF.tbl_caratula_cdv_planificador_frcst")
total_planif_frcst = df_planif_frcst.count()
print(f"Total registros: {total_planif_frcst:,}")

print("\n📅 Distribución por Año:")
spark.sql("""
    SELECT Ano, COUNT(*) as registros
    FROM LH_CARATULAS_PLNF.tbl_caratula_cdv_planificador_frcst
    GROUP BY Ano
    ORDER BY Ano
""").show(truncate=False)

print("\n📅 Distribución por Año y Mes:")
spark.sql("""
    SELECT Ano, Mes, COUNT(*) as registros
    FROM LH_CARATULAS_PLNF.tbl_caratula_cdv_planificador_frcst
    GROUP BY Ano, Mes
    ORDER BY Ano, Mes
""").show(truncate=False)

# ==============================================================================
# RESUMEN FINAL
# ==============================================================================
print("\n" + "="*80)
print("RESUMEN FINAL - TOTAL DE REGISTROS POR TABLA")
print("="*80)
print(f"1. tbl_caratula_cdv_clean:               {total_clean:,} registros")
print(f"2. tbl_caratula_cdv_facturado:           {total_facturado:,} registros")
print(f"3. tbl_caratula_cdv_frcst:                {total_frcst:,} registros")
print(f"4. tbl_caratula_cdv_planificador:        {total_planif_snp:,} registros")
print(f"5. tbl_caratula_cdv_planificador_facturado:  {total_planif_clean:,} registros")
print(f"6. tbl_caratula_cdv_planificador_frcst:  {total_planif_frcst:,} registros")
print("="*80)
total_esperado = total_clean + total_facturado + total_frcst + total_planif_snp + total_planif_clean + total_planif_frcst
print(f"TOTAL ESPERADO EN UNIFICADA: {total_esperado:,} registros")
print("="*80)

# ==============================================================================
# IDENTIFICAR CUÁLES TABLAS TIENEN 2025
# ==============================================================================
print("\n" + "="*80)
print("🔍 IDENTIFICANDO TABLAS CON DATOS DEL 2025")
print("="*80)

tablas_con_2025 = []

# Verificar cada tabla
if spark.sql("SELECT COUNT(*) as cnt FROM LH_INTELLIGENT_VISIBILITY_CARATULAS.tbl_caratula_cdv_clean WHERE Ano = 2025").collect()[0][0] > 0:
    count_2025 = spark.sql("SELECT COUNT(*) as cnt FROM LH_INTELLIGENT_VISIBILITY_CARATULAS.tbl_caratula_cdv_clean WHERE Ano = 2025").collect()[0][0]
    tablas_con_2025.append(("tbl_caratula_cdv_clean", count_2025))

if spark.sql("SELECT COUNT(*) as cnt FROM LH_INTELLIGENT_VISIBILITY_CARATULAS.tbl_caratula_cdv_facturado WHERE Ano = 2025").collect()[0][0] > 0:
    count_2025 = spark.sql("SELECT COUNT(*) as cnt FROM LH_INTELLIGENT_VISIBILITY_CARATULAS.tbl_caratula_cdv_facturado WHERE Ano = 2025").collect()[0][0]
    tablas_con_2025.append(("tbl_caratula_cdv_facturado", count_2025))

if spark.sql("SELECT COUNT(*) as cnt FROM LH_INTELLIGENT_VISIBILITY_CARATULAS.tbl_caratula_cdv_frcst WHERE Ano = 2025").collect()[0][0] > 0:
    count_2025 = spark.sql("SELECT COUNT(*) as cnt FROM LH_INTELLIGENT_VISIBILITY_CARATULAS.tbl_caratula_cdv_frcst WHERE Ano = 2025").collect()[0][0]
    tablas_con_2025.append(("tbl_caratula_cdv_frcst", count_2025))

if spark.sql("SELECT COUNT(*) as cnt FROM LH_CARATULAS_PLNF.tbl_caratula_cdv_planificador WHERE Ano = 2025").collect()[0][0] > 0:
    count_2025 = spark.sql("SELECT COUNT(*) as cnt FROM LH_CARATULAS_PLNF.tbl_caratula_cdv_planificador WHERE Ano = 2025").collect()[0][0]
    tablas_con_2025.append(("tbl_caratula_cdv_planificador", count_2025))

if spark.sql("SELECT COUNT(*) as cnt FROM LH_CARATULAS_PLNF.tbl_caratula_cdv_planificador_facturado WHERE Ano = 2025").collect()[0][0] > 0:
    count_2025 = spark.sql("SELECT COUNT(*) as cnt FROM LH_CARATULAS_PLNF.tbl_caratula_cdv_planificador_clean WHERE Ano = 2025").collect()[0][0]
    tablas_con_2025.append(("tbl_caratula_cdv_planificador_clean", count_2025))

if spark.sql("SELECT COUNT(*) as cnt FROM LH_CARATULAS_PLNF.tbl_caratula_cdv_planificador_frcst WHERE Ano = 2025").collect()[0][0] > 0:
    count_2025 = spark.sql("SELECT COUNT(*) as cnt FROM LH_CARATULAS_PLNF.tbl_caratula_cdv_planificador_frcst WHERE Ano = 2025").collect()[0][0]
    tablas_con_2025.append(("tbl_caratula_cdv_planificador_frcst", count_2025))

if len(tablas_con_2025) > 0:
    print("\n⚠️ LAS SIGUIENTES TABLAS TIENEN DATOS DEL 2025:")
    for tabla, count in tablas_con_2025:
        print(f"   • {tabla}: {count:,} registros del 2025")
else:
    print("\n✅ NINGUNA TABLA TIENE DATOS DEL 2025 - TODAS SON 2026")

print("\n" + "="*80)
print("✅ DIAGNÓSTICO COMPLETADO")
print("="*80)
# Out:
# StatementMeta(, 2db552ac-8876-4ac5-bf0e-3da40b84c41f, 26, Finished, Available, Finished)
# ...
# DIAGNÓSTICO: VERIFICANDO AÑOS EN CADA TABLA
# ...
#
# ...
# TABLA 1: LH_INTELLIGENT_VISIBILITY_CARATULAS.tbl_caratula_cdv_clean
# ...
# Total registros: 82,730
#
# 📅 Distribución por Año:
# +----+---------+
# |Ano |registros|
# +----+---------+
# |2026|13730    |
# |2027|13800    |
# |2028|13800    |
# |2029|13800    |
# |2030|13800    |
# |2031|13800    |
# +----+---------+
#
#
# 📅 Distribución por Año y Mes:
# +----+-------+---------+
# |Ano |Mes    |registros|
# +----+-------+---------+
# |2026|Febrero|13730    |
# |2027|Febrero|13800    |
# |2028|Febrero|13800    |
# |2029|Febrero|13800    |
# |2030|Febrero|13800    |
# |2031|Febrero|13800    |
# +----+-------+---------+
#
#
# ...
# TABLA 2: LH_INTELLIGENT_VISIBILITY_CARATULAS.tbl_caratula_cdv_facturado
# ...
# Total registros: 82,730
#
# 📅 Distribución por Año:
# +----+---------+
# |Ano |registros|
# +----+---------+
# |2026|13730    |
# |2027|13800    |
# ...

# %%
# ==============================================================================
# CARGAR TODAS LAS TABLAS
# ==============================================================================
from pyspark.sql.functions import col, lit

print("=== CARGANDO TODAS LAS TABLAS ===\n")

# Tabla 1
df_clean = spark.sql("SELECT * FROM LH_INTELLIGENT_VISIBILITY_CARATULAS.tbl_caratula_cdv_clean")
print(f"1. df_clean: {df_clean.count():,} registros")

# Tabla 2
df_facturado = spark.sql("SELECT * FROM LH_INTELLIGENT_VISIBILITY_CARATULAS.tbl_caratula_cdv_facturado")
print(f"2. df_facturado: {df_facturado.count():,} registros")

# Tabla 3
df_frcst = spark.sql("SELECT * FROM LH_INTELLIGENT_VISIBILITY_CARATULAS.tbl_caratula_cdv_frcst")
print(f"3. df_frcst: {df_frcst.count():,} registros")

# Tabla 4
df_planif_snp = spark.sql("SELECT * FROM LH_CARATULAS_PLNF.tbl_caratula_cdv_planificador")
print(f"4. df_planif_snp: {df_planif_snp.count():,} registros")

# Tabla 5
df_planif_clean = spark.sql("SELECT * FROM LH_CARATULAS_PLNF.tbl_caratula_cdv_planificador_clean")
print(f"5. df_planif_clean: {df_planif_clean.count():,} registros")

# Tabla 6
df_planif_frcst = spark.sql("SELECT * FROM LH_CARATULAS_PLNF.tbl_caratula_cdv_planificador_frcst")
print(f"6. df_planif_frcst: {df_planif_frcst.count():,} registros")

print("\n✅ 6 tablas cargadas")

# ==============================================================================
# VERIFICAR COLUMNA PLANIFICADOR
# ==============================================================================
print("\n=== VERIFICANDO COLUMNA 'Planificador' ===\n")

# Verificar cada tabla
print(f"df_clean tiene 'Planificador': {'Planificador' in df_clean.columns}")
print(f"df_facturado tiene 'Planificador': {'Planificador' in df_facturado.columns}")
print(f"df_frcst tiene 'Planificador': {'Planificador' in df_frcst.columns}")
print(f"df_planif_snp tiene 'Planificador': {'Planificador' in df_planif_snp.columns}")
print(f"df_planif_clean tiene 'Planificador': {'Planificador' in df_planif_clean.columns}")
print(f"df_planif_frcst tiene 'Planificador': {'Planificador' in df_planif_frcst.columns}")

print("\n✅ Verificación completada")

# ==============================================================================
# AGREGAR COLUMNA PLANIFICADOR DONDE NO EXISTA
# ==============================================================================
print("\n=== AGREGANDO COLUMNA 'Planificador' ===\n")

# df_clean
if 'Planificador' not in df_clean.columns:
    df_clean = df_clean.withColumn("Planificador", lit("Todos"))
    print("✓ df_clean: Columna 'Planificador' agregada = 'Todos'")
else:
    print("✓ df_clean: Ya tiene 'Planificador'")

# df_facturado
if 'Planificador' not in df_facturado.columns:
    df_facturado = df_facturado.withColumn("Planificador", lit("Todos"))
    print("✓ df_facturado: Columna 'Planificador' agregada = 'Todos'")
else:
    print("✓ df_facturado: Ya tiene 'Planificador'")

# df_frcst
if 'Planificador' not in df_frcst.columns:
    df_frcst = df_frcst.withColumn("Planificador", lit("Todos"))
    print("✓ df_frcst: Columna 'Planificador' agregada = 'Todos'")
else:
    print("✓ df_frcst: Ya tiene 'Planificador'")

# df_planif_snp
if 'Planificador' not in df_planif_snp.columns:
    df_planif_snp = df_planif_snp.withColumn("Planificador", lit("Todos"))
    print("✓ df_planif_snp: Columna 'Planificador' agregada = 'Todos'")
else:
    print("✓ df_planif_snp: Ya tiene 'Planificador'")

# df_planif_clean
if 'Planificador' not in df_planif_clean.columns:
    df_planif_clean = df_planif_clean.withColumn("Planificador", lit("Todos"))
    print("✓ df_planif_clean: Columna 'Planificador' agregada = 'Todos'")
else:
    print("✓ df_planif_clean: Ya tiene 'Planificador'")

# df_planif_frcst
if 'Planificador' not in df_planif_frcst.columns:
    df_planif_frcst = df_planif_frcst.withColumn("Planificador", lit("Todos"))
    print("✓ df_planif_frcst: Columna 'Planificador' agregada = 'Todos'")
else:
    print("✓ df_planif_frcst: Ya tiene 'Planificador'")

print("\n✅ Todas las tablas tienen columna 'Planificador'")

# ==============================================================================
# ACTUALIZAR TABLAS FÍSICAS QUE NO TENÍAN PLANIFICADOR
# ==============================================================================
print("\n=== ACTUALIZANDO TABLAS FÍSICAS ===\n")

# Solo actualizar las que NO tenían la columna originalmente
tablas_a_actualizar = []

# Verificar df_clean original
if 'Planificador' not in spark.sql("SELECT * FROM LH_INTELLIGENT_VISIBILITY_CARATULAS.tbl_caratula_cdv_clean LIMIT 1").columns:
    tablas_a_actualizar.append(("df_clean", df_clean, "LH_INTELLIGENT_VISIBILITY_CARATULAS.tbl_caratula_cdv_clean"))

# Verificar df_facturado original
if 'Planificador' not in spark.sql("SELECT * FROM LH_INTELLIGENT_VISIBILITY_CARATULAS.tbl_caratula_cdv_facturado LIMIT 1").columns:
    tablas_a_actualizar.append(("df_facturado", df_facturado, "LH_INTELLIGENT_VISIBILITY_CARATULAS.tbl_caratula_cdv_facturado"))

# Verificar df_frcst original
if 'Planificador' not in spark.sql("SELECT * FROM LH_INTELLIGENT_VISIBILITY_CARATULAS.tbl_caratula_cdv_frcst LIMIT 1").columns:
    tablas_a_actualizar.append(("df_frcst", df_frcst, "LH_INTELLIGENT_VISIBILITY_CARATULAS.tbl_caratula_cdv_frcst"))

# Actualizar solo las necesarias
if len(tablas_a_actualizar) > 0:
    print(f"Se actualizarán {len(tablas_a_actualizar)} tablas:\n")
    
    for nombre_df, df, tabla in tablas_a_actualizar:
        print(f"Actualizando {tabla}...")
        df.write.mode("overwrite").option("overwriteSchema", "true").saveAsTable(tabla)
        print(f"✓ {nombre_df} actualizada\n")
    
    print("✅ Tablas físicas actualizadas con columna 'Planificador'")
else:
    print("✓ Todas las tablas YA tienen columna 'Planificador' en el Lakehouse")
    print("✓ No se requieren actualizaciones")

# ==============================================================================
# APPEND TODAS LAS TABLAS A tbl_caratula_cdv_unificada
# ==============================================================================
print("\n=== APPEND TODAS LAS TABLAS ===\n")

# Crear tabla unificada con la primera tabla
print("Creando tabla base con df_clean...")
df_clean.write.mode("overwrite").saveAsTable("LH_INTELLIGENT_VISIBILITY_CARATULAS.tbl_caratula_cdv_unificada")
print(f"✓ Tabla creada: {df_clean.count():,} registros")

# Append df_facturado
print("\nAppend df_facturado...")
df_facturado.write.mode("append").saveAsTable("LH_INTELLIGENT_VISIBILITY_CARATULAS.tbl_caratula_cdv_unificada")
print("✓ Agregado")

# Append df_frcst
print("\nAppend df_frcst...")
df_frcst.write.mode("append").saveAsTable("LH_INTELLIGENT_VISIBILITY_CARATULAS.tbl_caratula_cdv_unificada")
print("✓ Agregado")

# Append df_planif_snp
print("\nAppend df_planif_snp...")
df_planif_snp.write.mode("append").saveAsTable("LH_INTELLIGENT_VISIBILITY_CARATULAS.tbl_caratula_cdv_unificada")
print("✓ Agregado")

# Append df_planif_clean
print("\nAppend df_planif_clean...")
df_planif_clean.write.mode("append").saveAsTable("LH_INTELLIGENT_VISIBILITY_CARATULAS.tbl_caratula_cdv_unificada")
print("✓ Agregado")

# Append df_planif_frcst
print("\nAppend df_planif_frcst...")
df_planif_frcst.write.mode("append").saveAsTable("LH_INTELLIGENT_VISIBILITY_CARATULAS.tbl_caratula_cdv_unificada")
print("✓ Agregado")

# Verificar total
print("\n=== VERIFICACIÓN FINAL ===")
total = spark.sql("SELECT COUNT(*) as total FROM LH_INTELLIGENT_VISIBILITY_CARATULAS.tbl_caratula_cdv_unificada").collect()[0][0]
print(f"\n✅ Total registros en tabla unificada: {total:,}")

# Distribución por Planificador
print("\nDistribución por Planificador:")
spark.sql("""
    SELECT Planificador, COUNT(*) as registros
    FROM LH_INTELLIGENT_VISIBILITY_CARATULAS.tbl_caratula_cdv_unificada
    GROUP BY Planificador
    ORDER BY registros DESC
""").show(truncate=False)

# Distribución por Calculo
print("\nDistribución por Calculo:")
spark.sql("""
    SELECT Calculo, COUNT(*) as registros
    FROM LH_INTELLIGENT_VISIBILITY_CARATULAS.tbl_caratula_cdv_unificada
    GROUP BY Calculo
    ORDER BY registros DESC
""").show(truncate=False)

print("\n✅ APPEND COMPLETADO - Tabla: tbl_caratula_cdv_unificada")
# Out:
# StatementMeta(, 2db552ac-8876-4ac5-bf0e-3da40b84c41f, 14, Finished, Available, Finished)
# === CARGANDO TODAS LAS TABLAS ===
# 1. df_clean: 82,730 registros
# 2. df_facturado: 82,730 registros
# 3. df_frcst: 82,730 registros
# 4. df_planif_snp: 380,620 registros
# 5. df_planif_clean: 268,560 registros
# 6. df_planif_frcst: 380,620 registros
#
# ✅ 6 tablas cargadas
#
# === VERIFICANDO COLUMNA 'Planificador' ===
#
# df_clean tiene 'Planificador': True
# df_facturado tiene 'Planificador': True
# df_frcst tiene 'Planificador': True
# df_planif_snp tiene 'Planificador': True
# df_planif_clean tiene 'Planificador': True
# df_planif_frcst tiene 'Planificador': True
#
# ✅ Verificación completada
#
# === AGREGANDO COLUMNA 'Planificador' ===
#
# ✓ df_clean: Ya tiene 'Planificador'
# ✓ df_facturado: Ya tiene 'Planificador'
# ✓ df_frcst: Ya tiene 'Planificador'
# ✓ df_planif_snp: Ya tiene 'Planificador'
# ✓ df_planif_clean: Ya tiene 'Planificador'
# ✓ df_planif_frcst: Ya tiene 'Planificador'
#
# ...

# %%
# PARTE B: CREAR TABLA ESPEJO
print("\nCreando tabla espejo...")

df_espejo = spark.sql("""
    SELECT * 
    FROM LH_INTELLIGENT_VISIBILITY_CARATULAS.tbl_caratula_cdv_unificada
""")

df_espejo.write \
    .mode("overwrite") \
    .option("overwriteSchema", "true") \
    .saveAsTable("LH_INTELLIGENT_VISIBILITY_CARATULAS.TBL_001_CARATULAS_CONT")

print("Tabla espejo guardada: TBL_001_CARATULAS_CONT")
print(f"Total registros en espejo: {df_espejo.count():,}")
# Out:
# StatementMeta(, 2db552ac-8876-4ac5-bf0e-3da40b84c41f, 15, Finished, Available, Finished)
# Creando tabla espejo...
# Tabla espejo guardada: TBL_001_CARATULAS_CONT
# Total registros en espejo: 1,277,990

# %%
df = spark.sql("SELECT * FROM LH_INTELLIGENT_VISIBILITY_CARATULAS.tbl_caratula_cdv_unificada")
display(df)
# Out:
# StatementMeta(, b7e5d96d-3d32-46e5-83ae-fe7cd0eaa70a, 3, Finished, Available, Finished)
# SynapseWidget(Synapse.DataFrame, 5a775c96-3197-4ee6-b155-c7fddc3485dc)

# %%
df = spark.sql("SELECT * FROM LH_INTELLIGENT_VISIBILITY_CARATULAS.tbl_001_caratulas_cont")
display(df)
# Out:
# StatementMeta(, b7e5d96d-3d32-46e5-83ae-fe7cd0eaa70a, 4, Finished, Available, Finished)
# SynapseWidget(Synapse.DataFrame, f2a11622-8122-4767-a6be-f3a597cede59)

# %%
# Welcome to your new notebook
# Type here in the cell editor to add code!
from pyspark.sql.functions import lit
# Out:
# StatementMeta(, f6ab0750-a7ce-41f6-b9b8-478d7e52aad3, 9, Finished, Available, Finished)

# %%
# ==============================================================================
# SNIPPET 1: AGREGAR COLUMNA PLANIFICADOR A TABLA CLEAN
# ==============================================================================

print("=== SNIPPET 1: AGREGAR COLUMNA PLANIFICADOR ===")

# Cargar tabla CLEAN existente
df_clean = spark.sql("""
    SELECT * 
    FROM LH_INTELLIGENT_VISIBILITY_CARATULAS.tbl_caratula_cdv_clean
""")

print(f"Registros originales: {df_clean.count():,}")

# Agregar columna Planificador = "Todos" a TODAS las filas
df_clean_con_planif = df_clean.withColumn("Planificador", lit("Todos"))

# Guardar sobrescribiendo CON overwriteSchema
df_clean_con_planif.write \
    .mode("overwrite") \
    .option("overwriteSchema", "true") \
    .saveAsTable("LH_INTELLIGENT_VISIBILITY_CARATULAS.tbl_caratula_cdv_clean")

print("Columna Planificador agregada con valor 'Todos'")
print(f"Total registros: {df_clean_con_planif.count():,}")

# Verificar
print("\nSample con nueva columna:")
spark.sql("""
    SELECT PAIS, Familia, Planificador, Attribute, ORDENM, Inv_Inic, Inv_Final
    FROM LH_INTELLIGENT_VISIBILITY_CARATULAS.tbl_caratula_cdv_clean
    WHERE PAIS = 'CR' AND Familia = 'LAVA' AND Ano = 2025 AND PWOH = 1
    ORDER BY ORDENM
    LIMIT 5
""").show(truncate=False)

print("[COMPLETADO] Snippet 1")
# Out:
# StatementMeta(, f6ab0750-a7ce-41f6-b9b8-478d7e52aad3, 10, Finished, Available, Finished)
# === SNIPPET 1: AGREGAR COLUMNA PLANIFICADOR ===
# Registros originales: 37,440
# Columna Planificador agregada con valor 'Todos'
# Total registros: 37,440
#
# Sample con nueva columna:
# +----+-------+------------+---------+------+--------+---------+
# |PAIS|Familia|Planificador|Attribute|ORDENM|Inv_Inic|Inv_Final|
# +----+-------+------------+---------+------+--------+---------+
# |CR  |LAVA   |Todos       |ENE      |1.0   |3656.0  |7049.0   |
# |CR  |LAVA   |Todos       |FEB      |2.0   |7049.0  |9011.0   |
# |CR  |LAVA   |Todos       |MAR      |3.0   |9011.0  |8191.0   |
# |CR  |LAVA   |Todos       |ABR      |4.0   |8191.0  |5782.0   |
# |CR  |LAVA   |Todos       |MAY      |5.0   |5782.0  |4139.0   |
# +----+-------+------------+---------+------+--------+---------+
#
# [COMPLETADO] Snippet 1

# %%
# ==============================================================================
# SNIPPET 2: APPEND TABLA PLANIFICADORES A CLEAN
# ==============================================================================

print("=== SNIPPET 2: APPEND PLANIFICADORES ===")

# Cargar tabla de planificadores
df_planificadores = spark.sql("""
    SELECT * 
    FROM LH_CARATULAS_PLNF.tbl_caratula_cdv_planificador
""")

print(f"Registros de planificadores a agregar: {df_planificadores.count():,}")

# APPEND a tabla CLEAN
df_planificadores.write \
    .mode("append") \
    .saveAsTable("LH_INTELLIGENT_VISIBILITY_CARATULAS.tbl_caratula_cdv_clean")

print("APPEND completado")

# Verificar total
total = spark.sql("""
    SELECT COUNT(*) as total 
    FROM LH_INTELLIGENT_VISIBILITY_CARATULAS.tbl_caratula_cdv_clean
""").collect()[0][0]

print(f"Total registros en tabla CLEAN: {total:,}")

# Ver distribución por planificador
print("\nDistribución por Planificador:")
spark.sql("""
    SELECT Planificador, COUNT(*) as registros
    FROM LH_INTELLIGENT_VISIBILITY_CARATULAS.tbl_caratula_cdv_clean
    GROUP BY Planificador
    ORDER BY registros DESC
""").show(20, truncate=False)

print("[COMPLETADO] Snippet 2")
# Out:
# StatementMeta(, f6ab0750-a7ce-41f6-b9b8-478d7e52aad3, 11, Finished, Available, Finished)
# === SNIPPET 2: APPEND PLANIFICADORES ===
# Registros de planificadores a agregar: 268,560
# APPEND completado
# Total registros en tabla CLEAN: 306,000
#
# Distribución por Planificador:
# +------------+---------+
# |Planificador|registros|
# +------------+---------+
# |Todos       |37440    |
# |F5Q         |28080    |
# |D5U         |23760    |
# |F5M         |14400    |
# |D5Z         |12960    |
# |F5G         |12960    |
# |D5Y         |11520    |
# |F5P         |10080    |
# |F5F         |9360     |
# |D5L         |9360     |
# |G4X         |9360     |
# |F5K         |7920     |
# |D5F         |6480     |
# |D5O         |6480     |
# |F5B         |6480     |
# |D5H         |5760     |
# |F5D         |5760     |
# |D5K         |5040     |
# |F5L         |5040     |
# |D5S         |5040     |
# +------------+---------+
# only showing top 20 rows
#
# [COMPLETADO] Snippet 2

# %%
# PARTE B: CREAR TABLA ESPEJO
print("\nCreando tabla espejo...")

df_espejo = spark.sql("""
    SELECT * 
    FROM LH_INTELLIGENT_VISIBILITY_CARATULAS.tbl_caratula_cdv_clean
""")

df_espejo.write \
    .mode("overwrite") \
    .saveAsTable("LH_INTELLIGENT_VISIBILITY_CARATULAS.TBL_001_CARATULAS_CONT")

print("Tabla espejo guardada: TBL_001_CARATULAS_CONT")
print(f"Total registros en espejo: {df_espejo.count():,}")
# Out:
# StatementMeta(, f6ab0750-a7ce-41f6-b9b8-478d7e52aad3, 12, Finished, Available, Finished)
# === SNIPPET 3: DIMENSIÓN Y ESPEJO ===
#
# Creando dimensión planificadores...
# Planificadores únicos: 56
# +------------+
# |Planificador|
# +------------+
# |B5A         |
# |B5E         |
# |B5G         |
# |D5B         |
# |D5C         |
# |D5D         |
# |D5E         |
# |D5F         |
# |D5G         |
# |D5H         |
# |D5I         |
# |D5K         |
# |D5L         |
# |D5M         |
# |D5N         |
# |D5O         |
# |D5P         |
# |D5Q         |
# |D5R         |
# |D5S         |
# |D5T         |
# |D5U         |
# |D5V         |
# |D5Y         |
# |D5Z         |
# |F5A         |
# |F5B         |
# |F5D         |
# |F5F         |
# |F5G         |
# |F5H         |
# |F5I         |
# |F5J         |
# |F5K         |
# |F5L         |
# |F5M         |
# |F5N         |
# |F5O         |
# |F5P         |
# |F5Q         |
# |G4D         |
# |G4I         |
# |G4M         |
# |G4Q         |
# ...

# %%
# ==============================================================================
# APPEND: Agregar planificadores a tabla CLEAN (final)
# ==============================================================================

from pyspark.sql.functions import lit

print("=== APPEND PLANIFICADORES A TABLA CLEAN ===")

# Cargar tabla CON planificadores (desde LH_CARATULAS_PLNF)
df_planificadores = spark.sql("""
    SELECT * 
    FROM LH_CARATULAS_PLNF.tbl_caratula_cdv_planificador
""")

print(f"Registros CON planificador: {df_planificadores.count():,}")

# Cargar tabla CLEAN para verificar estructura (desde LH_INTELLIGENT_VISIBILITY_CARATULAS)
df_clean = spark.sql("""
    SELECT * 
    FROM LH_INTELLIGENT_VISIBILITY_CARATULAS.tbl_caratula_cdv_clean
    LIMIT 1
""")

# Verificar si CLEAN ya tiene columna Planificador
if "Planificador" not in df_clean.columns:
    print("Tabla CLEAN NO tiene columna Planificador - agregando primero...")
    
    # Agregar columna a tabla existente
    spark.sql("""
        ALTER TABLE LH_INTELLIGENT_VISIBILITY_CARATULAS.tbl_caratula_cdv_clean 
        ADD COLUMNS (Planificador STRING)
    """)
    
    # Actualizar registros existentes con "Todos"
    spark.sql("""
        UPDATE LH_INTELLIGENT_VISIBILITY_CARATULAS.tbl_caratula_cdv_clean 
        SET Planificador = 'Todos' 
        WHERE Planificador IS NULL
    """)
    
    print("Columna Planificador agregada y llenada con 'Todos'")

# APPEND de planificadores a CLEAN
df_planificadores.write.format("delta").mode("append").saveAsTable(
    "LH_INTELLIGENT_VISIBILITY_CARATULAS.tbl_caratula_cdv_clean"
)

print(f"\n✅ APPEND completado a: tbl_caratula_cdv_clean")

# Verificar resultado
total = spark.sql("""
    SELECT COUNT(*) as total 
    FROM LH_INTELLIGENT_VISIBILITY_CARATULAS.tbl_caratula_cdv_clean
""").collect()[0][0]

print(f"Total registros en tabla CLEAN: {total:,}")

# Distribución por planificador
print("\nDistribución por Planificador:")
spark.sql("""
    SELECT Planificador, COUNT(*) as registros
    FROM LH_INTELLIGENT_VISIBILITY_CARATULAS.tbl_caratula_cdv_clean
    GROUP BY Planificador
    ORDER BY Planificador
""").show(truncate=False)

print("\n✅ COMPLETADO")
print("tbl_caratula_cdv_clean es la tabla FINAL")
# Out:
# StatementMeta(, f6ab0750-a7ce-41f6-b9b8-478d7e52aad3, -1, Cancelled, , Cancelled)

# %%
df = spark.sql("SELECT * FROM LH_INTELLIGENT_VISIBILITY_CARATULAS.tbl_caratula_cdv_clean")
display(df)
# Out:
# StatementMeta(, f6ab0750-a7ce-41f6-b9b8-478d7e52aad3, -1, Cancelled, , Cancelled)

# %%
# ==============================================================================
# CREAR TABLA DIMENSIÓN PLANIFICADORES DESDE TABLA DE PLANIFICADORES
# ==============================================================================

print("=== CREANDO TABLA DIMENSIÓN PLANIFICADORES ===")

# Extraer planificadores únicos desde la tabla correcta
df_dim_planificadores = spark.sql("""
    SELECT DISTINCT Planificador
    FROM LH_CARATULAS_PLNF.tbl_caratula_cdv_planificador
    WHERE Planificador IS NOT NULL
    ORDER BY Planificador
""")

print(f"Planificadores únicos encontrados: {df_dim_planificadores.count():,}")

# Mostrar lista completa
print("\nLista de planificadores:")
df_dim_planificadores.show(100, truncate=False)

# Guardar en el lakehouse de planificadores
df_dim_planificadores.write \
    .mode("overwrite") \
    .saveAsTable("LH_CARATULAS_PLNF.dim_planificadores")

print("\n✅ Tabla guardada: LH_CARATULAS_PLNF.dim_planificadores")
print("Columna: Planificador")

# Verificación
print("\nVerificando tabla creada:")
spark.sql("SELECT * FROM LH_CARATULAS_PLNF.dim_planificadores").show(20, truncate=False)
# Out:
# StatementMeta(, f6ab0750-a7ce-41f6-b9b8-478d7e52aad3, -1, Cancelled, , Cancelled)

# %%
# Crea un nuevo DataFrame con TODOS los datos de la tabla original
df_ESPEJO_CARATULAS = spark.sql("SELECT * FROM LH_INTELLIGENT_VISIBILITY_CARATULAS.tbl_caratula_cdv_clean")
# Out:
# StatementMeta(, f6ab0750-a7ce-41f6-b9b8-478d7e52aad3, -1, Cancelled, , Cancelled)

# %%
# 1. Definir la ruta de la nueva tabla
new_table_name = "LH_INTELLIGENT_VISIBILITY_CARATULAS.TBL_001_CARATULAS_CONT"

# 2. Copiar todos los datos y guardar la nueva tabla permanentemente
df_ESPEJO_CARATULAS.write \
    .mode("overwrite") \
    .format("delta") \
    .saveAsTable(new_table_name)

print(f"¡El espejo ha sido creado! La tabla completa {new_table_name} ahora existe en tu Lakehouse.")
# Out:
# StatementMeta(, f6ab0750-a7ce-41f6-b9b8-478d7e52aad3, -1, Cancelled, , Cancelled)
