# %% [markdown]
# # FINAL

# %%
# -*- coding: utf-8 -*-
# DICCIONARIO DE SKUs ACTUALIZADO - 3975 SKUs
dict_skus_ = {
  "ANDINO": {
    "CO": {
      "LAVA": [
        "DMG17R8MSDAB2", "LCA13SZI1", "LCA80GZI1", "LMA0220WDGAB0", "LMA1120WDGAB0",
        "LMA180BZI0", "LMA180GZI0", "LMA4120WDGAB0", "LMA6120WDGAB0", "LMA79104WGAB1",
        "LMA79114VBAB0", "LMA79114WBAB0", "LMA8120WDGAB0", "LMA9020WDGAB0", "LMA9020WGAB0",
        "LMC46100WDAB0", "LMC48100WDAB0", "LMC48100WDAB1", "LMC70200WDAB1", "LMC70203WDAB0",
        "LMC71200WDAB0", "LMC72201WGAB0", "LMC72211WDAB0", "LMC74201WDAB0", "LMC74215WDAB0",
        "LMC75201WDAB0", "LMD1123HBAB0", "LMD3123HBAB0", "LMD3124PBAB0", "LMD6124HBAB0",
        "LMD7023PBAB0", "MCL1740GSBB0", "MCLC2040GSBB0", "MCLC2040PPDG0", "MCLC2040PSDG0",
        "MCLC2240GSBB0", "MCLC2340GPDG0", "MCLC2340GSDG0",
      ],
      "COCC": [
        "1S2HE/16", "C2Y366P2TS1", "C2Y366P3TD1", "C2Y366P4MW2", "C2Y366P4TW2",
        "CCC20ANXN-5", "CCC20GCGXN-4", "CCC20GCGXN-5", "CCC20GTGXN-5", "CCC20GTGXN-6",
        "CG6012TX0", "CG6014P3I", "CG9014P3I", "CG9016I3I", "CGCI400I0",
        "CGG6020V0", "CGG6020V1", "CGG6025V0", "CGG6025V1", "CGG7710I2",
        "CGG7715V2", "CGG8610I1", "CGG8610I2", "CGG8615V1", "CGG8615V2",
        "CGP9019I6I", "CGP9019P6I", "CGP95302MS1", "CGP95362MS1", "CGU366P2TS1",
        "CGU366P3TD1", "CGU366P4TW2", "CGU486P2TS1", "CGU486P3TD1", "CGU486P4TW2",
        "CHP90302TSS", "CHP90362TSS", "CHP95302MSS", "CHP95362MSS", "CM6017P2I",
        "CM6018PI0", "CM6030N", "CM6030PI0", "CM6035NV0", "CM6035XV0",
        "CM6040NV0", "CM6040XV0", "CM6048PIW0", "CM7648PIW0", "CM9025II0",
        "CMG6015V0", "CMG6015V1", "CMG6018V0", "CMG6018V1", "CMG6044KM-0CON",
        "CMG6044LA-0CON", "CMG6044SA-1CON", "CMG6044V0", "CMG6054FA-0CON", "CMG6054LA-0CON",
        "CMG6054SA-1CON", "CMM6054SC-0CON", "CMPUV601SSX0", "CMPUV761SSX0", "CSB913M2NS5",
        "CSB913P2NS1", "CSB913P3ND1", "CSB913P3VD1", "CSB913P4NW2", "CSB923M2NS5",
        "CSB923P2NS1", "CSB923P3ND1", "CSB923P4NW2", "CTC912P2NS1", "CTG6010AI0",
        "CTM6011IX", "CTS70DM2NS5", "CTS70DP2NS1", "CTS90DP2NS1", "CTS90DP3ND1",
        "CTS90DP4MW2", "CTS90DP4NW2", "CTS90FP2NS1", "CTS90FP3ND1", "CTS90FP4NW2",
        "CVW93613MDS", "CVW93614MWM", "EG7686SSC0", "EMC20GGXN-6", "EMC30KXX-5",
        "EMC30KXX-6", "EMC5150SNX0", "EMC5150SNX1", "EMC6050NFX0", "EMC6050NFX1",
        "EMC6060NFX1", "EMC7630NFX0", "EMC7680NFX0", "HG6040EYAI1", "HG6040GWAI1",
        "HG6045EYAI2", "HGP6065EWAI0", "HGP6065EWAI1", "HGP6065EYAI0", "HGP6065EYAI1",
        "HGP6065LWAI0", "HGP6065LWAI1", "HGP8050K1", "HGP8050KE0", "HGP8050YE1",
        "HM6013GWAI0", "HM6014EUAI0", "HM6017GWAI0", "HM6021EWAI0", "HM6022EYAI0",
        "HM6027GWAI0", "HM6028EUAI0", "HM6028EWN0", "HM6031EUAI0", "HM6045EYI0",
        "HMFM6036EI1", "IBG2040XN0", "IBG2440GN0", "IO312DVI0", "IO6056HEWI0",
        "IO6056HGWI0", "IO614PVI0", "IO8042HEYD0", "IO9019CI5I", "IOT8002I1",
        "PGP64KRTIY0", "PGP7030SLSS", "PGP7036SLSS", "PGP75KMTIY0", "PGP75TI0",
        "PGP95EBG0", "PGP95EMNNY0", "PGP95IV0", "PGP95KBG0", "PGP95KMNNY0",
        "PGP96KMTIY0", "PGP96TI0", "PHP9030SJSS", "PHP9036SJSS", "PHP9036STSS",
        "PIP6014S", "PM302I0", "PM6042GV0", "PM6044ENA0", "PM6044NA0",
        "PM6044NF0", "PM6044NS0", "PM6046V0", "PM6048GV0", "PM6054NF0",
        "PM6054NS0", "PM6055NF0", "PM64IV0", "PM7650GV0", "PM7655GNV0",
        "PMC6043AN0", "PP9036SJSS", "PSB9120BLTS", "PSB9240SFSS", "PT7800SHSS",
        "PTS7000SNSS", "PV970NSS", "PV977NSS", "TX1G-6CON", "TX1G-7CON",
        "UVB30SKSS", "UVB36SKSS", "UVC7300SLSS", "UVC9480SLSS", "UVD6301SPSS",
        "UVD6361DPBB", "UVH13012MSS", "UVW9361BLTS", "UVW93642PSS", "ZDP484NGTSS",
        "ZGP486NDTSS", "ZGU30RSLSS", "ZGU364NDTSS", "ZGU36ESLSS", "ZGU486NDTSS",
        "ZHU30RSTSS", "ZHU36RSJSS", "ZHU36RSTSS", "ZSB9231NSS", "ZSB9232NSS",
        "ZSB9232VSS", "ZTS90DPSNSS", "ZTS90DSSNSS", "ZV950SDSS", "ZVC48LSS",
        "ZWL1126SJSS",
      ],
      "GLOB": [
        "AFM38DN", "ALASKA11", "ALASKA14!", "ALASKA145B4", "ALASKA145B5",
        "ALASKA145BH", "ALASKA145BH1", "ALASKA19!", "ALASKA195BH", "ALASKA195BH1",
        "ALASKA200B4", "ALASKA200B5", "ALASKA30()", "ALASKA300B3", "ALASKA300B4",
        "ALASKA300BH", "ALASKA300BH1", "ALASKA43()", "ALASKA430B H", "ALASKA430B3",
        "ALASKA430BH", "ALASKA52()", "ALASKA520BH", "ALASKAV2()", "ALASKAV200S0",
        "ALASKAVIT", "ALASKAVIT220B1", "ALASKAVIT316CEG", "ALASKAVIT320B0", "ALASKAVIT320B1",
        "ALASKAVIT416CEG", "CCP06BP2PS1", "CCP06BP3PD1", "CCP06BP4PW2", "CCP06DP2PS1",
        "CCP06DP4PW2", "CCR06BM2PS5", "CDE06RP3ND1", "CDT845M5NS5", "CDT845P2NS1",
        "CDT845P3ND1", "CDT845P4NW2", "CDT858P2VS1", "CDT858P3VD1", "CEB515P3NDS",
        "CEB515P4NWM", "CVM9179SLSS", "DM1260TPSS", "DM1460TPSS", "EM02PB",
        "EMBL3TGS", "EMM2PB", "EMM2PN", "EMMCHB", "EMTLP3TB",
        "EMTLP3TBB", "GBF410SSPSS", "GBF412SSMSSX", "GBT632SSMSSEC", "GDT226SILII",
        "GFC525N", "GLV1460FSS", "GLV1890XSS0", "GW12XDB", "GW12XDBB",
        "GW8XDBB", "GXCFS7CCSS", "HMM07BB", "HMM07BBW", "HMM07BR",
        "HMM07CE", "HMM07CEBN", "HMM07SB", "HMM07SBW", "HMM07SJW",
        "HMM07SN", "HMM09NJ1", "HMM11NP", "HMM11NPO", "HMM11SJW",
        "HMM11SN", "HMM15SJW", "HMM15SN", "HMM70SEJ", "ICMK12X0",
        "IO110MDI", "IO110MDI1", "JES11G1", "JES70G", "JVM3160RFSS",
        "MGE07SEJ", "MGE09SEJ", "MGE11SEJ", "MGE11XAF", "MGE14SEJG",
        "MXCBL01D", "MXCFS7W1", "PBT865SSPFS", "PBT865SSWFS", "PCWK22U1WDD",
        "PDT145SGLBB", "PDT145SSLSS", "PDT715SYNFS", "PDT715SYVFS", "PEB110SFSS",
        "PEB160SFSS", "PEB7227ANDD", "PEB9159SJSS", "PLV1817XSS", "PVS06BSPSS",
        "PW29BS3", "PWS06DSPSS", "RMF02BRX", "RMF02BRX0", "RMF02BRX1",
        "RMF04BRX", "RMF04BRX0", "RMF04BRX1", "RMF04CV1", "UCC15NPRII",
        "ZCWK22U2WSS", "ZDBI240HII", "ZDBR240NBS", "ZDT165SSLSS", "ZDT800SIFII",
        "ZDT915SSJSS", "ZDT975SSJSS", "ZDT985SINII", "ZDT985SPNSS", "ZDT985SSNSS",
        "ZDWI240HII", "ZEB1227SLSS", "ZIF301NPNII", "ZWL1126SRSS"
],
      "REFR": [
        "CFE28TP2MS1", "CFE28TP3MD1", "IBGA230TJCG1", "IBGA247PJCT", "IBGA300TSCG1",
        "IBGA313TSCT", "IBGP360TJCG1", "IBGP420TJCG1", "IBGP438OLCT", "IBGU235NACT",
        "IBGU235TACG1", "MA0360VLCX", "MA0384XMCSN", "MQL22LEKFPS", "MSL480LMLPS0",
        "MSL480LMLSS0", "MSL480LPLPS0", "MSL480LPLSS0", "MSL504SONBS0", "MSL521QMLSS0",
        "MSL525SMNBS0", "MSL565QMLSP0", "MSL631LKLNG0", "MSL631LKLSG0", "MSL631LKLSP0",
        "MSL631LKLSS0", "MSL746IOLFS0", "MTL442LKLSS0", "PFQ25LERCDS", "PNL26PGKCPS",
        "PNM25IMKCES", "PNQ25IMPCES", "PQL22LEKFSS", "PQL26PGKCSS", "PQL26PGKFPS",
        "PSB48YSNSS", "RMA230FJCG", "RMA230FJCG1", "RMA235FJCT", "RMA247FJCG",
        "RMA247PJCG", "RMA250FJCG", "RMA250FJCG1", "RMA250FJCL1", "RMA255FYCU",
        "RMA267FBCG", "RMA267FYCC", "RMA267FYCT", "RMA267PHCG", "RMA267PYCC",
        "RMA267PYCU", "RMA300FBCG", "RMA300FJCG", "RMA300FZCC", "RMA305FYCC",
        "RMA305FYCT", "RMA310FZCC", "RMA313FBCG", "RMA313FXCC", "RMA313FXCT",
        "RMA313FXCU", "RMA313FZCC", "RMB300IZBRP0", "RMB400IABRE0", "RMB400IBBRP0",
        "RMB400IBBRX0", "RMB432PXBQP0", "RMB432PXBQS0", "RMB520IBBQX0", "RMB520IJBQX0",
        "RMB520IWBQP0", "RMB520IWBQP1", "RMC320FACG1", "RMC390FACG1", "RMF04BRX0",
        "RMP360FLCL", "RMP365FYCT", "RMP384FGCC", "RMP384FGCT", "RMP384FLCG1",
        "RMP389GCC", "RMP389GCG", "RMP389GCT", "RMP389JCG", "RMP400FLCG",
        "RMP400FLCG1", "RMP400FLCT", "RMP400FYCU", "RMP400FZCC", "RMP405FYCU",
        "RMP410FZCC1", "RMP415BCG", "RMP415GCC", "RMP415GCG", "RMP415GCT",
        "RMP415YCC", "RMP415YCU", "RMP415ZCC", "RMP420FLCG", "RMP420FLCG1",
        "RMP420FYCU", "RMP421FBCG", "RMP421FGCC", "RMP421FGCT", "RMP421FYCU",
        "RMP421FZCC", "RMP425FYCU", "RMP435FZCU", "RMP438FBCG", "RMP438FGCT",
        "RMP438FYCU", "RMP438FZCU", "RMP470BCG", "RMP470GCT", "RMP470YCU",
        "RMP470ZCB", "RMP470ZCC", "RMP470ZCU", "RMS400IBBQP0", "RMS400IBBRP0",
        "RMS400IBBRX0", "RMS510IBBQP0", "RMS510IBBQX0", "RMS510IBBRP0", "RMS510IFBQP0",
        "RMU210NACG1", "RMU210NACU", "RMU235NACG1", "RMU235NACU", "ZIC30GNNII",
        "ZIK303NPPII", "ZIR241NPNII", "ZIR301NPNII", "ZIR361NPRII", "ZISS480DNSS",
        "ZIW303NPPII",
      ],
      "CALE": [
        "CAGLM1005AN1", "CAGLM1505AN1", "CAGLM2005AN1", "CAGM10ANS0", "CAGM15ANS0",
        "CAGM20ANS0", "CAGM30ANS0", "CAGM35ANS0", "CIM06C2SSNA", "CIM10C2NSNA",
        "CIM12C2NSNA", "CMD10TFBC", "CMD14TFBC", "CMD6TFBC", "CMM11C1FSNA",
        "CMM16C1FSNA", "CMM20C1FSNA", "CMP10TNBC", "CMP12TNBC", "CPGM1630BN",
      ],
      "AIAC": [
        "MGI18CDBC3", "MMI09CABWCCC1", "MMI09CABWCCC8", "MMI09CDBWCCC1", "MMI12CABWCCAXC9",
        "MMI12CABWCCBC1", "MMI12CABWCCC8", "MMI12CABWCCC9", "MMI12CABWCCCHI8", "MMI12CDBWCCAXC9",
        "MMI12CDBWCCBC1", "MMI12CDBWCCC8", "MMI12CDBWCCC9", "MMI12CDBWCCCHI8", "MMI12CDMCCC10",
        "MMI12CDMCCC8", "MMI18CDBWCCAXC9", "MMI18CDBWCCC8", "MMI18CDBWCCC9", "MMI18CDBWCCCHI8",
        "MMI18CDMCCC10", "MMI18CDMCCC8", "MMI24CDBWCCAXC9", "MMI24CDBWCCC8", "MMI24CDBWCCC9",
        "MMI24CDMCCC10", "MMI36HDBWCC32C1", "MMT09CABWCCC1", "MMT09CABWCCC8", "MMT09CDBWCCC1",
        "MMT12CABWCCAXC8", "MMT12CABWCCBC1", "MMT12CABWCCC8", "MMT12CABWCCCHI8", "MMT12CDBWCCAXC8",
        "MMT12CDBWCCBC1", "MMT12CDBWCCC8", "MMT18CDBWCCAXC8", "MMT18CDBWCCC8", "MMT24CDBWCCAXC8",
        "MMT24CDBWCCC8", "MMT24CDBWCCCHI8", "PTM12CABWJM2",
      ]
    },
    "EC": {
      "COCC": [
        "CD5115AN0", "CD5120SG0", "CD5120SN0", "CD51TBX0", "CDM6010AI0",
        "CGG7710IP0", "CGG8610IP0", "CGI1219S", "CGP9016I3I", "CGP9019P6I",
        "CMG6054LA-1EC", "CMG6054LA-2EC", "CMG6054SA-3EC", "CMP9002I", "CMPUV601SSX0",
        "CMPUV761SSX0", "EG7686SSC0", "EM5115SG0", "EM5115SG1", "EM5120SG1",
        "EM5120SX1", "EM5120SX2", "EM5130FX0", "EM5130FX1", "EM5530FN0",
        "EM6010AG0", "EM6015SG0", "EM6020SG0", "EM6020SG1", "EM6030SG0",
        "EM6030SG1", "EM6040FG1", "EM6040FG2", "EM6040FN0", "EM6060FX2",
        "EM6060FX3", "EM6095FX1", "EM6095FX2", "EM7610SG0", "EM7615SG0",
        "EM7620FX0", "EM7625FX0", "EM7630FX0", "EM7635FX0", "EM7640FX1",
        "EM7670FX1", "EMH7614DATMSS0", "HG6040EYAI1", "HG6045EYAI2", "HGP6065EYAI0",
        "HGP6065LXAI0", "HGP8050K1", "HGP8050KE0", "HM6027GWAI0", "HM6028EZAI0",
        "HM6031EZAI0", "PGP75KMTIY0", "PGP75TI0", "PGP95EBG0", "PGP95EMNNY0",
        "PGP95IV0", "PGP95KBG0", "PGP95KMNNY0", "PGP96KMTIY0", "PGP96TI0",
        "PGS930YPFS", "PHP774DMBB", "PM6032EV0", "PM64IV0", "PP932SMSS",
        "TX5120EX2", "TX5120EX3", "TX5120EX4",
      ],
      "GLOB": [
        "AFM38DNEC", "ALASKA145B5", "ALASKA145BH", "ALASKA195BH", "ALASKA200B5",
        "ALASKA300B4", "ALASKA300BH", "ALASKA300BH1", "ALASKA430BH", "ALASKAH145B0",
        "ALASKAH200B2", "ALASKAH320B2", "ALASKAVIT220B1", "ALASKAVIT316CEG", "ALASKAVIT320B1",
        "ALASKAVIT416CEG", "CEB515P2NSS", "EMBL1TN", "EMBL3TGS", "EMDPCCB1",
        "EMM2PB", "EMM2PN", "FUF14SVRWW", "GBF410SSPSS", "GBF412SSMSSX",
        "GBT632SSMSSEC", "GFC720N", "GW12XDBB2", "GW8XDBB2", "GXCFS7CCSS",
        "H,TM09N", "HMM07CEBN", "HMM09NJ1", "HMM11NPO", "HTM10LN",
        "JES11SG", "JES14SG", "JES70SE", "JES70W", "JVM3670SK",
        "MGE07SEJ", "MGE09SEJ", "MGE11SEJ", "MGE11XAF", "MGE14SEJG",
        "MXCBL01D", "MXCFS7CCSS", "PBT865SSPFS", "PEB110SFSS", "PEB160SFSS",
        "PLV1817XSS", "RMF0260XMXX3", "RMF04ERB0", "RMF04ERX0", "XO1120MD1",
        "ZEB1227SLSS", "HTM10LN1",
      ],
      "LAVA": [
        "DMG17R8MSDAB2", "LMA70200WDAB1", "LMA77113CBAB0", "LMA79113VBAB0", "LMD6124PBAB0",
        "LMDE3124PBAB0", "LMDE7023PBAB0", "LMDX1123HBAB0", "LMDX3123HBAB0", "LMDX6124HBAB0",
        "LMDX8124HBAB0", "LME1220WDGAB0", "LME7120WDGAB0", "LME79104VBAB0", "LME79104WBAB1",
        "LME79114SBAB0", "LME9120WDGAB0", "LMH72201WBAB1", "LMH74201WDAB1", "LMP75201WDAB0",
        "MCL2040ESDG0", "MCL2040PPDG1", "MCL2040PSBB0", "MCL2440EPDG0", "MCL2440ESDG0",
        "MCL2440PSBB0", "SME17R8MSDBP0", "SME47N8MSBBP0", "SMG17R8MSBAB0", "SMG26N5MNBAB0",
        "SMG47N8MSBAB0",
      ],
      "REFR": [
        "DUREX264PHET", "LMD6124PBAB0", "LMDE3124PBAB0", "LMDE7023PBAB0", "LMDX1123HBAB0",
        "LMDX3123HBAB0", "LMDX6124HBAB0", "LMDX8124HBAB0", "LME7120WDGAB0", "LME9120WDGAB0",
        "MSE480LPLPS0", "MSE480LPLSS0", "MSE521QMLSS0", "MSL631LKLNG0", "MTL442LKLSS0",
        "PFQ25LERCDS", "PNQ25IMPCES", "PQL22LEKFSS", "PQL26PGKCSS", "PQL26PGKFPS",
        "RMA230FVEL1", "RMA244PJEG", "RMA250FHEL1", "RMA250PHEL1", "RMA250PJEG1",
        "RMA250PJEU", "RMA264PHEU", "RMA264PJET", "RMA264PVEG", "RMA264PYEC",
        "RMA264PYEG", "RMA264PYEU", "RMA313FJEG", "RMA313FJET", "RMA313FWET",
        "RMA313FXEC", "RMA313FXEU", "RMA430FJEG", "RMA430FJET", "RMA430FWEU",
        "RMA440FZEU", "RMB300IZBRP0", "RMB432PXBQS0", "RMB520IJBQX0", "RMP378FGEU",
        "RMP378FHEU", "RMP378FJET", "RMP378FLEG", "RMP378FLEU", "RMP389GEU",
        "RMP389HEU", "RMP389JEG", "RMP389JET", "RMP415GEC", "RMP415GEU",
        "RMP415HEU", "RMP415JET", "RMP415YEU", "RMP418FGEU", "RMP418FJET",
        "RMP438FGEU", "RMP438FJET", "RMP470JET", "RMP470YEU", "RMP736FHEL1",
        "RMP736FYEU1", "RMP840FLEL1", "RMP840FYEU1", "RMP840FZEC1", "RMP942FJLEL1",
        "RMP942FYEU", "RMS510IBBQX0",
      ],
      "AIAC": [
        "MMI12CDBWCCE8", "MMI24CDBWCCE8", "MMT12CDBWCC32BN1", "MMT12CDBWCCAX8", "MMT12CDBWCCE8",
        "MMT18CDBWCCAX8", "MMT18CDBWCCE8", "MMT24CDBWCCAX8", "MMT24CDBWCCE8", "PTM12CABWJM2",
      ]
    },
    "PE": {
      "COCC": [
        "CGG6025V0", "CGG6025V1", "CGG8610I1", "CGG8610I2", "CGG8615V1",
        "CGG8615V2", "CGP9019P6Y", "CGP9536SLSS", "CGPI9007IP0", "CM6016PI0",
        "CM6018PI0", "CM6018PIY0", "CM9016PI0", "CM9018PIY0", "CME6050CSYX0",
        "CME6080CFYX0", "CMG6015V0", "CMG6044LC-0PE", "CMP3020FN0", "CMP3020FN1",
        "CMP3050FX0", "CMP5100AB0", "CMP5140FX0", "CMP5140FX1", "CMP5545FX0",
        "CMP6010FG0", "CMP6010FG1", "CMP6010FN0", "CMP6011FG0", "CMP6011FG1",
        "CMP6012AG0", "CMP6012AG1", "CMP6014AG0", "CMP6014AG1", "CMP6015SG0",
        "CMP6020FG0", "CMP6020FG1", "CMP6030FX0", "CMP6030FX1", "CMP6035FX0",
        "CMP6035FX1", "CMP6040FN0", "CMP6040FX0", "CMP6040FX1", "CMP6060FX0",
        "CMP6060FX1", "CMP6085FX0", "CMP6085FX1", "CMP7620FX0", "CMP7625FX0",
        "CMP7628FX0", "CMP7630FX0", "CMP7640FX0", "CMP7670FX0", "CMU6020PB0",
        "CMU6020PI0", "CMU9020PI0", "EG7686SSC0", "EME7675CSYX1", "EME7682CFYX0",
        "EME7682CFYX1", "EMH7602JSSY0", "EMH7612DSSY0", "EMH7614DATBS0", "EMH7614DATMSS0",
        "EMP5120GP0", "EMP5120GP1", "EMP5120GP2", "EMP7620SX0", "HG6045EYAI2",
        "HM6022EYAI0", "HM6028EYAI0", "HVGP4561YI", "IO905I0", "JGP3036SLSS",
        "JGP5030SLSS", "JGP5530SLSS", "JGP5536SLSS", "JP3530SJSS", "JP3536SJSS",
        "JTS3000SNSS", "JTS5000SNSS", "PGP7030SLSS", "PGP7036SLSS", "PGP75TI0",
        "PGP9030SLSS", "PGP9036SLSS", "PGP95EBG0", "PGP95KBG0", "PM6044PF0",
        "PM6045GV0", "PM6055PF0", "PM8655GV0", "PTS7000SNSS", "PV977NSS",
        "TX5110P1", "TX5110P2", "UVW9361BLTS", "ZET1PHSS", "ZGU36RSLSS",
        "ZSC1202JSS", "ZSC2202JSS", "ZV800SJSS", "ZV850SPSS", "ZV925SLSS",
      ],
      "GLOB": [
        "ALASKAVIT316PG", "ALASKAVIT416PG", "CHM200PB1", "CHM200PB2", "CHM200PB3",
        "CHM300PB2", "CHM300PS2", "CHM320PB1", "CHM320PS1", "CHM430PB2",
        "DAMYPRB0", "GDT225SSLSS", "GDT635HSJSS", "GFC525V", "GWS04HAESS",
        "GXCF05PFS2", "HMM07PBN", "HMM09PNJ", "HMM11PNPO", "HMM20PEB",
        "HMM20PEE", "HMM20PEG", "HMM23PSX", "HMM25PSX", "HMM28PSX",
        "HMM31PSX", "JES1495PSK", "MXCF05PFS", "PCR06WATSS", "PEB7227SLSS",
        "PEB9159SJSS", "RMF04PRB0", "RMF04PRX0", "RMF04PV0", "WDP6001I",
        "ZEB1227SLSS", "ZIDS240HSS", "ZIFS360NHLH",
      ],
      "LAVA": [
        "CLME70204BBB0", "CLMG70204BBB0", "CLMG70204DBB0", "CLPG70204DBB0", "LMA0120WPBB0",
        "LMA100BXI0", "LMA100GXI0", "LMA105BXI0", "LMA1220WDGBB0", "LMA160BXI0",
        "LMA160SXI0", "LMA4120WDGBB0", "LMA4120WPBB0", "LMA48100WDBB0", "LMA6120WDGBB0",
        "LMA6120WPBB0", "LMA70200WDBB1", "LMA72200WDBB1", "LMA72200WDBB2", "LMA8120WDGBB0",
        "LMA9020WGBB0", "LMA95BXI", "LMAP1010WBBB0", "LMAP1012WBBB0", "LMAP1015WGBB0",
        "LMAP4110WGBB0", "LMAP4120WGABB0", "LMAP4120WGBB0", "LMAP6110WBBB0", "LMAP6115WGBB0",
        "LMAP6120WGBB0", "LMAP9020WGBB0", "LMD3124PBBB0", "LMD6124PBBB0", "LME1220WDGAB0",
        "MCLP2440ESBB0", "MCLP2440PPDG0", "MCLP2440PSBB0", "MCLP2440PSDG0", "SEM090VBBB0",
        "SEM81BDBB", "SEM81BDGB", "SMG17R8MSDBB0", "SMG47N8MSBBB0", "SMG47N8MSDBB0",
        "SMG47N8MSGBB0",
      ],
      "REFR": [
        "MSC518LKRSS0", "MSD480LMRPS0", "MSD480LMRSS0", "MSD480LPRPS0", "MSD480LPRSS0",
        "MSD504SORBS0", "MSD518LKRSS0", "MSD525SERBS0", "MSD565QMLSP0", "MSD565QMLSS0",
        "MSD631LKLNG0", "MTD442LKRSS0", "PFR26JSRFFS", "PRD22LEKFSS", "RMA230FVPL1",
        "RMA230PJPG", "RMA250FVPG1", "RMA250FVPL1", "RMA250FYPG", "RMA255FYPG",
        "RMA264PYPC", "RMA300FBPG1", "RMA305FBPU", "RMA305FWPC", "RMA305FWPT",
        "RMA310FZPC", "RMA313FJPC", "RMA520FVPG1", "RMB300IZPRP0", "RMB315PTPRO0",
        "RMB400IAPRP0", "RMB432PXPRP0", "RMB432PXPRS0", "RMB520IBPRP0", "RMC320FAPG",
        "RMC390FAPG", "RMN220PVPRX0", "RMP360FJPC1", "RMP360FYPU", "RMP389JPG",
        "RMP405FJPC", "RMP405FYPU", "RMP410FZPC", "RMP415GPG", "RMP415YPC",
        "RMP415ZPC", "RMP420FLPG1", "RMP425FJPC", "RMP425FJPT", "RMP470YPC",
        "RMP942FLPG1", "RMU202PXPRS0", "RMU202PXPRS1",
      ],
      "AIAC": [
        "MMI09CDBWCCC1", "MMI12CDBWCCBC1", "MMT09CDBWCCC1", "MMT12CDBWCCBC1", "MMT12CDBWCCC8",
        "MMT12CDBWCCCE8", "MMT18CDBWCCC8", "MMT18CDBWCCCE8",
      ]
    },
    "CL": {
      "COCC": [
        "ANDES60TX3", "ANDES7620AG0", "ANDES7650FX0", "ANDES7650FX1", "ANDES7670FX0",
        "ANDES7670FX1", "ANDES76HG0", "CG6003TX0", "CM6045XV0", "CM6048PIX0",
        "CM6048PNX0", "CMC20ABX-6", "CMC20ABX-7", "CMC20AXX-1", "CMC20AXX-2",
        "CMC5100NA0", "CMC5100NA1", "CMC5110AX0", "CMC5110AX1", "CMC5115AX0",
        "CMC5515GCH-2", "CMC5530AG0", "CMC5530AG1", "CMC5540FX0", "CMC5540FX1",
        "CMC5550AX0", "CMC5560FX0", "CMC5560FX1", "CMC7660FX1", "CMG6044LD-1CL",
        "CMG6044SD-0CL", "CMG6044SD-1CL", "HM6018EXAI0", "HM6031EXAI0", "HM6045EXN0",
        "PG6040EVN0",
      ],
      "GLOB": [
        "FDHM150BY0", "FDHM150BY1", "FDHM150BY2", "FDHM200BY0", "FDHM200BY1",
        "FDHM200BY2", "GLV14FSITSS0", "HMM07CHBN", "HMM09CHNJ", "MLV14FSITSS0",
        "RMF02LRX0", "RMF04HV0", "RMF04LRX0",
      ],
      "LAVA": [
        "LMA0920WBCL0", "LMA0920WGCL0", "LMA2120WDGCL0", "LMA4120WDGCL0", "LMA5120WDGCL0",
        "LMA6120WDGCL0", "LMA6120WGCL0", "LMA7120WDGCL0", "LMA8120WDGCL0", "LMA8120WGCL0",
        "LMA9020WDGCL0", "LMA9120WDGCL0", "LMA9520WDGCL0", "MCL2040EEBBY0", "SEM010VBCL0",
        "SEM010VDCL0", "SEM101BDBY", "SEM101BDBY0", "SEM81BDBY", "SEM81BDGY",
        "SME26N5MNBCL0", "SMG26N5MNBCL1",
      ],
      "REFR": [
        "GRC22LFKFSS", "GRC26FGKFSS", "GRC26FGMFPS", "MSC480LKRPS0", "MSC518LKRSS0",
        "MSC525SERBS0", "MSC631LKLNG0", "MTC442LKRSS0", "PFO26JSRFFS", "PWO19JSRFFS",
        "RMA250PHUG1", "RMA250PVUG", "RMA255PJUC", "RMA255PYUU", "RMA300FWUC",
        "RMA300FWUT", "RMB176PXLCX0", "RMB1952BLCP0", "RMB276PXLCX0", "RMB300IZLRP0",
        "RMB300IZLRX0", "RMB302PXLRS0", "RMB426PXLRS0", "RMB432PXLRS0", "RMN220PVLRX0",
        "RMN222PXLRS0", "RMP400FHUG1", "RMP400FYUC", "RMP400FYUT", "RMP410FZUC",
        "RMP410FZUU", "RMS510IBLRP0",
      ]
    },
    "AR": {
      "COCC": [
        "AEDR60CNV", "AEGE62PV", "AEGE62VN0", "AGDR60CNV", "AGDR60EIA",
        "AGDR60EIA1", "AGDR76CIA", "AGGE62IV", "AGGE62VN0", "AGGE76I0",
        "CD5003MI", "CD5502AB", "CD5502AI", "CD5502MB", "CD5502MI",
        "CD5505AI", "CD5507AI", "CD5507MI", "CD5602AB0", "CD5602AI0",
        "CD5602AN0", "CD5603AB0", "CD5603AI0", "CD5603AN0", "CD5614AI0",
        "CD5617AI0", "CD6007MI", "CG756I", "CG760I", "CP6855AB",
        "CP6855AI", "CP6855B", "CP6855I", "CP756AI", "CP9656AI",
        "CP9656I", "CP9750I", "CRDR60IA", "CRDR90IA", "CRGE60I",
        "CTGE60I0", "CTGE90I0", "CUDR604BA", "CUDR604IA", "CUDR604NA",
        "CVGE90I", "HD60EGCV0", "HEDR600CI", "HEDR600MI", "HEDR601CN",
        "HEDR601MI", "HEGE6050I", "HEGE6055I", "HG6018EVAI0", "HG6035EVAI0",
        "HGDR601CN", "HM60EGCI0",
      ],
      "GLOB": [
        "601400511", "601400512", "601400592", "601400593", "601400594",
        "601400595", "601400611", "601400612", "601400621", "601400627",
        "601400629", "601400673", "601400674", "601400677", "601400781",
        "601400782", "601400784", "601400785", "601400786", "601400787",
        "601400788", "601400789", "601400790", "601400791", "601400792",
        "601400793", "601400794", "601400796", "601400801", "601400802",
        "601400807", "601400808", "601400809", "601400810", "601400811",
        "601400824", "601400828", "601400829", "601400830", "601400852",
        "601400853", "601400854", "601400855", "601400856", "601400890",
        "601400899", "601400915", "601400916", "601400917", "601400918",
        "601400919", "CVDR08CN0", "CVDR12CN0", "FHDR143CB", "FHDR293CB",
        "FHP220B", "FHP300B", "FHP420B", "HMD20ARBB0", "HMD20ARNJ0",
        "HMD20ARSB0", "HMD25ARSB0", "HMD30ARSJ0", "HPK90B", "LVDR1306CB0",
        "LVDR1306CI0", "LVDR1406CB0", "LVDR1406CI0", "LVDR1506CI0", "RDF04LGAS0",
      ],
      "LAVA": [
        "700100711", "700200378", "700200380", "700200382", "701000860",
        "701000862", "701000964", "701000976", "701100040", "701100108",
        "701100124", "701100150", "701100156", "701100182", "701100196",
        "701100198", "701100204", "701100206", "701100212", "701100278",
        "701100280", "701100282", "701100284", "701100286", "701500000",
        "701500001", "709802016", "709802457", "709802585", "709802587",
        "709802594", "709802832", "709802833", "709802834", "709802836",
        "709802837", "709802838", "709802840", "709802906", "709803246",
        "709803250", "709803251", "709803252", "709803386", "709803398",
        "709803399", "709803422", "709803423", "709803424", "709803430",
        "709803431", "709803443", "709803444", "709803596", "709803598",
        "709803599", "709803600", "709803612", "709803752", "709803766",
        "709803783", "709803804", "709803805", "709803809", "709803812",
        "709803826", "709803827", "709803828", "709803859", "709803860",
        "709803861", "709803862", "709803863", "709803864", "709803903",
        "709803973", "709803988", "709803989", "709803990", "709803995",
        "709803996", "709803997", "709804000", "709804028", "709804035",
        "709804036", "709804037", "709804038", "709804039", "709804052",
        "709804095", "709804199", "709804218", "709804347", "709804348",
        "709804376", "709804406", "709804407", "709804422", "709804442",
        "709804443", "709804444", "709804466", "709804468", "709804543",
        "709804580", "709804581", "709804582", "709804594", "709804612",
        "709804613", "709804614", "709804639", "709804656", "709804659",
        "709804660", "709804673", "709804674", "709804675", "709804676",
        "709804677", "709804678", "709804679", "709804680", "709804681",
        "709804698", "709804699", "709804700", "709804789", "709804824",
        "LCFDR0608LB0", "LCFDR0609LB0", "LCFDR0610LB0", "LCFDR0710SB0", "LCFDR0814SB0",
        "LCFDR0814SG0", "LCFDR1012SB0", "LFDR0606LB0", "LFDR0608LB0", "LFDR0609LB0",
        "LFDR0610ISB0", "LFDR0710ISB0", "LFDR0710ISG0", "LFDR0710SB0", "LFDR0814SB0",
        "LFDR0814SG0", "LFDR0914ISG0", "LFDR1012SB0", "LFDR1012TG0", "LFDR1114ISG0",
        "LFDRI0710SB0", "LFJA0914SB0", "LFMA0709LB0", "LFMA0810SB0", "LFMA1014SB0",
        "LFMA1312SG0", "LPDR0665ILG", "LPDR0865ILG", "LPDR1165LG", "LPDR1165LG0",
        "LRDR56SB0", "LRDR57SB0", "LRJM56SB0", "LRPK56SB0", "LRPK57SB0",
        "LRSH56SB0", "LSCDR0805SB0", "LSCDR0805SG0", "LSCDR1006SG0", "LSCDR1106I",
        "LSCDR1208SG0", "LSCPK1106I", "LSDR0680TB0", "LSDR0680TS0", "LTDR0608PB0",
        "LTDR0610PB0", "LTDR0714PBI0", "LTDR0714PGI0", "LTDR0810PB0", "LTDR0810PI0",
        "LTDR67SB0", "LTDR79SB0", "LTDRI0714PB0", "LTDRI0714PG0", "PRIMMA5N",
        "SCPK07B", "SCPK07M", "SED090VBCL0", "SED090VGCL0",
      ],
      "REFR": [
        "DSP480LKRSS0", "DSP610IORSS0", "DTP458BKRSS0", "DTP469LKRSS0", "GEPS6FGKFSS",
        "HDR120F00B", "HDR120F00N", "HDR120F00S", "HDR280F00B", "HDR280F30PB",
        "HDR280F50B", "HDR280F50PB", "HDR300N00B", "HDR300N00M", "HDR300N30B",
        "HDR300N30M", "HDR320F00N", "HDR320F00S", "HDR320F50E", "HDR320F50N",
        "HDR320F50NE", "HDR320F50S", "HDR370F00B", "HDR370F00S", "HDR370F11S",
        "HDR370F50B", "HDR370F61E", "HDR370F61S", "HDR380N12M", "HDR380N12N",
        "HDR400F00B", "HDR400F00S", "HDR400F11N", "HDR400F11S", "HDR400F30B",
        "HDR400F30E", "HDR400F30S", "HDR400F41E", "HDR400F41N", "HDR400F41S",
        "HDR420N00B", "HDR420N00M", "HDR420N30B", "HDR420N30M", "HDR430N12M",
        "HDR430N42M", "HETOKMAGNA350", "HETOKMAGNA350N", "HETOKMAGNA360", "HGE455M12L",
        "HME280F00B", "HME320F00S", "HPK120P00B", "HPK120P00S", "HPK120P00S02",
        "HPK135B01", "HPK135B01-C", "HPK135M", "HPK135M00B01", "HPK135MA00B01",
        "HPK135P00B01", "HPK136M00N01", "HPK136M00S01", "HPK136S01", "HPK141M00B",
        "HPK141M10S", "HPK151M00B", "HPK151M11N01", "HPK151M11S", "HPK151M11S02",
        "HPK350M00B", "HPK350M00L", "HPK450M00B", "HPK450M00L", "HTH135M00B01",
        "JM350BLANCO", "MD-HFH340MK", "MD-HFH400MK", "MD-HFH400NG", "MD-HFHIN340MK",
        "PQP458BKRSS0", "RDA250FVRT", "RDA300FBRT", "RDA300FHRT", "RDP400FZRT",
        "RDP410ZRT", "RENX24281FHS", "RENX24281FHW", "RENX24301FHS", "RGA300FHRE",
        "RGS1951BGRX0", "RRS1540BGRX0", "RZB210PVARX0", "RZB520IJARX0", "RZD215PVARX0",
        "RZN320PCARX0", "RZS510IBARX0", "YEP26FGTFSS", "YRP26FGTFSS",
      ]
    }
  },
  "CEAM": {
    "CR": {
      "REFR": [
        "CFE28TP2MS1", "CFE28TP3MD1", "CFE28TP4MW2", "CWE19SP3ND9", "CWE23SP2MS1",
        "CWE23SP4MW2", "GNM26AEKFSS", "GNM26AETFSS", "HBM425EMNSS0", "HQM458BKNSS0",
        "HSM518HMNSS0", "HSM541HMNSS0", "MSM480LKLSS0", "MSM504SONBS0", "MSM544LMLSS0",
        "MSM631LKLNG0", "MSM631LKLSS0", "MSM746IOLFS0", "MSM746LIOLFS0", "MTM482SENSS0",
        "PDF21EYRCFS", "PDM21ESKCSS", "PFF25LYRCFS", "PFM25LSKCSS", "PNF25FYRCFS",
        "PNM22LETFSS", "PNM25FSKCSS", "PNM26PGKCSS", "PNM26PGLCPS", "PNM26PGTCFS",
        "PNM26PGTFPS", "RMA1230PVCAE", "RMA1230PVCAG1", "RMA1250FACAE", "RMA1250FJCAU",
        "RMA1250PJCAU", "RMA1250PVCAE", "RMA1300FHCAE", "RMA1300FXCAU", "RMA1300FYCAE",
        "RMA230PVCRE", "RMA230PVCRG1", "RMA230PVMRE1", "RMA230PVMRG1", "RMA250FAMRE1",
        "RMA250PJCRE", "RMA250PJCRU", "RMA300FBNG", "RMA300FXCRU", "RMA300FXNU",
        "RMA300FYCRE", "RMA300FYMRE0", "RMA300FYMRE1", "RMA300FZCRU", "RMA300FZMRX0",
        "RMA300FZNU", "RMB300IZMRP0", "RMB300IZMRX0", "RMB400IBMRP0", "RMB400IBMRX0",
        "RMB520IBMRP0", "RMB520IBMRP1", "RMB520IBMRX1", "RMC181PXCRB0", "RMC181PXCRX0",
        "RMC181PXMRX0", "RMC181PYMRX0", "RMD165PVCRB0", "RMD165PVCRS0", "RMP1400FJCAU",
        "RMP370GCAT", "RMP400FHCRU", "RMP400FJCRU", "RMP400FJNU", "RMP400FZNU",
        "RMP410FZNU", "RMP410JCAU", "RMP410ZCAU", "RMP420FYCRU", "RMP420FYNU",
        "RMP435FZNC", "RMP435FZNU", "RMP450ZCAU", "RMS1951AMXE0", "RMS400IAMRE0",
        "RMS400IAMRX0", "RMS400IBMRX0", "RMS510IAMRX0", "RMS510IBMRX0", "RMS510IXMRX0",
        "RMT510RXMRE0", "RMU210FANE", "RMU210FANU", "RTA230FVCRG0", "RTA230FVMRG0",
        "RTA250PJCRG", "RTA250PJNG", "RTA300FHMRE1", "RTA300FYCRE", "RTP400FJCRE",
        "RTP400FJNL", "RTU210NACAE", "RTU210NANB", "RTU210NANE", "RTU290NACRE",
        "RTU290NANE", "ZIF241NPNII", "ZIF361NPRII", "ZIR241NPNII", "ZIR301NPNII",
        "ZIR361NPRII", "ZISS420DNSS", "ZISS480DNSS", "ZWE23NSTSS",
      ],
      "LAVA": [
        "CHAC2186NXGG0", "CPA2412NXDG0", "DME17R8MSDBP1", "DME47N8MSDBP0", "GFD55ESSNWW",
        "GFW550SSNWW", "GFW850SPNRS", "LGA71215CBAB0", "LGA72214CBAB0", "LGA74215WBAB0",
        "LGA79113CBAB0", "LGH72201WBAB0", "LGH73201WBAB0", "LHA9120WGAB0", "LMA46102VBAB0",
        "LMA5120WPAB0", "LMA6120WDGAB0", "LMA70200WDAB1", "LMA70214CBAB0", "LMA70215WBAB0",
        "LMA72200WDAB0", "LMA72215CBAB0", "LMA72215WBAB0", "LMA74215WBAB1", "LMA74215WDAB0",
        "LMA74215WDAB1", "LMA76102CBAB0", "LMA77113CBAB0", "LMA78113CBAB0", "LMA79113VBAB0",
        "LMA8120WDGAB0", "LMC48100WDAB0", "LMD2200B0", "LMDX1123HBAB0", "LMDX2224HBAB0",
        "LMDX3123HBAB0", "LMDX6124HBAB0", "LMDX8124HBAB0", "LME79104VBAB0", "LME79104WBAB1",
        "LMH72201WBAB0", "LMH72201WBAB1", "LMH74201WDAB0", "LMH74201WDAB1", "LMP75201WDAB0",
        "LMP75205WDAB0", "LMX70214WDAB0", "MCL2040EPDG0", "MCL2040ESBB0", "MCL2040ESDG0",
        "MCL2040PSBB0", "MCL2040PSDG0", "MCL2440EPDG0", "MCL2440ESBB0", "MCL2440ESDG0",
        "MCL2440PSBB0", "MCL2440PSDG0", "PFD87ESPVRS", "PFW870SPVRS", "SGE47N5MSSBT0",
        "SGE47N5XNSBH0", "SGG47N5MSSAB0", "SGG47N5XNBAB0", "SME17R8MSBBP0", "SME17R8MSDBP0",
        "SME27N5MSBBP0", "SME47N8MSBBP0", "SME47N8MSBBT0", "SME47N8MSDBP0", "SME47N8MSDBT0",
        "SMG27N5MSBAB0", "SMG47N8MSBAB0",
      ],
      "GLOB": [
        "AFM38DN", "CCWK15C1WSS", "CCWK15C1WWM", "CDT828P2VS1", "CDT858P3VD1",
        "CDT875P4NW2", "CDT888P4VW2", "CEB515P2NSS", "CEB515P4NWM", "CHC11BPL5",
        "CHC11BPS0", "CHC15BPL4", "CHC25BPL2", "CHC5BPL40", "CHC5BPS1",
        "CHC7BPL30", "CHC7BPS1", "CHC9BPL3", "CHC9BPS1", "CHM11BPL4",
        "CHM11BPL5", "CHM11PHL0", "CHM15BPL4", "CHM15PHL0", "CHM25BPL1",
        "CHM25BPL2", "CHM25PGL0", "CHM5BPL3", "CHM5BPL40", "CHM5PPL0",
        "CHM7BPL2", "CHM7BPL30", "CHM7PPL0", "CHM9BPL4", "CHM9PPL0",
        "CVM517P2RS1", "EMM2PB", "EMM2PN", "GBF410SSPSS", "GBP655SSPSS",
        "GLV1460FSS", "GW8XDBB2", "HLV0845FSSS", "HMM07BJ", "HMM07PJB",
        "HMM07PJN", "HMM09NJ", "HMM114SEJ", "HMM70BS", "HMM70SEJ",
        "HMM70SW", "IO110MDI", "IO160MDI", "IO1702LI6", "IO1716LI0",
        "JES1153SFE", "JES11W", "JES14W", "JES70SE", "JES70W",
        "JVM3162RJSS", "MGE07SEJ", "MGE09SEJ", "MGE14XEJG", "MXCFS7CCSS",
        "PBT865SMPES", "PBT865SSPFS", "PCWK22U1WDD", "PEB110SFSS", "PEB160SFSS",
        "PEB7227ANDD", "PES7227SLSS", "PVM9215SKSS", "PW29BS3", "QDP225SSPSS",
        "RMF0260XMXB3", "RMF0260XMXX3", "RMF0411PYMB0", "RMF0411PYMX0", "UCC15NPRII",
        "VM2164LB0", "VM3164LB0", "ZCWK22U2WSS", "ZDT925SINII", "ZDT925SPNSS",
        "ZDT925SSNSS", "ZDWR240NBS", "ZIF301NBRII", "ZIF301NPNII",
      ],
      "COCC": [
        "C2S900P2MS1", "C2Y366P3TD1", "CA20TBX0", "CEP90302TSS", "CEP90361TBB",
        "CES700P2MS1", "CES700P4MW2", "CGP70302NS1", "CGP70362NS1", "CGP9019I6I",
        "CGP9019P6I", "CGP95302MS1", "CGS700P2MS1", "CGS700P4MW2", "CGU366P2TS1",
        "CM6045UIW0", "CM7618PIW0", "CM7645UGW0", "CM7645UIW0", "CM7645UNW0",
        "CM7648PIW0", "CMA3010AG0", "CMA3020FG0", "CMA3020FN0", "CMA3020FX0",
        "CMPU761GX0", "CMPU761NX0", "CMPUV601SSX0", "CMPUV761SSX0", "CTS70DP2NS1",
        "CTS90DP3ND1", "CTS90DP4NW2", "CTS90FP4NW2", "CVW73612MSS", "CVW73614MWM",
        "CVW93044PWM", "EAE5020BSS0", "EM5041BAIS0", "EM5041BAIS1", "EM5043BFIS1",
        "EM5060CFIX0", "EM6032CAIS0", "EM6038CFIX0", "EM7622BAPS2", "EM7641BAIS1",
        "EM7655CSIN0", "EM7657CSIS1", "EM7659BFIX0", "EM7659BFIX2", "EM7660CFIX2",
        "EM7660CFIX3", "EM7690CFIX2", "EMA5105SN0", "EMA5105SN1", "EMA5110SG0",
        "EMA5110SG1", "EMA5130FX0", "EMA6030AG0", "EMA6030SG1", "EME5025BSS0",
        "EME5040BVS0", "EME6063BVX0", "EME7620BSFL0", "EMH7602DSS0", "EMH7602JBS0",
        "EMH7602JS0", "EMH7602JSS0", "EMH7613DATSS0", "EMH7613DTSS0", "EMH7614DATBS0",
        "EMH7614DATMSS0", "EMH7614DATSS0", "HGP6065EWAI0", "HGP6065EWAI1", "HGP8050KE0",
        "HGP8050YE1", "HM6021EWAI0", "HM6031EUAI0", "IO6040EVN0", "IO6056HEWI1",
        "IO6056HGWI1", "IO6065HEYR0", "IO64TI0", "IO75TI0", "IO7650EVN0",
        "IO7686SS0", "IO7690ESS0", "IO8042HEYD0", "IO8042HEYD1", "IO9014ICSSS0",
        "IO96TI0", "JBS360RRSS", "JBS360RTSS", "JCB810SKSS", "JCB820SKSS",
        "JCB830SKSS", "JCB830STSS", "JCB840SKSS", "JCB840STSS", "JCB870STSS",
        "JCBS630SVSS", "JCBS631SFSS", "JGB735SPSS", "JGBS66REKSS", "JP3030SWSS",
        "JTS3000SNSS", "JTS5000SNSS", "JTS5000SVSS", "P2S930YPFS", "PGP75KMTI0",
        "PGP75TI0", "PGP95EBG0", "PGP95KBG0", "PGP95KMNN0", "PIP8014",
        "PM302I0", "PM6040EVN0", "PM6044PF0", "PM64IV0", "PMI6055PF0",
        "PP7030SJSS", "PP930SMSS1", "PP936SMSS1", "PTS7000SNSS", "UVC9480SLSS",
        "WEM5044CAIB0", "WEM7643CAIS1", "ZDP366NTSS", "ZDP484NGTSS", "ZDP486NDTSS",
        "ZGP366NTSS", "ZGU364NDTSS", "ZGU366NTSS", "ZGU36ESLSS", "ZHU30RDTBB",
        "ZHU30RSTSS", "ZHU36RSTSS", "ZSB9231NSS", "ZSB9232VSS", "ZTS90DPSNSS",
        "ZTS90DSSNSS", "ZVW1480SPSS",
      ],
      "CALE": [
        "CDM40SLP", "CDM80SLP", "CIM062SLP", "CIM102SLP", "CIM11KWCA2SSE",
        "CIM142SLP", "CIM15KWCA2SSE", "CMM11M1FSLP", "CMM16M1FSLP", "CRM06SLP",
        "CRM09SLP",
      ],
      "AIAC": [
        "HS12HFW13MI", "HS18HFB13MI", "HS18HFW13MI", "HS24HFW13MI", "MMI12CABWCC32M1",
        "MMI12CABWCC6M9", "MMI12CDBWCC32M1", "MMI12CDBWCC6M8", "MMI12CDBWCC6M9", "MMI18CDBWCC32M1",
        "MMI18CDBWCC6M8", "MMI24CDBWCC32M1", "MMI24CDBWCC6M8", "MMT12CDBWCCM2", "MMT12CDBWCCTM1",
        "MMT18CDBWCCM1", "MMT18CDBWCCTM1", "PTM12CABWJM2",
      ]
    },
    "GT": {
      "REFR": [
        "CFE26KP2NS1", "CFE28TP2MS1", "CFE28TP4MW2", "CWE23SP4MW2", "GNM22AETFSS",
        "GNM26AEKFES", "GNM26AEKFSS", "GNM26AETFSS", "HBM425EMNSS0", "HQM458BKNSS0",
        "HSM541HMNSS0", "IOM510MZMRN0", "MSM480LKLSS0", "MSM504SONBS0", "MSM544LMLSS0",
        "MSM631LKLNG0", "MSM631LKLSS0", "MSM746IOLFS0", "MSM746LIOLFS0", "MTM482SENSS0",
        "ONM23WKZGS", "PDF21EYRCFS", "PDM21ESKCSS", "PFF25LYRCFS", "PFM25LSKCSS",
        "PNF25FYRCFS", "PNM22LETFSS", "PNM26PGKCSS", "PNM26PGTCFS", "PNM26PGTFPS",
        "RCC300OVCAE", "RCC300OVNB", "RCC300OVNE", "RCC390OVCAE", "RCC390OVNB",
        "RCC390OVNE", "RMA1230PVCAE", "RMA1230PVCAG1", "RMA1250PJCAG", "RMA1250PJCAU",
        "RMA1250PVCAE", "RMA1300FHCAE", "RMA1300FHCAU", "RMA1300FJCAU", "RMA1300FXCAC",
        "RMA1300FXCAU", "RMA1300FZCAC", "RMA1300FZCAU", "RMA230PVMRE1", "RMA230PVMRG1",
        "RMA250FAMRE1", "RMA250FJMRU1", "RMA250FXMRE0", "RMA250PJMRU1", "RMA250PJNG",
        "RMA300FBNG", "RMA300FHMRE1", "RMA300FHNU", "RMA300FJMRQ0", "RMA300FJMRX0",
        "RMA300FJNU", "RMA300FXNC", "RMA300FXNU", "RMA300FZNC", "RMA300FZNU",
        "RMB300IZMRP0", "RMB300IZMRX0", "RMB400IBMRP0", "RMB400IBMRX0", "RMB520IBMRP1",
        "RMB520IBMRX1", "RMC181PXCRB0", "RMC181PXCRX0", "RMC320FVCAE", "RMC320FVCAG",
        "RMC320FVNE", "RMC320FVNG", "RMC400FVCAE", "RMC400FVCAG", "RMC400FVNB",
        "RMC400FVNE", "RMC400FVNG", "RMD165PVCRB0", "RMD165PVCRS0", "RME360FGMRE0",
        "RME360PVMRE0", "RMN207PVCRX0", "RMN240PVRRX0", "RMP1400FHCAE", "RMP1400FJCAU",
        "RMP370GCAT", "RMP400FHNE", "RMP400FHNU", "RMP400FJNU", "RMP400FLNU",
        "RMP400FZNC", "RMP400FZNU", "RMP410FZNC", "RMP410FZNU", "RMP410HCAT",
        "RMP410HCAU", "RMP410JCAU", "RMP410ZCAU", "RMP420FYCRU", "RMP420FYNU",
        "RMP430FZNC", "RMP430FZNU", "RMP435FZNC", "RMP435FZNU", "RMP450DCAG",
        "RMP450YCAU", "RMP450ZCAC", "RMP450ZCAU", "RMS400IAMRE0", "RMS400IAMRX0",
        "RMS400IVMRE0", "RMS510IAMRE0", "RMS510IAMRX0", "RMS510IBMRX0", "RMS510IVMRE0",
        "RMS510IXMRX0", "RMT400RYMRE0", "RMT510RXMRE0", "RMT510RYMRE0", "RMU1290FACAE",
        "RMU210FANE", "RMU210FANU", "RMU235FANE", "RMU290FANE", "RTA300FYMRE0",
        "ZIF361NPRII", "ZIR361NPRII", "ZISS480DNSS",
      ],
      "LAVA": [
        "CHAC2186NXGG0", "CPA2412NXDG0", "DME17R8MSDBP1", "DME47N8MSDBP0", "GFD55ESSNWW",
        "GFW550SSNWW", "LGA71215CBAB0", "LGA74215WBAB0", "LGA79113CBAB0", "LGH73201WBAB0",
        "LHA9120WGAB0", "LMA4120WDGAB0", "LMA46102VBAB0", "LMA5120WPAB0", "LMA70200WBAB1",
        "LMA70200WDAB1", "LMA70200WGAB0", "LMA70214CBAB0", "LMA70214VBAB0", "LMA70215WBAB0",
        "LMA71214VBAB0", "LMA72215CBAB0", "LMA72215WBAB1", "LMA74215WBAB1", "LMA74215WDAB1",
        "LMA76102CBAB0", "LMA77113CBAB0", "LMA78113CBAB0", "LMA79113VBAB0", "LMA79114CBAK0",
        "LMA8120WDGAB0", "LMC46100WDAB0", "LMDX2224HBAB0", "LME79104VBAB0", "LME79104WBAB1",
        "LMH70211WBAB0", "LMH72201WBAB0", "LMH72201WBAB1", "LMH72205SBAB0", "LMH72205WBAB0",
        "LMH72205WDAB0", "LMH72211WDAB0", "LMH74201WDAB0", "LMH74201WDAB1", "LMP75201WDAB0",
        "LMP75205WDAB0", "LMX70214WDAB0", "MCL2040EPDG0", "MCL2040ESBB0", "MCL2040ESDG0",
        "MCL2040PPDG1", "MCL2040PSBB0", "MCL2440EPDG0", "MCL2440ESBB0", "MCL2440ESDG0",
        "MCL2440PSDG0", "SGE47N5MSSBT0", "SGE47N5XNSBH0", "SGE47N5XSBBH0", "SGE47N8MSSBT0",
        "SME17R8MSBBP0", "SME17R8MSDBP0", "SME26N5MNBBP0", "SME47N8MSBBP0", "SME47N8MSBBT0",
        "SME47N8MSDBP0", "SME47N8MSDBT0", "SMG17R8MSDAB0", "SMG26N5MNBAB0", "SMG47N8MSBAB0",
        "SMG47N8MSDAB0",
      ],
      "GLOB": [
        "AFM38DN", "ALASKAVIT416CEG", "CCWK15C1WSS", "CDT805P2NS1", "CDT828P2VS1",
        "CDT875P4NW2", "CDT888P4VW2", "CEB515P4NWM", "CHC11BPL5", "CHC11BPS0",
        "CHC15BPL4", "CHC25BPL2", "CHC5BPL40", "CHC5BPS1", "CHC7BPL30",
        "CHC7BPS1", "CHC9BPL3", "CHC9BPS1", "CHM11BPL3", "CHM11BPL4",
        "CHM11BPL5", "CHM11PHL0", "CHM15BPL4", "CHM15PHL0", "CHM25BPL1",
        "CHM25BPL2", "CHM25PGL0", "CHM5BPL40", "CHM5PPL0", "CHM7BPL2",
        "CHM7BPL30", "CHM7BPS1", "CHM7PPL0", "CHM9BPL4", "CHM9PPL0",
        "EMDPCCB3", "EMM2PB", "EMM2PN", "FCM5FSWH", "GBF410SSPSS",
        "GBF412SSMSSX", "GBP655SSPSS", "GLV1460FSS", "GW8XDBB2", "HLV0845FSSS",
        "HMM07BJ", "HMM07PJB", "HMM07PJN", "HMM09NJ", "HMM111BS",
        "HMM11XEB", "HMM700WK", "HMM70SEJ", "IO110MDI", "IO160MDI",
        "IO1702LI6", "IO1716LI0", "JVM3162RJSS", "MGE07SEJ", "MGE09SEJ",
        "MGE11SEJ", "MXCBL01D", "MXCFS7CCSS", "PBT865SMPES", "PBT865SSPFS",
        "PCWK22U1WDD", "PEB110SFSS", "PEB160SFSS", "PEB7227ANDD", "PW29BS3",
        "QDP225SSPSS", "RMF0260XMXB3", "RMF0260XMXX3", "RMF0411PYMB0", "RMF0411PYMX0",
        "UCC15NPRII", "VC2164LB0", "VC3164LB0", "VM2164LB0", "VM3164LB0",
        "ZDBR240NBS", "ZDT925SINII", "ZDT925SPNSS", "ZDWR240NBS", "ZEB1227SLSS",
        "ZIDS240NSS", "ZIFS240NSS",
      ],
      "COCC": [
        "C2S900P2MS1", "C2Y366P4TW2", "CC20CGX0", "CC20TBX0", "CEM7641BSIS2",
        "CEM7650BSIN3", "CEP90361TBB", "CES700P4MW2", "CGP9019I6I", "CGP9019P6I",
        "CGS700P4MW2", "CGU366P2TS1", "CGU486P2TS1", "CM6045UIW0", "CM7618PIW0",
        "CM7641B", "CM7645UGW0", "CM7645UIW0", "CM7645UNW0", "CM7648PIW0",
        "CMA3020FG1", "CMPU761GX0", "CMPU761NX0", "CMPUV601SSX0", "CMPUV761SSX0",
        "CTS70DP2NS1", "CTS90DP4NW2", "CTS90FP4NW2", "CVW73614MWM", "EC2040DBAIS0",
        "EC3030BAPB2", "EC3030BAPN2", "EC3040BSIF1", "EC7660CFIX0", "ECG5100BIB0",
        "EM5022DBAPN0", "EM5030BFIS0", "EM5032BAPS0", "EM5032BAPS1", "EM5035CFIS0",
        "EM5035CSIS1", "EM5041BAIS1", "EM5041BFIS0", "EM5043BFIS0", "EM5043BFIS1",
        "EM5046CAIX0", "EM5046CAIX1", "EM6032CAIS0", "EM6038CFIX0", "EM7620BAIS2",
        "EM7620BAPN2", "EM7622BAPS1", "EM7622BAPS2", "EM7641BAIB1", "EM7641BAIS2",
        "EM7655CSIN0", "EM7655CSIN1", "EM7658BFIN3", "EM7659BFIS1", "EM7659BFIS3",
        "EM7659BFIX0", "EM7659BFIX2", "EM7674CFIS0", "EM7690CFIX2", "EMA5105SN0",
        "EMA5105SN1", "EMA5110SG0", "EMA5110SG1", "EMA5120SG0", "EMA5120SG1",
        "EMA5130FX0", "EMA5130FX1", "EMA6030SG0", "EMA6030SG1", "EME5025BSB0",
        "EMH7602DSS0", "EMH7602JBS0", "EMH7602JS0", "EMH7602JSS0", "EMH7612DSS0",
        "EMH7612DTSS0", "EMH7612JS0", "EMH7613DATSS0", "EMH7613DBS0", "EMH7613DTSS0",
        "EMH7614DATMSX0", "EMH7614DATSS0", "EMH7616DATMSX0", "HGP6065EWAI1", "HGP8050YE1",
        "HM6021EWAI0", "HM6031EUAI0", "IO6014ICSSS0", "IO6032HEWD0", "IO6040EVN0",
        "IO6056HEWI0", "IO6056HEWI1", "IO6065HEYR1", "IO64TI0", "IO7017CP3I",
        "IO75TI0", "IO7618P2DS", "IO7650EVN0", "IO7680ESS0", "IO7686FES0",
        "IO7686SS0", "IO7686SSC0", "JBS360RTSS", "JCB810SKSS", "JCB820SKSS",
        "JCB840SKSS", "JCBS630SVSS", "JCBS631SFSS", "JGB735SPSS", "JGBS61RPSS",
        "JGBS66REKSS", "JTS3000SNSS", "JTS5000SNSS", "JTS5000SVSS", "P2S930YPFS",
        "PGP75KMTI0", "PGP75TI0", "PGP95KMNN0", "PIO75KMTI0", "PIP8014",
        "PM302I0", "PM6040EVN0", "PM6044PF0", "PM64IV0", "PMI6055PF0",
        "PP930SMSS1", "PP936SMSS1", "PTS7000SNSS", "QCGSS740RNSS", "QCSS740RNSS",
        "UVC9480SLSS", "UVW93642PSS", "WEM7643CAIS1", "WEM7643CSIS0", "WEM7659CFIS3",
        "ZDP366NTSS", "ZDP486NDTSS", "ZGU30RSLSS", "ZGU366NTSS", "ZHU30RSTSS",
        "ZHU36RSTSS", "ZSB9232VSS", "ZTS90DPSNSS", "ZTSX1FPSNSS", "ZVW1480SPSS",
      ],
      "CALE": [
        "CDM40SLP", "CDM80SLP", "CIM062SLP", "CIM102SLP", "CIM11KWCA2SSE",
        "CIM142SLP", "CIM15KWCA2SSE", "CMM11M1FSLP", "CMM16M1FSLP", "CRM06SLP",
        "CRM09SLP",
      ],
      "AIAC": [
        "HS12HFW13MI", "MCI12CABWCCAX9", "MMI12CABWCC32M1", "MMI12CABWCC6M8", "MMI12CABWCC6M9",
        "MMI12CABWCCAX8", "MMI12CDBWCC32M1", "MMI18CDBWCC32M1", "MMI18CDBWCC6M8", "MMI18CDMCCM8",
        "MMI24CDBWCC32M1", "MMI24CDBWCC6M8", "MMI36HDBWCAAXM8", "MMT12CABWCCM2", "MMT12CABWCCTM1",
        "MMT12CDBWCCM2", "MMT12CDBWCCTM1", "MMT18CDBWCC32BC1", "MMT18CDBWCCM1", "MMT24CDBWCCM1",
        "PTM12CABWJM2",
      ]
    },
    "HN": {
      "REFR": [
        "GNM26AETFSS", "HBM425EMNSS0", "HQM458BKNSS0", "HSM518HMNSS0", "HSM541HMNSS0",
        "MSM504SONBS0", "MSM521HKNSS0", "MSM544LMLSS0", "MSM631LKLNG0", "MSM631LKLSS0",
        "MSM746IOLFS0", "MSM746LIOLFS0", "MTM482SENSS0", "ONM23WGTHFS", "PDF21EYRCFS",
        "PFF25LYRCFS", "PNF25FYRCFS", "PNM22LETFSS", "PNM26PGTCFS", "PNM26PGTFPS",
        "RCA1250OVCAE", "RCA230OVMRE1", "RCA250OVMRE1", "RCC300OVNE", "RCC390OVCAE",
        "RCC390OVNB", "RCC390OVNE", "RCU210NUNE", "RCU235TUNS", "RCU290TVNE",
        "RMA1230PVCAE", "RMA1230PVCAG1", "RMA1250FACAE", "RMA1250FJCAU", "RMA1250PJCAG",
        "RMA1250PJCAU", "RMA1250PVCAE", "RMA1300FHCAE", "RMA1300FHCAU", "RMA1300FJCAU",
        "RMA1300FXCAC", "RMA1300FXCAU", "RMA1300FYCAE", "RMA1300FZCAC", "RMA1300FZCAU",
        "RMA230PVMRE1", "RMA230PVMRG1", "RMA250FAMRE1", "RMA250FJMRU1", "RMA250FYMRE0",
        "RMA250PJMRU1", "RMA250PJNG", "RMA300FHMRE1", "RMA300FHNU", "RMA300FJMRQ0",
        "RMA300FJNU", "RMA300FXNC", "RMA300FXNU", "RMA300FYMRE1", "RMA300FZNC",
        "RMA300FZNU", "RMB300IZMRP0", "RMB300IZMRX0", "RMB400IBMRP0", "RMB400IBMRX0",
        "RMB520IBMRP1", "RMB520IBMRX0", "RMB520IBMRX1", "RMC181PXCRB0", "RMC181PXCRX0",
        "RMC320FVCAE", "RMC320FVNE", "RMC400FVCAE", "RMC400FVCAG", "RMC400FVNE",
        "RMD165PVCRB0", "RMD165PVCRS0", "RMN207PVCRX0", "RMN240PVRRX0", "RMP1400FHCAU",
        "RMP1400FJCAU", "RMP370GCAT", "RMP400FJNU", "RMP400FLNU", "RMP400FZNC",
        "RMP400FZNU", "RMP410FZNC", "RMP410FZNU", "RMP410HCAU", "RMP410JCAU",
        "RMP410ZCAU", "RMP420FYCRU", "RMP420FYNU", "RMP430FZNC", "RMP435FZNC",
        "RMP435FZNU", "RMP450DCAG", "RMP450YCAU", "RMP450ZCAU", "RMS400IAMRM0",
        "RMS400IAMRX0", "RMS400IBMRX0", "RMS400IVMRM0", "RMS510IAMRX0", "RMS510IBMRX0",
        "RMS510IXMRX0", "RMT510RXMRE0", "RMU1290FACAE", "RMU210FANE", "RMU210FANU",
        "RMU210NANG", "RMU235FANE",
      ],
      "LAVA": [
        "CHAC2186NXGG0", "DME17R8MSDBP1", "DME47N8MSDBP0", "LGA71215CBAB0", "LGA72214CBAB0",
        "LGA74215WBAB0", "LGA79113CBAB0", "LGH73201WBAB0", "LHA9120WGAB0", "LMA4120WDGAB0",
        "LMA46102VBAB0", "LMA5120WPAB0", "LMA70213CBAB0", "LMA70214CBAB0", "LMA71214VBAB0",
        "LMA71215WBAB0", "LMA72200WDAB0", "LMA72215CBAB0", "LMA72215WBAB1", "LMA74215WBAB1",
        "LMA76102CBAB0", "LMA77113CBAB0", "LMA78113CBAB0", "LMA79113VBAB0", "LMA79114CBAK0",
        "LMA8120WDGAB0", "LMDX2224HBAB0", "LMH72201WBAB1", "LMH72205WBAB0", "LMH74201WDAB1",
        "LMP75201WDAB0", "LMP75205WDAB0", "MCL2040EPDG0", "MCL2040ESBB0", "MCL2040ESDG0",
        "MCL2040PSBB0", "MCL2440ESBB0", "MCL2440ESDG0", "MCL2440PSBB0", "SGE47N5MSSBT0",
        "SGE47N5XNSBH0", "SGG47N5XNBAB0", "SME26N5MNBBP0", "SME26N5MNBBT0", "SME47N8MSBBP0",
        "SME47N8MSBBT0", "SMG26N5MNBAB0",
      ],
      "GLOB": [
        "AFM38DN", "ALASKAVIT416CEG", "CHC11BPL5", "CHC11BPS0", "CHC15BPL4",
        "CHC25BPL2", "CHC5BPL40", "CHC5BPS1", "CHC7BPL30", "CHC7BPS1",
        "CHC9BPL3", "CHC9BPS1", "CHM11BPL5", "CHM11PHL0", "CHM15BPL3",
        "CHM15BPL4", "CHM15PHL0", "CHM25BPL1", "CHM25BPL2", "CHM25PGL0",
        "CHM5BPL3", "CHM5BPL40", "CHM5PPL0", "CHM7BPL2", "CHM7BPL30",
        "CHM7PPL0", "CHM9BPL4", "CHM9PPL0", "EMDPCCB3", "EMM2PB",
        "EMM2PN", "GBF410SSPSS", "GLV1460FSS", "HLV0845FSSS", "HMM07PJB",
        "HMM07PJN", "HMM09NJ", "HMM111BS", "HMM700WK", "IO110MDI",
        "IO1702LI6", "JES11W", "JES70SE", "JES70W", "JVM3162RJSS",
        "MGE07SEJ", "MGE09SEJ", "MGE11SEJ", "MXCFS7CCSS", "PEB160SFSS",
        "PW29BS3", "QDP225SSPSS", "RMF0260XMXB3", "RMF0260XMXX3", "RMF0411PYMB0",
        "RMF0411PYMX0", "VM2164LB0", "VM3164LB0",
      ],
      "COCC": [
        "CC20CGX0", "CC20TBX0", "CG9014P3I", "CM6045UIW0", "CM7618PIW0",
        "CM7645UGW0", "CM7645UIW0", "CM7645UNW0", "CMA3020FG1", "CMPU761GX0",
        "CMPUV601SSX0", "CMPUV761SSX0", "EC3030BAPB2", "ECG5100FN0", "EM5032BAPS1",
        "EM5035CFIS0", "EM5043BFIS1", "EM6038CFIX0", "EM7620BAIS2", "EM7620BAPN2",
        "EM7622BAPS2", "EM7641BAIN2", "EM7641BAIS2", "EM7655CSIN1", "EM7659BFIX0",
        "EM7659BFIX2", "EMA5105SB0", "EMA5105SN0", "EMA5105SN1", "EMA5110SG0",
        "EMA5110SG1", "EMA5120SG0", "EMA5120SG1", "EMA5130FX0", "EMA5130FX1",
        "EMA6030AG1", "EME5025BSB0", "EME5025BSS0", "EME5030BES0", "EME5030BES1",
        "EME6063BVX0", "EME7620BSFL0", "EME7630BEB1", "EME7630BEFL0", "EME7630BESL1",
        "EMH7602DSS0", "EMH7602JBS0", "EMH7602JS0", "EMH7602JSS0", "EMH7612JS0",
        "EMH7613DTSS0", "EMH7614DATBS0", "EMH7614DATMSS0", "EMH7614DATSS0", "HGP6065EWAI0",
        "HGP8050YE1", "HM6031EUAI0", "IO6040EVN0", "IO6056HEWI1", "IO64TI0",
        "IO75TI0", "IO7650EVN0", "IO7686SS0", "JBS360DMWW", "JBS360RTSS",
        "JCB810SKSS", "JCB820SKSS", "JCB830STSS", "JCB840STSS", "JCB870STSS",
        "JCBS630SVSS", "JCBS631SFSS", "JGB735SPSS", "JGBS66REKSS", "JTS5000SVSS",
        "PGP64KRTI0", "PGP64TI0", "PGP75KMTI0", "PGP75TI0", "PM302I0",
        "PM6040EVN0", "PM64IV0", "PP930SMSS1", "PP936SMSS1", "QCGSS740RNSS",
        "WEM7643CFIS0", "WEM7643CSIS0", "WEM7659CFIS3", "WEM7661CFIX2",
      ],
      "CALE": [
        "CIM11KWCA2SSE", "CIM15KWCA2SSE",
      ],
      "AIAC": [
        "HS12HFW13MI", "HS18HFB13MI", "HS18HFW13MI", "HS24HFW13MI", "MMI12CDBWCC32M1",
        "MMI12CDBWCC6M9", "MMI12CDBWCCTM1", "MMI18CDBWCC32M1", "MMI18CDBWCC6M8", "MMI18CDBWCCTM1",
        "MMI24CDBWCC6M8", "MMI24CDBWCCTM1", "MMT12CDBWCCM2", "MMT12CDBWCCTM1", "MMT18CDBWCCM1",
        "MMT18CDBWCCTM1", "MMT24CDBWCCM1", "MMT24CDBWCCTM1", "PTM12CABWJM2",
      ]
    },
    "SV": {
      "REFR": [
        "CFE28TP2MS1", "CFE28TP3MD1", "CFE28TP4MW2", "CWE23SP4MW2", "GNM26AETFSS",
        "HBM425EMNSS0", "HFM410LPLSS0", "HQM458BKNSS0", "HSM541HMNSS0", "HTM507JMLSS0",
        "IOM510MZMRN0", "MSM480LKLSS0", "MSM504SONBS0", "MSM544LMLSS0", "MSM631LKLNG0",
        "MSM631LKLSS0", "MSM746IOLFS0", "MSM746LIOLFS0", "MTM482SENSS0", "ONM23WGTHFS",
        "PDF21EYRCFS", "PDM21ESKCSS", "PFF25LYRCFS", "PNF25FYRCFS", "PNM22LETFSS",
        "PNM26PGTCFS", "PNM26PGTFPS", "RCC300OVCAE", "RCC300OVNE", "RCC390OVCAE",
        "RCC390OVNB", "RCC390OVNE", "RMA1230PVCAG1", "RMA1250PJCAG", "RMA1250PJCAU",
        "RMA1250PVCAE", "RMA1300FHCAE", "RMA1300FHCAU", "RMA1300FJCAU", "RMA1300FXCAC",
        "RMA1300FXCAU", "RMA1300FYCAE", "RMA1300FZCAU", "RMA230PVMRG1", "RMA250FAMRE1",
        "RMA250FJMRU1", "RMA250PJMRU1", "RMA250PJNG", "RMA300FBNG", "RMA300FHMRE1",
        "RMA300FHNU", "RMA300FJMRD0", "RMA300FJMRQ0", "RMA300FJNU", "RMA300FXNC",
        "RMA300FXNU", "RMA300FZNC", "RMA300FZNU", "RMB300IZMRP0", "RMB300IZMRX0",
        "RMB400IBMRP0", "RMB400IBMRX0", "RMB520IBMRX1", "RMC181PXCRB0", "RMC181PXCRX0",
        "RMC320FVCAE", "RMC320FVNE", "RMC400FVCAE", "RMC400FVNE", "RMD165PVCRB0",
        "RMD165PVCRS0", "RME360FZMRP0", "RMN207PVCRX0", "RMN240PVRRX0", "RMP1400FHCAU",
        "RMP1400FJCAU", "RMP370GCAT", "RMP400FHNU", "RMP400FJNU", "RMP400FZNC",
        "RMP400FZNU", "RMP410FZNC", "RMP410FZNU", "RMP410HCAT", "RMP410HCAU",
        "RMP410JCAU", "RMP410ZCAU", "RMP420FDNG", "RMP420FYCRU", "RMP420FYNU",
        "RMP435FZNC", "RMP435FZNU", "RMP450ZCAC", "RMP450ZCAU", "RMS400IAMRE0",
        "RMS400IAMRX0", "RMS510IAMRX0", "RMS510IBMRX0", "RMS510IXMRX0", "RMU1290FACAE",
        "RMU210FANE", "RMU210FANU", "RMU235FANE", "RMU290FANE", "ZICS360NNLH",
        "ZICS360NNRH", "ZIF361NPRII", "ZISS480DNSS",
      ],
      "LAVA": [
        "CHAC2186NXGG0", "DME17R8MSDBP1", "DME47N8MSDBP0", "GFD55ESSNWW", "GFW550SSNWW",
        "LGA71215CBAB0", "LGA72214CBAB0", "LGA74215WBAB0", "LGA79113CBAB0", "LGH73201WBAB0",
        "LHA9120WGAB0", "LMA4120WDGAB0", "LMA46102VBAB0", "LMA5120WPAB0", "LMA6120WDGAB0",
        "LMA70214CBAB0", "LMA72200WDAB0", "LMA72215CBAB0", "LMA72215WBAB1", "LMA74215WBAB1",
        "LMA74215WDAB1", "LMA76102CBAB0", "LMA77113CBAB0", "LMA78113CBAB0", "LMA79113VBAB0",
        "LMA8120WDGAB0", "LMDX2224HBAB0", "LME79104VBAB0", "LMH72205WBAB0", "LMH74201WDAB1",
        "LMP75201WDAB0", "LMP75205WDAB0", "MCL2040ESBB0", "MCL2040ESDG0", "MCL2440ESBB0",
        "MCL2440ESDG0", "PFD87ESPVRS", "PFW870SPVRS", "SGE47N5MSSBT0", "SGE47N5XNSBH0",
        "SME17R8MSBBP0", "SME17R8MSDBP0", "SME26N5MNBBP0", "SME26N5MNBBT0", "SME47N8MSBBP0",
        "SME47N8MSBBT0", "SMG26N5MNBAB0",
      ],
      "GLOB": [
        "AFM38DN", "ALASKAVIT416CEG", "CCWK15C1WSS", "CDT828P2VS1", "CDT875P4NW2",
        "CEB515P2NSS", "CEB515P4NWM", "CHC11BPL5", "CHC11BPS0", "CHC15BPL4",
        "CHC25BPL2", "CHC5BPL40", "CHC5BPS1", "CHC7BPL30", "CHC7BPS1",
        "CHC9BPL3", "CHC9BPS1", "CHM11BPL5", "CHM11PHL0", "CHM15BPL4",
        "CHM15PHL0", "CHM25BPL1", "CHM25BPL2", "CHM25PGL0", "CHM5BPL3",
        "CHM5BPL40", "CHM5PPL0", "CHM7BPL2", "CHM7BPL30", "CHM7PPL0",
        "CHM9BPL4", "CHM9PPL0", "CK1UP150RS1", "CVM517P2RS1", "EMDPCCB3",
        "EMM2PB", "EMM2PN", "GBF410SSPSS", "GBP655SSPSS", "GLV1460FSS",
        "HLV0845FSSS", "HMM07PJB", "HMM07PJN", "HMM09NJ", "HMM700WK",
        "IO110MDI", "IO110MDI1", "IO160MDI", "IO1702LI6", "JES11W",
        "JES14W", "JES70SE", "JES70W", "JVM3162RJSS", "MGE07SEJ",
        "MGE09SEJ", "MGE11SEJ", "MXCFS7CCSS", "PBT865SMPES", "PBT865SSPFS",
        "PCWK22U1WDD", "PEB110SFSS", "PEB160SFSS", "PEB7227ANDD", "PLV1817XSS",
        "PVM9215SKSS", "PW29BS3", "QDP225SSPSS", "RMF0260XMXB3", "RMF0260XMXX3",
        "RMF0411PYMB0", "RMF0411PYMX0", "UCC15NPRII", "VM2164LB0", "VM3164LB0",
        "ZCWK22U2WSS", "ZDT925SPNSS", "ZEB1227SLSS",
      ],
      "COCC": [
        "C2S900P2MS1", "CC20TBX0", "CEP90361TBB", "CES700P2MS1", "CGP70302NS1",
        "CGP70362NS1", "CGP9019I6I", "CGP9019P6I", "CGS700P2MS1", "CGS700P4MW2",
        "CGU366P2TS1", "CM5021N", "CM6045UIW0", "CM7618PIW0", "CM7645UGW0",
        "CM7645UIW0", "CM7645UNW0", "CMPU761GX0", "CMPU761NX0", "CMPUV601SSX0",
        "CMPUV761SSX0", "CTS70DP2NS1", "CTS90FP2NS1", "CVW73612MSS", "EC3040BSIF1",
        "EM5022DBAPN0", "EM5032BAPS1", "EM5043BFIS1", "EM6038CFIX0", "EM7622BAPS1",
        "EM7622BAPS2", "EM7641BAIS2", "EM7655CSIN0", "EM7655CSIN1", "EM7658BFIN2",
        "EM7658BFIN3", "EM7659BFIX0", "EM7659BFIX2", "EMA5105SN0", "EMA5105SN1",
        "EMA5110SG0", "EMA5110SG1", "EMA5130FX0", "EMA5130FX1", "EMA6030FX0",
        "EMA6030FX1", "EMA6030SG0", "EMA6030SG1", "EME6063BVX0", "EMH7602DSS0",
        "EMH7602JBS0", "EMH7602JS0", "EMH7602JSS0", "EMH7613DTSS0", "HGP6065EWAI0",
        "HGP6065EWAI1", "HGP8050K0", "HGP8050YE1", "HM6021EWAI0", "HM6031EUAI0",
        "IO312DVI0", "IO6014ICSSS0", "IO6032HEWD0", "IO6040EVN0", "IO6056HEWI0",
        "IO6056HEWI1", "IO614PVI0", "IO64BG0", "IO64TI0", "IO75TI0",
        "IO7650EVN0", "IO7686SS0", "IO8042HEYD0", "IO8042HEYD1", "IO9014ICSSS0",
        "IO9017CP3I", "IO96TI0", "JCB810SKSS", "JCB820SKSS", "JCB840STSS",
        "JCBS631SFSS", "JGB735SPSS", "JGBS66REKSS", "JTS3000SNSS", "JTS5000SVSS",
        "P2S930YPFS", "PGP64TI0", "PGP75KMTI0", "PGP75TI0", "PGP95KMNN0",
        "PIO64KRTI0", "PIO75KMTI0", "PIP8014", "PM302I0", "PM6040EVN0",
        "PM64IV0", "PMI6055PF0", "PP930SMSS1", "PP936SMSS1", "QCGSS740RNSS",
        "QCSS740RNSS", "UVW93642PSS", "WDP8000K0", "WEM7659CFIS3", "ZGU366NTSS",
        "ZGU36ESLSS", "ZTS90DPSNSS", "ZVW1480SPSS",
      ],
      "CALE": [
        "CIM11KWCA2SSE", "CIM15KWCA2SSE",
      ],
      "AIAC": [
        "HS12HFW13MI", "MMI12CABWCC32M1", "MMI12CABWCC6M9", "MMI12CDBWCC32M1", "MMI12CDBWCC6M9",
        "MMI12CDMCCM9", "MMI18CDBWCC32M1", "MMI18CDMCCM9", "MMI24CDBWCC32M1", "MMI24CDBWCC6M8",
        "MMT12CDBWCCTM1", "PTM12CABWJM2",
      ]
    }
  },
  "NORTEAMERICA": {
    "CA": {
      "ACCE": [
    "CXPR6HKPTCU", "CXPR6HKPTSS", "CXQB4H4PNBT", "CXQB4H4PNBZ", "CXQB4H4PNSS",
    "CX8DC9SPWM", "CX10DC9SPDS", "CX10DC9SPSS", "CX10DC9SPWM", "DSDR24F",
    "FORGE02CUPS", "GFA24KITL", "GFA28KITN", "GFP1528PNRS", "GFP1528PNSN",
    "GFP1528PTDS", "GFP1528SNWW", "GFR0728PTDS", "GFR0728SNWW", "IM18000",
    "IM19000", "IM4D", "JX10PEM", "JX15BUMPBB", "JX30ASSC", "JX827SFC",
    "JX827SLFC", "JX830SFC", "JX830SLFC", "JX1124STC", "JXCF72", "JXCGRILL1",
    "JXDC72ES", "JXFILLR1DD", "JXFILLR1SS", "JXFLUSH1", "JXGRILL1", "JXPROBE1",
    "JXTR32B", "JXS50SS", "UPK4", "UXN70", "UXBDA812", "UXCF91", "UXDC72SJSS",
    "UXDC734MWM", "UXPRRGG", "UXRC70", "UXWORXR27", "UXWORXR30", "ZKSP1H1TVT1",
    "ZXPR36HKTB1", "ZXPR36HKTT1", "ZXPR48HLTB1", "ZXPR48HSTB1", "ZXS900SSNSS",
  ],
      "REFR": [
        "CFE26KP2NS1", "CFE28UELDS", "CGE29DM5TS5", "CHE23DM5WS5", "CJE23DM5WS5",
    "CJE23DP2WS1", "CJE23DP4WW2", "CQE28DM5NS5", "CSB42WP2NS1", "CSB48WP2NS1",
    "CVE28DP2NS1", "CVE28DP3ND1", "CVE28DP4NW2", "CWE19SP2NS1", "CWE19SP3ND1",
    "CWE19SP4NW2", "CWE23SP2MS1", "CWE23SP3MD1", "CWE23SP4MW2", "CXE22DM5PS5",
    "CXE22DP2PS1", "CXE22DP3PD1", "CXE22DP4PW2", "CYE22TP2MS1", "CYE22TP3MD1",
    "CYE22TP4MW2", "CYE22UP2MS1", "CZS22MP2NS1", "DFE24JYRKFS", "GBE17HYRFS",
    "GBE21AGKBB", "GBE21AGKWW", "GBE21ASKSS", "GBE21AYRKFS", "GBE21DYKFS",
    "GDE21DGKWW", "GDE21DMKES", "GDE21DSKSS", "GDE21DYRKFS", "GDE21EYKFS",
    "GDE25ESKSS", "GDE25EYKFS", "GFE24JYKFS", "GFE26JBMTS", "GFE26JGMBB",
    "GFE26JGMWW", "GFE26JMMES", "GFE26JYMFS", "GLE12HSPSS", "GNE21FYKFS",
    "GNE21DYRKFS", "GNE25DYRKFS", "GNE25JYKFS", "GNE27JGMBB", "GNE27JGMWW",
    "GNE27JMMES", "GNE27JSMSS", "GNE27JYMFS", "GPE12FGKBB", "GPE12FGKWW",
    "GPE12FSKSB", "GSE23GYPFS", "GSE25GYPFS", "GSS23GGKWW", "GSS23GGPBB",
    "GSS23GGPWW", "GSS23GMPES", "GSS23GSKSS", "GSS23GYPFS", "GSS25GGPBB",
    "GSS25GMPES", "GSS25GYPFS", "GSS25IMNES", "GSS25IYNFS", "GTE16DTNLWW",
    "GTE16DTNRWW", "GTE17DTNRWW", "GTE17GSNRSS", "GTE17GTNRBB", "GTE17GTNRWW",
    "GTE18DTNRWW", "GTE18FSLKSS", "GTE18FTLKBB", "GTE18FTLKWW", "GTE18GMNRES",
    "GTE18GSNRSS", "GTE18GTNRWW", "GTE21GSHSS", "GTE21GTHWW", "GTR21GSPSS",
    "GTR21GTPWW", "GTS18FSLKSS", "GTS18FTLKBB", "GTS18FTLKWW", "GTS19KYNRFS",
    "GWE19JGLBB", "GWE19JGLWW", "GWE19JMLES", "GWE19JYLFS", "GWE19OYLFS",
    "GWE22JYMFS", "GWE23GMNES", "GWE23GYNFS", "GYE18JYLFS", "GYE21JYMFS",
    "GYE22GMNES", "GYE22GYNFS", "GZS22IMNES", "GZS22IYNFS", "HPE16BTNRWW",
    "HRB15N3BGS", "HRF15N3AGS", "HRQ16N3BGS", "M2E9FPMKII", "MBE11DSLSS",
    "MBE11DSVSS", "MBE19DSNKSS", "MBE19DTNKWW", "MDE19DSNKSS", "MDE19DTNKWW",
    "MNE18DYTNFS", "MPE12FGKLWW", "MPE12FGKWW", "MPE12FSKSB", "MSS26KTRKWW",
    "MSS26KYRKFS", "MTE18GSKSS", "MTE18GTKWW", "MTE18HSKRSS", "MTE18HTKBB",
    "MTE18HTKRWW", "MWE22FYPKFS", "MWS21FSKSS", "MYE22HYPKFS", "PAD28BYTFS",
    "PFE24HGLKWW", "PFE24HMLKES", "PFE24HSLKSS", "PFE24HYRCFS", "PFE24HYRKFS",
    "PFE28PMKES", "PFE28PYNFS", "PGE29BYTFS", "PNE21NGLKWW", "PNE21NMLKES",
    "PNE21NSLKSS", "PNE21NYRKFS", "PNE25NGLKBB", "PNE25NGLKWW", "PNE25NMLKES",
    "PNE25NSLKSS", "PNE25NYRKFS", "PWE23KYNFS", "PYD22KBLTS", "PYD22KYNFS",
    "PYE18HMLKES", "PYE18HSLKSS", "PYE18HYRCFS", "PYE18HYRKFS", "QHE16HYPFS",
    "QJS15HYRFS", "ZIC303NPPII", "ZIC363IPVLH", "ZIC363IPVRH", "ZIC363NBVLH",
    "ZIC363NBVRH", "ZICP360NHRH", "ZICS360NNRH", "ZICS360NVLH", "ZICS360NVRH",
    "ZIF241NPNII", "ZIF361NBRII", "ZIF361NPRII", "ZIK303NPPII", "ZIP364IPVII",
    "ZIP364NBVII", "ZIPS360NNSS", "ZIR241NBRII", "ZIR241NPNII", "ZIR301NBRII",
    "ZIR301NPNII", "ZIR361NBRII", "ZIR361NPRII", "ZIS420NNII", "ZIS480NNII",
    "ZISB360DNII", "ZISB420DNII", "ZISB480DNII", "ZISS360DNSS", "ZISS420DHSS",
    "ZISS420DNSS", "ZISS420NNSS", "ZISS480DNSS", "ZISS480NNSS", "ZIW303NPPII",
    "ZWE23NSTSS", "ZWE23NSYSS", "ZWE23PSNSS",
      ],
      "LAVA": [
        "GFD14JSINWW", "GFD45GSMMDG", "GFD55ESMNWW", "GFD55ESMRRS", "GFD55GSSNWW",
    "GFD65ESMNSN", "GFD65ESMVDS", "GFD85ESMNRS", "GFQ14ESSNWW", "GFT14JSIMWW",
    "GFW148SSMWW", "GFW450SPMDG", "GFW550SMNWW", "GFW550SPRRS", "GFW650SPNSN",
    "GFW655SPVDS", "GFW850SPNRS", "GNW128PSMWW", "GNW128SSMWW", "GTD32EBMPWW",
    "GTD40EBMRWS", "GTD40GBMRWS", "GTD45EBMRWS", "GTD45GBMKWS", "GTD45GBMRWS",
    "GTD46EDMNWS", "GTD49EBMRDG", "GTD49EBMRWS", "GTD49GBMRWS", "GTD65EBMRDG",
    "GTD65EBMRWS", "GTD65GBMRWS", "GTD68EBMRDG", "GTD68EBMRWS", "GTD68GBMRWS",
    "GTD69EBPTDG", "GTD69EBPYWR", "GTD75GCMLWS", "GTW223BMRWW", "GTW302BMPWW",
    "GTW330BMMWW", "GTW331BMRWS", "GTW334BMRWS", "GTW451BMRWS", "GTW460BMMWW",
    "GTW465BMMWS", "GTW485BMMWS", "GTW490BMRWS", "GTW491BMRDG", "GTW491BMRWS",
    "GTW495DMNWS", "GTW550BMRWS", "GTW580BMRWS", "GTW680BMMDG", "GTW680BMRDG",
    "GTW680BMRWS", "GTW681BMRDG", "GTW681BMRWS", "GTW685BMRWS", "GTW690BMTDG",
    "GTW690BMYWR", "GTW720BPNDG", "GTW750CPLDG", "GTW750CSLWS", "GTX22EBMRWW",
    "GTX33EBMRWS", "GTX34EBMRWS", "GUD24ESMMWW", "GUD24GSSMWW", "GUD27EEMNWW",
    "GUD27ESMMWW", "GUD27GSSMWW", "GUD37EEMNDG", "GUD37ESMMDG", "GUD57EEMTDG",
    "GUV27ESMWWW", "HLC1700AXW", "MTW201BMRWW", "MTX22EBMRWW", "PCKS443EBWW",
    "PCVH480EKWW", "PFD87ESMVRS", "PFQ83HSHWWW", "PFQ83HSLWWW", "PFQ83HSSWWW",
    "PFQ97HSPVDS", "PFW870SPVRS", "PSKP333EBWW", "PSKS333EBWW", "PTD60EBMRDG",
    "PTD60EBMRWS", "PTD60GBSRWS", "PTD70EBMTDG", "PTD70EBMTWS", "PTD70GBPTDG",
    "PTD90EBMTDG", "PTD90EBMTRS", "PTD90GBPTRS", "PTW600BPRDG", "PTW600BSRWS",
    "PTW700BPTDG", "PTW705BSTWS", "PTW800BPWRS", "PTW900BPTRS", "QFD15ESMNWW",
    "QFW150SSNWW", "WCVH4800KWW",
      ],
      "GLOB": [
        "C7CDAAS2PS3", "C7CDAAS3PD3", "C7CDAAS4PW3", "C7CEBBS2RS3", "C7CEBBS3RD3",
    "C7CEBBS4RW3", "C7CESAS2RS3", "C7CESAS3RD3", "C7CESAS4RW3", "C9OAAAS2RS3",
    "C9OAAAS3RD3", "C9OAAAS4RW3", "C9TMA2S2PS3", "C9TMA2S3PD3", "C9TMA2S4PW3",
    "CCP06BP2PS1", "CCP06BP3PD1", "CCP06BP4PW2", "CCP06DP2PS1", "CCP06DP4PW2",
    "CCR06BM2PS5", "CDE06RP2NS1", "CDE06RP3ND1", "CDE06RP4NW2", "CDP888M5VS5",
    "CDT845P2NS1", "CDT845P3ND1", "CDT858P2VS1", "CDT858P3VD1", "CDT875M5NS5",
    "CDT875P2NS1", "CDT875P4NW2", "CDT888P2VS1", "CDT888P3VD1", "CDT888P4VW2",
    "CEB515P4NWM", "CTW900P3PD1", "CTW900P4PW2", "CVM517P2MS1", "CVM517P2RS1",
    "CVM517P3MD1", "CVM517P3RD1", "CVM517P4MW2", "CVM517P4RW2", "CVM721M2NCS5",
    "CWLC12P2RS1", "CWLC12P4RW5", "DBP655SSTSS", "DBT655SSNSS", "DVM2185SMSS",
    "FCM16SLWW", "FCM22DLWW", "FCM5STWW", "FCM7STWW", "FORGE02PACK",
    "FUF14DLRWW", "FUF14SMRWW", "FUF17DLRWW", "FUF17SMRWW", "FUF21DLRWW",
    "FUF21SMRWW", "G7CDAASSPSS", "G7CDABSSPSS", "G7KD15SSPSS", "G7KE17SSPSS",
    "G8BJAASSPSS", "G8H0AASSPSS", "G8H1AASSPSS", "G8P0AASSPSS", "G9OAABSSPSS",
    "G9OCAASSPSS", "GBF180SGMWW", "GBF180SSMSS", "GBF410SGPBB", "GBF410SGPWW",
    "GBF410SSPSS", "GBF532SGPBB", "GBF532SGPWW", "GBF532SSPSS", "GBF630SMLES",
    "GBF655SGPWW", "GBF655SMPES", "GBF655SSPSS", "GBP420SSPSS", "GBP534SGPWW",
    "GBP534SSPSS", "GBP655SMPES", "GBP655SSPSS", "GBT412SIMII", "GBT500SGVWW",
    "GBT500SSVSS", "GBT600SSVFS", "GBT632SSMSS", "GBT640SGPWW", "GBT640SMPES",
    "GBT640SSPSS", "GCE06GGHWW", "GCE06GSHSB", "GDE03GLKLB", "GDF510PGRWW",
    "GDF510PSRSS", "GDF511PGRBB", "GDF511PGRWW", "GDF511PSRSS", "GDF645SGNWW",
    "GDF650SYVFS", "GDF670SYVFS", "GDP630PGRWW", "GDP630PYRFS", "GDT225SGLWW",
    "GDT225SSLSS", "GDT226SILII", "GDT226SSLSS", "GDT410SIFII", "GDT635HSMSS",
    "GDT635HSRSS", "GDT650SMVES", "GDT650SYVFS", "GDT665SMNES", "GDT665SSNSS",
    "GDT670SMVES", "GDT670SYVFS", "GPT225SGLWW", "GPT225SSLSS", "GVS04BQNSS",
    "GWS04HAESS", "HC45SG42SB", "HCM5SMWW", "HCM9DMWW", "HEBF100BXS",
    "HEN30ET", "HMV1472BHS", "JE1140STC", "JEB2167RMSS", "JES1140STC",
    "JES1145WTC", "JVM1635SFC", "JVM1635SLJC", "JVM2160DMBB", "JVM2160DMWW",
    "JVM2162SMSS", "JVM2165SMSS", "JVM2185SMSS", "MBF420SGPWW", "MBF422SGMWW",
    "MBT425SGVWW", "MUF06DMRWW", "P4INSASBVTS", "P8MSASS6TBB", "P8MSASS6TGW",
    "P8MSASS6TOW", "P9SBAAS6VBB", "PBF665SMPES", "PBF665SSPFS", "PBP665SGPWW",
    "PBP665SSPFS", "PBT660SGLWW", "PBT660SSLSS", "PBT700SSVFS", "PBT860SMMES",
    "PBT860SSMSS", "PBT865SMPES", "PBT865SSPFS", "PCR06BATSS", "PCR06WATSS",
    "PDP715SYNFS", "PDP715SYVFS", "PDP755SYRFS", "PDP755SYVFS", "PDT145SGLWW",
    "PDT145SSLSS", "PDT660SSFSS", "PDT705SYWFS", "PDT715SMNES", "PDT715SYNFS",
    "PDT715SYVFS", "PDT755SYRFS", "PDT785SYNFS", "PEB3228RMSS", "PEM10SFC",
    "PEM10SLFC", "PEM11SHC", "PTW9000SPSS", "PVM1899SJC", "PVM2155SHC",
    "PVM2188DSMC", "PVM2188SJC", "PVM2188SLJC", "PVS06BSPSS", "PWS06DSPSS",
    "PXR03FLMFSC", "QDP225SSPSS", "QDP555SYNFS", "QDT125SSKSS", "QDT125SSLSS",
    "QVM7167RNCSS", "UBT410SGVBB", "UBT410SGVWW", "UBT410SSVSS", "UCC15NPRII",
    "UDT165SIVII", "UNC15NPRII", "XPIO13BCBT", "XPIO13SCSS", "XPIO43SCSS",
    "XPIOX3BCBT", "XPIOX3SCSS", "ZDBI240HII", "ZDBR240NBS", "ZDT925SINII",
    "ZDT925SPNSS", "ZDT925SSNSS", "ZDT975SPJSS", "ZDT985SINII", "ZDT985SPNSS",
    "ZDT985SSNSS", "ZDWI240HII", "ZDWR240NBS", "ZIBC24PWII", "ZIBI240HII",
    "ZIBS240NSS", "ZIDI240HII", "ZIDS240NSS", "ZIF181NBRII", "ZIF181NPNII",
    "ZIF241NBRII", "ZIF301NBRII", "ZIF301NPNII", "ZIFI240HII", "ZIFS240NSS",
    "ZIW241NBWII", "ZIWD24PWII", "ZWL1126SJSSC", "ZWL1126SRSS",
      ],
      "COCC": [
        "BIL616TI2-B5-09", "C2Y366P2TS1", "C2Y366P3TD1", "C2Y366P4TW2", "C2Y486P3TD1",
    "C2Y486P4TW2", "CC2S900M2NS5", "CC2S900P2MS1", "CC2S900P3MD1", "CC2S900P4MW2",
    "CC2S950M2NS5", "CC2S950P2MS1", "CC2S950P3MD1", "CCES700P2MS1", "CCES700P3MD1",
    "CCES700P4MW2", "CCES750P2MS1", "CCES750P4MW2", "CCGS700M2NS5", "CCGS700P2MS1",
    "CCGS700P3MD1", "CCGS700P4MW2", "CCGS750P2MS1", "CCGS750P4MW2", "CCHS900P2MS1",
    "CCHS900P4MW2", "CCHS950P2MS1", "CCHS950P3MD1", "CCHS950P4MW2", "CEP90301TBB",
    "CEP90302TSS", "CEP90361TBB", "CEP90362TSS", "CGP95302MS1", "CGP95362MS1",
    "CGU366P2TS1", "CGY366P2TS1", "CGY366P3TD1", "CGY366P4TW2", "CHP90301TBB",
    "CHP90302TSS", "CHP90361TBB", "CHP90362TSS", "CHP95362MSS", "CHS900M2NS5",
    "CHS90XM2NS5", "CHS90XP2MS1", "CRS70XAWCS1", "CSB913M2NS5", "CSB913M2VS5",
    "CSB913P2NS1", "CSB913P2VS1", "CSB913P3ND1", "CSB913P3VD1", "CSB913P4NW2",
    "CSB913P4VW2", "CSB923M2NS5", "CSB923P2NS1", "CSB923P2VS1", "CSB923P3ND1",
    "CTC912P2NS1", "CTD90DM2NS5", "CTD90DP2NS1", "CTD90DP3ND1", "CTD90DP4NW2",
    "CTD90FP2NS1", "CTD90FP3ND1", "CTD90FP4NW2", "CTS70DM2NS5", "CTS70DP2NS1",
    "CTS90DM2NS5", "CTS90DP2NS1", "CTS90DP3MD1", "CTS90DP3ND1", "CTS90DP4NW2",
    "CTS90FP2NS1", "CTS90FP3ND1", "CTS90FP4NW2", "CTW900P2PS1", "CVW73012MSS",
    "CVW73013MDS", "CVW73014MWM", "CVW93043PDS", "CVW93044PWM", "CVW93643PDS",
    "CVW93644PWM", "HCW225LAES", "HCW225RAES", "HCW2360AES", "JBS86SPSS",
    "JCAS300DMWW", "JCAS300RPSS", "JCAS640RMSS", "JCB630DKWW", "JCB630EKES",
    "JCB630ETES", "JCB630SKSS", "JCB630SVSS", "JCB635DKBB", "JCB635DKWW",
    "JCB635STSS", "JCB830DKWW", "JCB830DVWW", "JCB830SKSS", "JCB830STSS",
    "JCB840DKWW", "JCB840DVWW", "JCB840EKES", "JCB840ETES", "JCB840SKSS",
    "JCB840STSS", "JCB870SNSS", "JCB870STSS", "JCBP240DMWW", "JCBS250DMWW",
    "JCBS250SMSS", "JCBS280DMWW", "JCBS325SWSS", "JCBS350SVSS", "JCBS630DKWW",
    "JCBS630SKSS", "JCBS630SVSS", "JCGAS300DMWW", "JCGAS640RMSS", "JCGB660DPWW",
    "JCGB660SPSS", "JCGB735DPWW", "JCGB735EPES", "JCGB735SPSS", "JCGB745SPSS",
    "JCGBS10DEMWW", "JCGBS60DEKBB", "JCGBS60DEKWW", "JCGBS66SEKSS", "JCGS760EPES",
    "JCGS760SPSS", "JCGSS66SELSS", "JCGSS86SPSS", "JGSS66SELSS", "JCS830SMSS",
    "JCS830SVSS", "JCS840EMES", "JCS840SMSS", "JCSS630SMSS", "JCT5000SFSS",
    "JEP5030DTBB", "JEP5030STSS", "JGP3030DLBB", "JGP3030SLSS", "JGP3036DLBB",
    "JGP3036SLSS", "JGP5030DLBB", "JGP5030SLSS", "JGP5036SLSS", "JKS3000DNWW",
    "JKS3000SNSS", "JKS5000DNBB", "JKS5000DVBB", "JKS5000SNSS", "JKS5000SVSS",
    "JP3021DPBB", "JP3030DJBB", "JP3030DWBB", "JP3030SJSS", "JP3030SWSS",
    "JP3036DLBB", "JP3036SLSS", "JP5030SJSS", "JT3800SHSS", "JTS3000DNWW",
    "JTS3000ENES", "JTS3000SNSS", "JTS5000DNBB", "JTS5000DVBB", "JTS5000ENES",
    "JTS5000EVES", "JTS5000SNSS", "JTS5000SVSS", "JVW5301EJESC", "JVW5301SJSSC",
    "JVX3240SJSSC", "JVX3300SJSSC", "JVX5300DJWWC", "JVX5300EJESC", "JVX5300SJSSC",
    "MCB757DMWW", "MCB787DNWW", "MCBS523DNWW", "MCBS525DNWW", "MCBS585DNWW",
    "MCP2024DXBB", "MCRS20SFSS", "MER247CWBS", "NS-RGRCESS3-C", "NS-RNE4BMWH9-C",
    "PB935YPFS", "PC2B935YPFS", "PC2S930SELSS", "PC2S930YPFS", "PCB900YVFS",
    "PCB905YPFS", "PCB905YVFS", "PCB940SKSS", "PCGB935YPFS", "PCGB940ZEJSS",
    "PCGB965YPFS", "PCGS930BELTS", "PCGS930YPFS", "PCGS960YPFS", "PCHB920SMSS",
    "PCHB920YMFS", "PCHS920SMSS", "PCHS920YMFS", "PCS940DMWW", "PCS940EMES",
    "PCS940SFSS", "PCS940YMFS", "PCS980SMSS", "PCS980YMFS", "PEP7030DTBB",
    "PEP7036DTBB", "PGP9030SLSS", "PGP9036SLSS", "PHP7030DTBB", "PHP7036DTBB",
    "PHS93XYPFS", "PP9030DJBB", "PSS93YPFS", "PT7800SHSS", "PTD7000SNSS",
    "PTS7000SNSS", "PTS700LSNSS", "PTS700RSNSS", "PTS9000SNSS", "PTS9200SNSS",
    "PVX7300EJESC", "PVX7300SJSSC", "QCAS740RMSS", "QCGAS740RMSS", "QCGSS740RNSS",
    "QCSS740RNSS", "RCBS360DTWW", "UVC7300SLSS", "UVC9300SLSS", "UVC9360SLSS",
    "UVC9420SLSS", "UVC9480SLSS", "UVW8301SLSS", "UVW9301SLSS", "UVW93042PSS",
    "UVW9361SLSS", "UVW93642PSS", "ZDP304NTSS", "ZDP364NDTSS", "ZDP366NTSS",
    "ZDP484NGTSS", "ZDP486NDTSS", "ZEP30FRSS", "ZGP304NRSS", "ZGP304NTSS",
    "ZGP364NDTSS", "ZGP366NTSS", "ZGP486NDTSS", "ZGU30RSLSS", "ZGU364NDTSS",
    "ZGU366NTSS", "ZGU36ESLSS", "ZGU36RSLSS", "ZGU486NDTSS", "ZHP304ETVSS",
    "ZHP365ETVSS", "ZHU30RDPBB", "ZHU30RDTBB", "ZHU30RSTSS", "ZHU36RDTBB",
    "ZHU36RSPSS", "ZHU36RSTSS", "ZVIS361SRSS", "ZVIS481SRSS", "ZMB9031SNSS",
    "ZMB9032SNSS", "ZSB9131NSS", "ZSB9131VSS", "ZSB9132NSS", "ZSB9132VSS",
    "ZSB9231NSS", "ZSB9231VSS", "ZSB9232NSS", "ZSB9232VSS", "ZSC2202JSS",
    "ZTD90DPSNSS", "ZTD90DSSNSS", "ZTDX1DPSNSS", "ZTDX1DSSNSS", "ZTDX1FPSNSS",
    "ZTS90DPSNSS", "ZTS90DSSNSS", "ZTSX1DPSNSS", "ZTSX1DSSNSS", "ZTSX1FPSNSS",
    "ZTW900PSNSS", "ZTW900SSNSS", "ZV36SSJSS", "ZV48SSJSS", "ZV800SJSS",
    "ZV830SMSS", "ZV925SLSS", "ZV950SDSS", "ZVC48DTB1", "ZVC48STSS",
    "ZVC53DWTT", "ZVC53DWB1", "ZVWS361SRSS", "ZVWS481SRSS", "ZVW1360SPSS",
    "ZVW1480SPSS", "ZVW8301SWSS",
      ],
      "CALE": [
      ],
      "AIAC": [
        "APCA10YBMW", "APCA14YBMW", "APWA14YBMW", "AWAS05BWFC", "AWCS06BWFC",
    "HPP10XCT", "HPP10XCT-G", "QPCA10JAMW-A", "QPFA08YBMW",
      ]
    }
  }
}

# ============================================
# ESTADÍSTICAS
# ============================================
# ANDINO: 1573 SKUs
# CEAM: 1601 SKUs
# NORTEAMERICA: 801 SKUs
# TOTAL: 3975 SKUs
# Out:
# StatementMeta(, 39d21195-a990-4930-8dfa-0a4cf2989f2b, 3, Finished, Available, Finished)

# %%
from pyspark.sql.functions import col
import sempy.fabric as fabric

# ================================================================
# Configuración
# ================================================================
WORKSPACE = "WS_PROD_CONT"
DATASET = "CVI Continental"

paises_requeridos = ["CR","GT","HN","SV","PE","CO","EC","CL","AR","CA","MX"]

planif_validos = [
    "G5Z","G5Y","G5X","G5W","G5V","G5U","G5T","G5S","G5R","G5Q","G5P","G5O","G5N","G5M","G5L",
    "G5K","G5J","G5I","G5H","G5G","G5F","G5E","G5D","G5C","G5B","G5A",
    "F5Z","F5Y","F5X","F5W","F5V","F5U","F5T","F5S","F5R","F5Q","F5P","F5O","F5N","F5M","F5L",
    "F5K","F5J","F5I","F5H","F5G","F5F","F5E","F5D","F5B","F5A",
    "D5Z","D5Y","D5X","D5W","D5V","D5U","D5T","D5S","D5R","D5Q","D5P","D5O","D5N","D5M","D5L",
    "D5K","D5J","D5I","D5H","D5G","D5F","D5E","D5D","D5C","D5B","D5A",
    "H5V","H5Q","H5P",
    "G4Z","G4Y","G4X","G4W","G4V","G4U","G4T","G4S","G4R","G4Q","G4P","G4O","G4N","G4M","G4L",
    "G4K","G4J","G4I","G4H","G4G","G4F","G4E","G4D","G4C","G4B","G4A"
]

# ================================================================
# Función genérica para cargar y filtrar tablas
# ================================================================
def cargar_y_filtrar(nombre_tabla, col_planif=None, col_pais=None):
    print(f"\n=== Procesando tabla: {nombre_tabla} ===")
    
    # Cargar tabla
    df = fabric.read_table(dataset=DATASET, table=nombre_tabla, workspace=WORKSPACE)
    spark_df = spark.createDataFrame(df)
    
    # Mostrar debug columnas y filas
    print(f"Columnas: {spark_df.columns}")
    print(f"Filas antes de filtrar: {spark_df.count()}")
    
    # Filtrar solo si se especifican columnas
    if col_planif and col_pais:
        df_filtrado = spark_df.filter(
            col(col_planif).isin(planif_validos) & col(col_pais).isin(paises_permitidos)
        )
        print(f"Filas después de filtrar: {df_filtrado.count()}")
        return df_filtrado
    else:
        return spark_df

# ================================================================
# Cargar y filtrar cada tabla con su columna correspondiente
# ================================================================

# COMPRAS (sin filtro por planificador)
spark_df_compras_filtrado = cargar_y_filtrar(
    "CONTINENTAL_COMPRAS_GOVERNANCE1",
    col_pais="País"
)

# COSTEADO desde Lakehouse
spark_df_costeado_filtrado = spark.sql("SELECT * FROM LH_INTELLIGENT_VISIBILITY_CARATULAS.CONTINENTAL_COSTEADO_GOVERNANCE_CA")

# ENTREGAS (sin filtro por planificador) CVI CONTINENTAL
spark_df_entregas_filtrado = cargar_y_filtrar(
    "CONTINENTAL_ENTREGAS_ENTRANTES",
    col_pais="País"
)

# PLAN DE DEMANDA (cargado desde Lakehouse)
spark_df_plan_demanda_filtrado = spark.sql("SELECT * FROM LH_INTELLIGENT_VISIBILITY_CARATULAS.DEMANDA_LOCAL")
display(spark_df_plan_demanda_filtrado)

# CALENDARIO (sin filtros)
spark_df_calendario = cargar_y_filtrar("CONTINENTAL_GENERICO_CALENDARIOFISCAL")
# Out:
# StatementMeta(, 39d21195-a990-4930-8dfa-0a4cf2989f2b, 4, Finished, Available, Finished)
# === Procesando tabla: CONTINENTAL_COMPRAS_GOVERNANCE1 ===
# Columnas: ['Almacén', 'Centro', 'Fecha de documento', 'Fecha preferente de entrega', 'Grupo artículos', 'Número del documento de compras', 'Número de posición del documento de compras', 'Material', 'País', 'Organización de compras', 'Planificador Necesidades', 'Planificador Necesidades Clave', 'Proveedor', 'Proveedor_des', 'Región', 'Sociedad_des', 'Cantidad de pedido', 'Cantidad de pedido pendiente', 'Llave EE', 'Fecha EE', 'Qty EE', 'Qty sin EE', 'Fecha Final', 'OC Mes Actual']
# Filas antes de filtrar: 5402
#
# === Procesando tabla: CONTINENTAL_ENTREGAS_ENTRANTES ===
# ...

# %%
from pyspark.sql.functions import col
import sempy.fabric as fabric

# ================================================================
# Configuración
# ================================================================
WORKSPACE = "WS_PROD_CONT"
DATASET = "CVI Continental"
LAKEHOUSE = "LH_INTELLIGENT_VISIBILITY_CARATULAS"

paises_requeridos = ["CR","GT","HN","SV","PE","CO","EC","CL","AR","CA"]

planif_validos = [
    "G5Z","G5Y","G5X","G5W","G5V","G5U","G5T","G5S","G5R","G5Q","G5P","G5O","G5N","G5M","G5L",
    "G5K","G5J","G5I","G5H","G5G","G5F","G5E","G5D","G5C","G5B","G5A",
    "F5Z","F5Y","F5X","F5W","F5V","F5U","F5T","F5S","F5R","F5Q","F5P","F5O","F5N","F5M","F5L",
    "F5K","F5J","F5I","F5H","F5G","F5F","F5E","F5D","F5B","F5A",
    "D5Z","D5Y","D5X","D5W","D5V","D5U","D5T","D5S","D5R","D5Q","D5P","D5O","D5N","D5M","D5L",
    "D5K","D5J","D5I","D5H","D5G","D5F","D5E","D5D","D5C","D5B","D5A",
    "H5V","H5Q","H5P",
    "G4Z","G4Y","G4X","G4W","G4V","G4U","G4T","G4S","G4R","G4Q","G4P","G4O","G4N","G4M","G4L",
    "G4K","G4J","G4I","G4H","G4G","G4F","G4E","G4D","G4C","G4B","G4A"
]

# ================================================================
# Función genérica para cargar y filtrar tablas del Modelo Semántico
# ================================================================
def cargar_y_filtrar_semantico(nombre_tabla, col_planif=None, col_pais=None):
    print(f"\n=== Procesando tabla (Modelo Semántico): {nombre_tabla} ===")
    
    # Cargar tabla
    df = fabric.read_table(dataset=DATASET, table=nombre_tabla, workspace=WORKSPACE)
    spark_df = spark.createDataFrame(df)
    
    # Mostrar debug columnas y filas
    print(f"Columnas: {spark_df.columns}")
    print(f"Filas antes de filtrar: {spark_df.count()}")
    
    # Filtrar solo si se especifican columnas
    if col_planif and col_pais:
        df_filtrado = spark_df.filter(
            col(col_planif).isin(planif_validos) & col(col_pais).isin(paises_requeridos)
        )
        print(f"Filas después de filtrar: {df_filtrado.count()}")
        return df_filtrado
    elif col_pais:
        df_filtrado = spark_df.filter(col(col_pais).isin(paises_requeridos))
        print(f"Filas después de filtrar: {df_filtrado.count()}")
        return df_filtrado
    else:
        return spark_df

# ================================================================
# Función para cargar y filtrar tablas desde Lakehouse
# ================================================================
def cargar_y_filtrar_lakehouse(nombre_tabla, col_planif=None, col_pais=None):
    print(f"\n=== Procesando tabla (Lakehouse): {nombre_tabla} ===")
    
    # Cargar tabla desde Lakehouse
    spark_df = spark.sql(f"SELECT * FROM {LAKEHOUSE}.{nombre_tabla}")
    
    # Mostrar debug columnas y filas
    print(f"Columnas: {spark_df.columns}")
    print(f"Filas antes de filtrar: {spark_df.count()}")
    
    # Filtrar solo si se especifican columnas
    if col_planif and col_pais:
        df_filtrado = spark_df.filter(
            col(col_planif).isin(planif_validos) & col(col_pais).isin(paises_requeridos)
        )
        print(f"Filas después de filtrar: {df_filtrado.count()}")
        return df_filtrado
    elif col_pais:
        df_filtrado = spark_df.filter(col(col_pais).isin(paises_requeridos))
        print(f"Filas después de filtrar: {df_filtrado.count()}")
        return df_filtrado
    else:
        return spark_df

# ================================================================
# Cargar tablas
# ================================================================

# COMPRAS - Desde LAKEHOUSE (con filtro de país y planificador)
# NOTA: Las columnas ahora están limpias sin espacios
spark_df_compras_filtrado = cargar_y_filtrar_lakehouse(
    "CONTINENTAL_COMPRAS_GOVERNANCE_DAX",
    col_planif="Planificador_Necesidades_Clave",  # Sin espacios
    col_pais="Pais"  # Sin tilde
)

# ENTREGAS - Desde LAKEHOUSE (con filtro de país y planificador)
# NOTA: Las columnas ahora están limpias sin espacios
spark_df_entregas_filtrado = cargar_y_filtrar_lakehouse(
    "CONTINENTAL_ENTREGAS_ENTRANTES_DAX",
    col_planif="Planificador_de_Necesidades",  # Sin espacios
    col_pais="Pais"  # Sin tilde
)

# COSTEADO - Desde Lakehouse (sin cambios)
print("\n=== Procesando tabla: COSTEADO ===")
spark_df_costeado_filtrado = spark.sql(f"SELECT * FROM {LAKEHOUSE}.CONTINENTAL_COSTEADO_GOVERNANCE_CA")
print(f"Filas: {spark_df_costeado_filtrado.count()}")

# PLAN DE DEMANDA - Desde Lakehouse (sin cambios)
print("\n=== Procesando tabla: PLAN DE DEMANDA ===")
spark_df_plan_demanda_filtrado = spark.sql(f"SELECT * FROM {LAKEHOUSE}.DEMANDA_LOCAL")
print(f"Filas: {spark_df_plan_demanda_filtrado.count()}")
display(spark_df_plan_demanda_filtrado)

# CALENDARIO - Desde Modelo Semántico (sin cambios)
spark_df_calendario = cargar_y_filtrar_semantico("CONTINENTAL_GENERICO_CALENDARIOFISCAL")

# ================================================================
# Resumen
# ================================================================
print("\n" + "="*60)
print("✅ TABLAS CARGADAS")
print("="*60)
print(f"📦 COMPRAS (Lakehouse): {spark_df_compras_filtrado.count():,} filas")
print(f"📦 ENTREGAS (Lakehouse): {spark_df_entregas_filtrado.count():,} filas")
print(f"📦 COSTEADO (Lakehouse): {spark_df_costeado_filtrado.count():,} filas")
print(f"📊 PLAN DEMANDA (Lakehouse): {spark_df_plan_demanda_filtrado.count():,} filas")
print(f"🗓️ CALENDARIO (Modelo Semántico): {spark_df_calendario.count():,} filas")
print("="*60)
# Out:
# StatementMeta(, e0de1206-12be-4155-94f0-8bd5dc3ba409, 6, Finished, Available, Finished)
# === Procesando tabla (Lakehouse): CONTINENTAL_COMPRAS_GOVERNANCE_DAX ===
# Columnas: ['Almacen', 'Centro', 'Fecha_de_documento', 'Fecha_preferente_de_entrega', 'Grupo_articulos', 'Material', 'Numero_del_documento_de_compras', 'Numero_posicion_en_documento_solicitud_pedido', 'Organizacion_de_compras', 'Pais', 'Planificador_Necesidades', 'Planificador_Necesidades_Clave', 'Proveedor', 'Region', 'Cantidad_base', 'Cantidad_de_pedido', 'Cantidad_de_pedido_pendiente', 'Llave_EE', 'Fecha_EE', 'Qty_EE', 'Qty_sin_EE', 'Fecha_Final', 'OC_Mes_Actual']
# Filas antes de filtrar: 111829
# Filas después de filtrar: 34082
#
# === Procesando tabla (Lakehouse): CONTINENTAL_ENTREGAS_ENTRANTES_DAX ===
# ...

# %%
from pyspark.sql.functions import col

# Definir países por región
# Definir países por región
paises_ceam = ["CR", "GT", "HN", "SV"]
paises_andino = ["PE", "CO", "EC", "CL", "AR"]
paises_norteamerica = ["CA"]
paises_mexico = ["MX"]
paises_permitidos = paises_ceam + paises_andino + paises_norteamerica + paises_mexico

# Cargar tabla de facturación directamente desde el lakehouse
spark_df_facturacion_gov = spark.sql(
    "SELECT * FROM LH_INTELLIGENT_VISIBILITY_CARATULAS.CONTINENTAL_FACTURIACION_CDV_1"
).withColumnRenamed("País Sociedad", "País")

# Debug columnas y filas
print("=== Facturación: columnas y filas iniciales ===")
print(f"Columnas: {spark_df_facturacion_gov.columns}")
print(f"Filas totales: {spark_df_facturacion_gov.count()}")

# Filtrar por planificadores, países y ejercicio/período
spark_df_facturacion_filtrado = spark_df_facturacion_gov.filter(
    (col("Planificador Necesidades").isin(planif_validos)) &
    (col("País").isin(paises_permitidos)) &
    (col("Ejercicio/Período") >= 2025001)
).select(
    "Material", "País", "Grupo Artículos", "Volumen Ventas", 
    "Ejercicio/Período", "Planificador Necesidades"
)

# Debug filas después del filtro
print(f"Filas después de filtrar: {spark_df_facturacion_filtrado.count()}")

# Verificar qué países y planificadores están en los datos
print("Países encontrados en los datos filtrados:")
spark_df_facturacion_filtrado.select("País").distinct().show()

print("Planificadores encontrados en los datos filtrados:")
spark_df_facturacion_filtrado.select("Planificador Necesidades").distinct().show()

# Mostrar primeras filas
spark_df_facturacion_filtrado.show(5)
# Out:
# StatementMeta(, 39d21195-a990-4930-8dfa-0a4cf2989f2b, 5, Finished, Available, Finished)
# === Facturación: columnas y filas iniciales ===
# Columnas: ['Volumen Ventas', 'Año natural/Semana', 'Año natural', 'País', 'Ejercicio/Período', 'Material', 'Grupo Artículos', 'Planificador Necesidades', 'Planificador Necesidades Descripción', 'Almacén']
# Filas totales: 221930
# Filas después de filtrar: 94545
# Países encontrados en los datos filtrados:
# +----+
# |País|
# +----+
# |  MX|
# |  SV|
# |  CL|
# |  CA|
# |  HN|
# |  GT|
# |  EC|
# |  CR|
# |  PE|
# |  CO|
# |  AR|
# +----+
#
# Planificadores encontrados en los datos filtrados:
# +------------------------+
# |Planificador Necesidades|
# +------------------------+
# |                     D5F|
# |                     D5N|
# |                     D5K|
# |                     D5A|
# |                     F5M|
# |                     D5P|
# |                     D5L|
# |                     D5C|
# |                     D5W|
# ...

# %%
from pyspark.sql.functions import col

# Definir países por región
paises_ceam = ["CR", "GT", "HN", "SV"]
paises_andino = ["PE", "CO", "EC", "CL", "AR"]
paises_permitidos = paises_ceam + paises_andino

# Cargar tabla de facturación
df_facturacion_gov = fabric.read_table(
    dataset=DATASET,
    table="CONTINENTAL_FACTURIACION_CDV",
    workspace=WORKSPACE
)
spark_df_facturacion_gov = spark.createDataFrame(df_facturacion_gov)

# Debug columnas y filas
print("=== Facturación: columnas y filas iniciales ===")
print(f"Columnas: {spark_df_facturacion_gov.columns}")
print(f"Filas totales: {spark_df_facturacion_gov.count()}")

# Filtrar por planificadores, países y ejercicio/período
spark_df_facturacion_filtrado = spark_df_facturacion_gov.filter(
    (col("Planificador Necesidades").isin(planif_validos)) &
    (col("País").isin(paises_permitidos)) &
    (col("Ejercicio/Período") >= 2025001)
).select(
    "Material", "País", "Grupo Artículos", "Volumen Ventas", 
    "Ejercicio/Período", "Planificador Necesidades"
)

# Debug filas después del filtro
print(f"Filas después de filtrar: {spark_df_facturacion_filtrado.count()}")

# Verificar qué países y planificadores están en los datos
print("Países encontrados en los datos filtrados:")
spark_df_facturacion_filtrado.select("País").distinct().show()

print("Planificadores encontrados en los datos filtrados:")
spark_df_facturacion_filtrado.select("Planificador Necesidades").distinct().show()

# Mostrar primeras filas
spark_df_facturacion_filtrado.show(5)
# Out:
# StatementMeta(, 0787bc1a-d1f3-4611-b714-b42440ff7f5a, 5, Finished, Available, Finished)
# === Facturación: columnas y filas iniciales ===
# Columnas: ['Canal distribución', 'Centro', 'País (Cliente)', 'Ejercicio/Período', 'Factura', 'Gr.export.', 'Gr.export. Descripción', 'Grupo Artículos', 'Material', 'Organización de ventas', 'Planificador Necesidades', 'Sociedad', 'Volumen Ventas', 'País 2.', 'Tipo de Venta', 'Fecha2', 'País', 'Fecha', 'Cliente Descripción']
# Filas totales: 13940870
# Filas después de filtrar: 624784
# Países encontrados en los datos filtrados:
# +----+
# |País|
# +----+
# |  EC|
# |  CL|
# |  PE|
# |  GT|
# |  CR|
# |  CO|
# |  AR|
# |  SV|
# |  HN|
# +----+
#
# Planificadores encontrados en los datos filtrados:
# +------------------------+
# |Planificador Necesidades|
# +------------------------+
# |                     D5L|
# |                     D5C|
# |                     D5S|
# |                     F5P|
# |                     F5D|
# ...

# %%
from pyspark.sql.functions import current_timestamp
import re

# ================================================================
# 5. Función para limpiar nombres de columnas
# ================================================================
def clean_column_names(df):
    for old_col in df.columns:
        new_col = (old_col.replace(" ", "_")
                          .replace("/", "_")
                          .replace("(", "")
                          .replace(")", "")
                          .replace("í", "i")
                          .replace("ó", "o")
                          .replace("á", "a")
                          .replace("é", "e")
                          .replace("ú", "u")
                          .replace("ñ", "n")
                          .replace(".", "_")
                          .replace("-", "_"))
        if old_col != new_col:
            df = df.withColumnRenamed(old_col, new_col)
    return df

# ================================================================
# 6. Guardar en Lakehouse
# ================================================================
print("💾 GUARDANDO TABLAS EN LAKEHOUSE")

# COSTEADO desde Lakehouse
spark_df_costeado_filtrado = spark.sql("SELECT * FROM LH_INTELLIGENT_VISIBILITY_CARATULAS.CONTINENTAL_COSTEADO_GOVERNANCE_CA")
spark_df_costeado_final = clean_column_names(spark_df_costeado_filtrado).withColumn("ultima_actualizacion", current_timestamp())
spark_df_costeado_final.write.mode("overwrite").option("overwriteSchema", "true").saveAsTable("continental_costeado")

# COMPRAS
spark_df_compras_final = clean_column_names(spark_df_compras_filtrado).withColumn("ultima_actualizacion", current_timestamp())
spark_df_compras_final.write.mode("overwrite").option("overwriteSchema", "true").saveAsTable("continental_compras")

# ENTREGAS
spark_df_entregas_final = clean_column_names(spark_df_entregas_filtrado).withColumn("ultima_actualizacion", current_timestamp())
spark_df_entregas_final.write.mode("overwrite").option("overwriteSchema", "true").saveAsTable("continental_entregas")

# CALENDARIO (no se filtra)
spark_df_calendario_final = clean_column_names(spark_df_calendario).withColumn("ultima_actualizacion", current_timestamp())
spark_df_calendario_final.write.mode("overwrite").option("overwriteSchema", "true").saveAsTable("continental_calendario")

# DEMANDA
spark_df_demanda_final = clean_column_names(spark_df_plan_demanda_filtrado).withColumn("ultima_actualizacion", current_timestamp())
spark_df_demanda_final.write.mode("overwrite").option("overwriteSchema", "true").saveAsTable("continental_demanda")

# FACTURACION
spark_df_facturacion_final = clean_column_names(spark_df_facturacion_filtrado).withColumn("ultima_actualizacion", current_timestamp())
spark_df_facturacion_final.write.mode("overwrite").option("overwriteSchema", "true").saveAsTable("continental_facturacion")

print("\n🎯 RESUMEN DE TABLAS GUARDADAS:")
print("✅ continental_compras")
print("✅ continental_costeado")
print("✅ continental_entregas")
print("✅ continental_calendario")
print("✅ continental_demanda")
print("✅ continental_facturacion")
print("📅 Todas las tablas actualizadas con filtros: ORIGEN=IMPORTADO + Países CEAM/Andino")
# Out:
# StatementMeta(, 39d21195-a990-4930-8dfa-0a4cf2989f2b, 6, Finished, Available, Finished)
# 💾 GUARDANDO TABLAS EN LAKEHOUSE
#
# 🎯 RESUMEN DE TABLAS GUARDADAS:
# ✅ continental_compras
# ✅ continental_costeado
# ✅ continental_entregas
# ✅ continental_calendario
# ✅ continental_demanda
# ✅ continental_facturacion
# 📅 Todas las tablas actualizadas con filtros: ORIGEN=IMPORTADO + Países CEAM/Andino

# %% [markdown]
# ## Entregas + OC

# %%
# -*- coding: utf-8 -*-
# DICCIONARIO DE SKUs ACTUALIZADO - 4665 SKUs
dict_skus = {
  "ANDINO": {
    "CO": {
      "LAVA": [
        "CPAC2312NXDG0", "DMG17R8MSDAB2", "LCA13SZI1", "LCA80GZI1", "LMA0220WDGAB0",
        "LMA1120WDGAB0", "LMA180BZI0", "LMA180GZI0", "LMA4120WDGAB0", "LMA6120WDGAB0",
        "LMA79104WGAB1", "LMA79114VBAB0", "LMA79114WBAB0", "LMA8120WDGAB0", "LMA9020WDGAB0",
        "LMA9020WGAB0", "LMC46100WDAB0", "LMC48100WDAB0", "LMC48100WDAB1", "LMC70200WDAB1",
        "LMC70203WDAB0", "LMC71200WDAB0", "LMC72201WGAB0", "LMC72211WDAB0", "LMC74201WDAB0",
        "LMC74215WDAB0", "LMC75201WDAB0", "LMD1123HBAB0", "LMD3123HBAB0", "LMD3124PBAB0",
        "LMD6124HBAB0", "LMD7023PBAB0", "MCL1740GSBB0", "MCLC2040GSBB0", "MCLC2040PPDG0",
        "MCLC2040PSDG0", "MCLC2240GSBB0", "MCLC2340GPDG0", "MCLC2340GSDG0",
      ],
      "COCC": [
        "1S2HE/16", "C2Y366P2TS1", "C2Y366P3TD1", "C2Y366P4MW2", "C2Y366P4TW2",
        "CCC20ANXN-5", "CCC20GCGXN-4", "CCC20GCGXN-5", "CCC20GTGXN-5", "CCC20GTGXN-6",
        "CG6012TX0", "CG6014P3I", "CG9014P3I", "CG9016I3I", "CGCI400I0",
        "CGG6020V0", "CGG6020V1", "CGG6025V0", "CGG6025V1", "CGG7710I2",
        "CGG7715V2", "CGG8610I1", "CGG8610I2", "CGG8615V1", "CGG8615V2",
        "CGP9019I6I", "CGP9019P6I", "CGP95302MS1", "CGP95362MS1", "CGU366P2TS1",
        "CGU366P3TD1", "CGU366P4TW2", "CGU486P2TS1", "CGU486P3TD1", "CGU486P4TW2",
        "CHP90302TSS", "CHP90362TSS", "CHP95302MSS", "CHP95362MSS", "CM6017P2I",
        "CM6018PI0", "CM6030N", "CM6030PI0", "CM6035NV0", "CM6035XV0",
        "CM6040NV0", "CM6040XV0", "CM6048PIW0", "CM7648PIW0", "CM9025II0",
        "CMG6015V0", "CMG6015V1", "CMG6018V0", "CMG6018V1", "CMG6044KM-0CON",
        "CMG6044LA-0CON", "CMG6044SA-1CON", "CMG6044V0", "CMG6054FA-0CON", "CMG6054LA-0CON",
        "CMG6054SA-1CON", "CMM6054SC-0CON", "CMPUV601SSX0", "CMPUV761SSX0", "CSB913M2NS5",
        "CSB913P2NS1", "CSB913P3ND1", "CSB913P3VD1", "CSB913P4NW2", "CSB923M2NS5",
        "CSB923P2NS1", "CSB923P3ND1", "CSB923P4NW2", "CTC912P2NS1", "CTG6010AI0",
        "CTM6011IX", "CTS70DM2NS5", "CTS70DP2NS1", "CTS90DP2NS1", "CTS90DP3ND1",
        "CTS90DP4MW2", "CTS90DP4NW2", "CTS90FP2NS1", "CTS90FP3ND1", "CTS90FP4NW2",
        "CVW93613MDS", "CVW93614MWM", "EG7686SSC0", "EMC20GGXN-6", "EMC30KXX-5",
        "EMC30KXX-6", "EMC5150SNX0", "EMC5150SNX1", "EMC6050NFX0", "EMC6050NFX1",
        "EMC6060NFX1", "EMC7630NFX0", "EMC7680NFX0", "HG6040EYAI1", "HG6040GWAI1",
        "HG6045EYAI2", "HGP6065EWAI0", "HGP6065EWAI1", "HGP6065EYAI0", "HGP6065EYAI1",
        "HGP6065LWAI0", "HGP6065LWAI1", "HGP8050K1", "HGP8050KE0", "HGP8050YE1",
        "HM6013GWAI0", "HM6014EUAI0", "HM6017GWAI0", "HM6021EWAI0", "HM6022EYAI0",
        "HM6027GWAI0", "HM6028EUAI0", "HM6028EWN0", "HM6031EUAI0", "HM6045EYI0",
        "HMFM6036EI1", "IBG2040XN0", "IBG2440GN0", "IO312DVI0", "IO6056HEWI0",
        "IO6056HGWI0", "IO614PVI0", "IO8042HEYD0", "IO9019CI5I", "IOT8002I1",
        "JTS5000SNSS", "PGP64KRTIY0", "PGP7030SLSS", "PGP7036SLSS", "PGP75KMTIY0",
        "PGP75TI0", "PGP95EBG0", "PGP95EMNNY0", "PGP95IV0", "PGP95KBG0",
        "PGP95KMNNY0", "PGP96KMTIY0", "PGP96TI0", "PHP9030SJSS", "PHP9030STSS",
        "PHP9036SJSS", "PHP9036STSS", "PIP6014S", "PM302I0", "PM6042GV0",
        "PM6044ENA0", "PM6044NA0", "PM6044NF0", "PM6044NS0", "PM6046V0",
        "PM6048GV0", "PM6054NF0", "PM6054NS0", "PM6055NF0", "PM64IV0",
        "PM7650GV0", "PM7655GNV0", "PMC6043AN0", "PP9036SJSS", "PSB9120BLTS",
        "PSB9240SFSS", "PT7800SHSS", "PTS7000SNSS", "PV970NSS", "PV977NSS",
        "TX1G-6CON", "TX1G-7CON", "UVB30SKSS", "UVB36SKSS", "UVC7300SLSS",
        "UVC9480SLSS", "UVD6301SPSS", "UVD6361DPBB", "UVH13012MSS", "UVW9361BLTS",
        "UVW93642PSS", "ZDP484NGTSS", "ZGP486NDTSS", "ZGU30RSLSS", "ZGU364NDTSS",
        "ZGU36ESLSS", "ZGU486NDTSS", "ZHU30RSTSS", "ZHU36RSJSS", "ZHU36RSTSS",
        "ZSB9231NSS", "ZSB9231VSS", "ZSB9232NSS", "ZSB9232VSS", "ZTS90DPSNSS",
        "ZTS90DSSNSS", "ZV950SDSS", "ZVC48LSS", "ZWL1126SJSS",
      ],
      "GLOB": [
        "AFM38DN", "ALASKA11", "ALASKA14!", "ALASKA145B4", "ALASKA145B5",
        "ALASKA145BH", "ALASKA145BH1", "ALASKA19!", "ALASKA195BH", "ALASKA195BH1",
        "ALASKA200B4", "ALASKA200B5", "ALASKA30()", "ALASKA300B3", "ALASKA300B4",
        "ALASKA300BH", "ALASKA300BH1", "ALASKA43()", "ALASKA430B H", "ALASKA430B3",
        "ALASKA430BH", "ALASKA52()", "ALASKA520BH", "ALASKAV2()", "ALASKAV200S0",
        "ALASKAVIT", "ALASKAVIT220B1", "ALASKAVIT316CEG", "ALASKAVIT320B0", "ALASKAVIT320B1",
        "ALASKAVIT416CEG", "CCP06BP2PS1", "CCP06BP3PD1", "CCP06BP4PW2", "CCP06DP2PS1",
        "CCP06DP4PW2", "CCR06BM2PS5", "CCWK15C1WDS", "CCWK15C1WSS", "CDE06RP2NS1",
        "CDE06RP3ND1", "CDT845M5NS5", "CDT845P2NS1", "CDT845P3ND1", "CDT845P4NW2",
        "CDT858P2VS1", "CDT858P3VD1", "CEB515P3NDS", "CEB515P4NWM", "CVM9179SLSS",
        "DM1260TPSS", "DM1460TPSS", "EM02PB", "EMBL3TGS", "EMM2PB",
        "EMM2PN", "EMMCHB", "EMTLP3TB", "EMTLP3TBB", "GBF410SSPSS",
        "GBF412SSMSSX", "GBT632SSMSSEC", "GDT226SILII", "GFC525N", "GLV1460FSS",
        "GLV1890XSS0", "GW12XDB", "GW12XDBB", "GW8XDBB", "GXCFS7CCSS",
        "H32K85FX", "H43K85FFX", "H50K85FUX", "H65S80FUX", "H75S80FUX",
        "HMM07BB", "HMM07BBW", "HMM07BR", "HMM07CE", "HMM07CEBN",
        "HMM07SB", "HMM07SBW", "HMM07SJW", "HMM07SN", "HMM09NJ1",
        "HMM11NP", "HMM11NPO", "HMM11SJW", "HMM11SN", "HMM15SJW",
        "HMM15SN", "HMM70SEJ", "ICMK12X0", "IO110MDI", "IO110MDI1",
        "JES11G1", "JES70G", "JVM3160RFSS", "MGE07SEJ", "MGE09SEJ",
        "MGE11SEJ", "MGE11XAF", "MGE14SEJG", "MXCBL01D", "MXCFS7W1",
        "PBT865SSPFS", "PBT865SSWFS", "PCWK22U1WDD", "PDT145SGLBB", "PDT145SSLSS",
        "PDT715SYNFS", "PDT715SYVFS", "PEB110SFSS", "PEB160SFSS", "PEB7227ANDD",
        "PEB9159SJSS", "PLV1817XSS", "PVS06BSPSS", "PW29BS3", "PWS06DSPSS",
        "RMF02BRX", "RMF02BRX0", "RMF02BRX1", "RMF04BRX", "RMF04BRX0",
        "RMF04BRX1", "RMF04CV1", "UCC15NPRII", "ZCWK22U2WSS", "ZDBI240HII",
        "ZDBR240NBS", "ZDT165SSLSS", "ZDT800SIFII", "ZDT915SSJSS", "ZDT975SSJSS",
        "ZDT985SINII", "ZDT985SPNSS", "ZDT985SSNSS", "ZDWI240HII", "ZEB1227SLSS",
        "ZIF301NPNII", "ZWL1126SRSS",
      ],
      "REFR": [
        "CFE28TP2MS1", "CFE28TP3MD1", "CFE28TP4MW2", "IBGA230TJCG1", "IBGA247PJCT",
        "IBGA300TSCG1", "IBGA313TSCT", "IBGP360TJCG1", "IBGP420TJCG1", "IBGP438OLCT",
        "IBGU235NACT", "IBGU235TACG1", "MA0360VLCX", "MA0384XMCSN", "MQL22LEKFPS",
        "MSL480LMLPS0", "MSL480LMLSS0", "MSL480LPLPS0", "MSL480LPLSS0", "MSL504SONBS0",
        "MSL521QMLSS0", "MSL525SMNBS0", "MSL565QMLSP0", "MSL631LKLNG0", "MSL631LKLSG0",
        "MSL631LKLSP0", "MSL631LKLSS0", "MSL746IOLFS0", "MTL442LKLSS0", "PFQ25LERCDS",
        "PNL26PGKCPS", "PNM25IMKCES", "PNQ25IMPCES", "PQL22LEKFSS", "PQL26PGKCSS",
        "PQL26PGKFPS", "PSB48YSNSS", "RMA230FJCG", "RMA230FJCG1", "RMA235FJCT",
        "RMA247FJCG", "RMA247PJCG", "RMA250FJCG", "RMA250FJCG1", "RMA250FJCL1",
        "RMA255FYCU", "RMA267FBCG", "RMA267FYCC", "RMA267FYCT", "RMA267PHCG",
        "RMA267PYCC", "RMA267PYCU", "RMA300FBCG", "RMA300FJCG", "RMA300FZCC",
        "RMA305FYCC", "RMA305FYCT", "RMA310FZCC", "RMA313FBCG", "RMA313FXCC",
        "RMA313FXCT", "RMA313FXCU", "RMA313FZCC", "RMB300IZBRP0", "RMB400IABRE0",
        "RMB400IBBRP0", "RMB400IBBRX0", "RMB432PXBQP0", "RMB432PXBQS0", "RMB520IBBQX0",
        "RMB520IJBQX0", "RMB520IWBQP0", "RMB520IWBQP1", "RMC320FACG1", "RMC390FACG1",
        "RMF04BRX0", "RMP360FLCL", "RMP365FYCT", "RMP384FGCC", "RMP384FGCT",
        "RMP384FLCG1", "RMP389GCC", "RMP389GCG", "RMP389GCT", "RMP389JCG",
        "RMP400FLCG", "RMP400FLCG1", "RMP400FLCT", "RMP400FYCU", "RMP400FZCC",
        "RMP405FYCU", "RMP410FZCC1", "RMP415BCG", "RMP415GCC", "RMP415GCG",
        "RMP415GCT", "RMP415YCC", "RMP415YCU", "RMP415ZCC", "RMP420FLCG",
        "RMP420FLCG1", "RMP420FYCU", "RMP421FBCG", "RMP421FGCC", "RMP421FGCT",
        "RMP421FYCU", "RMP421FZCC", "RMP425FYCU", "RMP435FZCU", "RMP438FBCG",
        "RMP438FGCT", "RMP438FYCU", "RMP438FZCU", "RMP470BCG", "RMP470GCT",
        "RMP470YCU", "RMP470ZCB", "RMP470ZCC", "RMP470ZCU", "RMS400IBBQP0",
        "RMS400IBBRP0", "RMS400IBBRX0", "RMS510IBBQP0", "RMS510IBBQX0", "RMS510IBBRP0",
        "RMS510IFBQP0", "RMU210NACG1", "RMU210NACU", "RMU235NACG1", "RMU235NACU",
        "ZIC30GNNII", "ZIF361NPRII", "ZIK303NPPII", "ZIR240NPKII", "ZIR241NPNII",
        "ZIR301NPNII", "ZIR361NPRII", "ZISS480DNSS", "ZIW303NPPII",
      ],
      "CALE": [
        "CAGLM1005AN1", "CAGLM1505AN1", "CAGLM2005AN1", "CAGM10ANS0", "CAGM15ANS0",
        "CAGM20ANS0", "CAGM30ANS0", "CAGM35ANS0", "CDM40MPESA", "CDM40MPESD",
        "CDM80MPESD", "CIM06C2SSNA", "CIM10C2NSNA", "CIM12C2NSNA", "CMD10TFBC",
        "CMD14TFBC", "CMD6TFBC", "CMM11C1FSNA", "CMM16C1FSNA", "CMM20C1FSNA",
        "CMP10TNBC", "CMP12TNBC", "CPGM1630BN",
      ],
      "AIAC": [
        "MGI18CDBC3", "MMI09CABWCCC1", "MMI09CABWCCC8", "MMI09CDBWCCC1", "MMI12CABWCCAXC9",
        "MMI12CABWCCBC1", "MMI12CABWCCC8", "MMI12CABWCCC9", "MMI12CABWCCCHI8", "MMI12CDBWCCAXC9",
        "MMI12CDBWCCBC1", "MMI12CDBWCCC8", "MMI12CDBWCCC9", "MMI12CDBWCCCHI8", "MMI12CDMCCC10",
        "MMI12CDMCCC8", "MMI18CDBWCCAXC9", "MMI18CDBWCCC8", "MMI18CDBWCCC9", "MMI18CDBWCCCHI8",
        "MMI18CDMCCC10", "MMI18CDMCCC8", "MMI24CDBWCCAXC9", "MMI24CDBWCCC8", "MMI24CDBWCCC9",
        "MMI24CDMCCC10", "MMI36HDBWCC32C1", "MMT09CABWCCC1", "MMT09CABWCCC8", "MMT09CDBWCCC1",
        "MMT12CABWCCAXC8", "MMT12CABWCCBC1", "MMT12CABWCCC8", "MMT12CABWCCCHI8", "MMT12CDBWCCAXC8",
        "MMT12CDBWCCBC1", "MMT12CDBWCCC8", "MMT18CDBWCCAXC8", "MMT18CDBWCCC8", "MMT24CDBWCCAXC8",
        "MMT24CDBWCCC8", "MMT24CDBWCCCHI8", "PTM12CABWJM2",
      ],
      "ACCE": [
      ]
    },
    "EC": {
      "LAVA": [
        "DMG17R8MSDAB2", "LMA70200WDAB1", "LMA77113CBAB0", "LMA79113VBAB0", "LMD6124PBAB0",
        "LMDE3124PBAB0", "LMDE7023PBAB0", "LMDX1123HBAB0", "LMDX2224HBAB0", "LMDX3123HBAB0",
        "LMDX6124HBAB0", "LMDX8124HBAB0", "LME1220WDGAB0", "LME7120WDGAB0", "LME79104VBAB0",
        "LME79104WBAB1", "LME79114SBAB0", "LME9120WDGAB0", "LMH72201WBAB1", "LMH74201WDAB1",
        "LMP75201WDAB0", "MCL2040ESDG0", "MCL2040PPDG1", "MCL2040PSBB0", "MCL2440EPDG0",
        "MCL2440ESDG0", "MCL2440PSBB0", "SME17R8MSDBP0", "SME47N8MSBBP0", "SMG17R8MSBAB0",
        "SMG26N5MNBAB0", "SMG47N8MSBAB0",
      ],
      "COCC": [
        "CD5115AN0", "CD5120SG0", "CD5120SN0", "CD51TBX0", "CDM6010AI0",
        "CGG7710IP0", "CGG8610IP0", "CGI1219S", "CGP9016I3I", "CGP9019P6I",
        "CMG6054LA-1EC", "CMG6054LA-2EC", "CMG6054SA-3EC", "CMP9002I", "CMPUV601SSX0",
        "CMPUV761SSX0", "EG7686SSC0", "EM5115SG0", "EM5115SG1", "EM5120SG1",
        "EM5120SX1", "EM5120SX2", "EM5130FX0", "EM5130FX1", "EM5530FN0",
        "EM6010AG0", "EM6015SG0", "EM6020SG0", "EM6020SG1", "EM6030SG0",
        "EM6030SG1", "EM6040FG1", "EM6040FG2", "EM6040FN0", "EM6060FX2",
        "EM6060FX3", "EM6095FX1", "EM6095FX2", "EM7610SG0", "EM7615SG0",
        "EM7620FX0", "EM7625FX0", "EM7630FX0", "EM7635FX0", "EM7640FX1",
        "EM7670FX1", "EMH7614DATMSS0", "HG6040EYAI1", "HG6045EYAI2", "HGP6065EYAI0",
        "HGP6065LXAI0", "HGP8050K1", "HGP8050KE0", "HM6027GWAI0", "HM6028EZAI0",
        "HM6031EZAI0", "PGP75KMTIY0", "PGP75TI0", "PGP95EBG0", "PGP95EMNNY0",
        "PGP95IV0", "PGP95KBG0", "PGP95KMNNY0", "PGP96KMTIY0", "PGP96TI0",
        "PGS930YPFS", "PHP774DMBB", "PM6032EV0", "PM64IV0", "PP932SMSS",
        "TX5120EX2", "TX5120EX3", "TX5120EX4",
      ],
      "GLOB": [
        "AFM38DN", "AFM38DNEC", "ALASKA145B5", "ALASKA145BH", "ALASKA195BH",
        "ALASKA200B5", "ALASKA300B4", "ALASKA300BH", "ALASKA300BH1", "ALASKA430BH",
        "ALASKAH145B0", "ALASKAH200B2", "ALASKAH320B2", "ALASKAVIT220B1", "ALASKAVIT316CEG",
        "ALASKAVIT320B1", "ALASKAVIT416CEG", "CEB515P2NSS", "EMBL1TN", "EMBL3TGS",
        "EMDPCCB1", "EMM2PB", "EMM2PN", "EMMCHB", "FUF14SVRWW",
        "GBF410SSPSS", "GBF412SSMSSX", "GBT632SSMSSEC", "GFC720N", "GW12XDBB2",
        "GW8XDBB2", "GXCFS7CCSS", "H,TM09N", "HMM07CEBN", "HMM09NJ1",
        "HMM11NPO", "HTM10LN", "HTM10LN1", "JES11SG", "JES14SG",
        "JES70SE", "JES70W", "JVM3670SK", "MGE07SEJ", "MGE09SEJ",
        "MGE11SEJ", "MGE11XAF", "MGE14SEJG", "MXCBL01D", "MXCFS7CCSS",
        "PBT865SSPFS", "PEB110SFSS", "PEB160SFSS", "PLV1817XSS", "RMF0260XMXX3",
        "RMF04ERB0", "RMF04ERX0", "XO1120MD1", "ZEB1227SLSS",
      ],
      "REFR": [
        "DUREX264PHET", "LMD6124PBAB0", "LMDE3124PBAB0", "LMDE7023PBAB0", "LMDX1123HBAB0",
        "LMDX3123HBAB0", "LMDX6124HBAB0", "LMDX8124HBAB0", "LME7120WDGAB0", "LME9120WDGAB0",
        "MSE480LMLPS0", "MSE480LMLSS0", "MSE480LPLPS0", "MSE480LPLSS0", "MSE521QMLSS0",
        "MSE565QMLSP0", "MSL631LKLNG0", "MTL442LKLSS0", "PFQ25LERCDS", "PNQ25IMPCES",
        "PQL22LEKFSS", "PQL26PGKCSS", "PQL26PGKFPS", "RMA230FVEL1", "RMA244PJEG",
        "RMA250FHEL1", "RMA250PHEL1", "RMA250PJEG1", "RMA250PJEU", "RMA264PHEU",
        "RMA264PJET", "RMA264PVEG", "RMA264PYEC", "RMA264PYEG", "RMA264PYEU",
        "RMA313FJEG", "RMA313FJET", "RMA313FWET", "RMA313FXEC", "RMA313FXEU",
        "RMA430FJEG", "RMA430FJET", "RMA430FWEU", "RMA440FZEU", "RMB300IZBRP0",
        "RMB432PXBQS0", "RMB520IJBQX0", "RMP378FGEU", "RMP378FHEU", "RMP378FJET",
        "RMP378FLEG", "RMP378FLEU", "RMP389GEU", "RMP389HEU", "RMP389JEG",
        "RMP389JET", "RMP415GEC", "RMP415GEU", "RMP415HEU", "RMP415JET",
        "RMP415YEU", "RMP418FGEU", "RMP418FJET", "RMP438FGEU", "RMP438FJET",
        "RMP470JET", "RMP470YEU", "RMP736FHEL1", "RMP736FYEU1", "RMP840FLEL1",
        "RMP840FYEU1", "RMP840FZEC1", "RMP942FJLEL1", "RMP942FYEU", "RMS510IBBQX0",
      ],
      "CALE": [
      ],
      "AIAC": [
        "MMI12CDBWCCE8", "MMI24CDBWCCE8", "MMT12CDBWCC32BN1", "MMT12CDBWCCAX8", "MMT12CDBWCCE8",
        "MMT18CDBWCCAX8", "MMT18CDBWCCE8", "MMT24CDBWCCAX8", "MMT24CDBWCCE8", "PTM12CABWJM2",
      ],
      "ACCE": [
      ]
    },
    "PE": {
      "COCC": [
        "CGG6025V0", "CGG6025V1", "CGG8610I1", "CGG8610I2", "CGG8615V1",
        "CGG8615V2", "CGP9019P6Y", "CGP9536SLSS", "CGPI9007IP0", "CM6016PI0",
        "CM6018PI0", "CM6018PIY0", "CM9016PI0", "CM9018PIY0", "CME6050CSYX0",
        "CME6080CFYX0", "CMG6015V0", "CMG6044LC-0PE", "CMP3020FN0", "CMP3020FN1",
        "CMP3050FX0", "CMP5100AB0", "CMP5140FX0", "CMP5140FX1", "CMP5545FX0",
        "CMP6010FG0", "CMP6010FG1", "CMP6010FN0", "CMP6011FG0", "CMP6011FG1",
        "CMP6012AG0", "CMP6012AG1", "CMP6014AG0", "CMP6014AG1", "CMP6015SG0",
        "CMP6020FG0", "CMP6020FG1", "CMP6030FX0", "CMP6030FX1", "CMP6035FX0",
        "CMP6035FX1", "CMP6040FN0", "CMP6040FX0", "CMP6040FX1", "CMP6060FX0",
        "CMP6060FX1", "CMP6085FX0", "CMP6085FX1", "CMP7620FX0", "CMP7625FX0",
        "CMP7628FX0", "CMP7630FX0", "CMP7640FX0", "CMP7670FX0", "CMU6020PB0",
        "CMU6020PI0", "CMU9020PI0", "EG7686SSC0", "EME7675CSYX1", "EME7682CFYX0",
        "EME7682CFYX1", "EMH7602JSSY0", "EMH7612DSSY0", "EMH7614DATBS0", "EMH7614DATMSS0",
        "EMP5120GP0", "EMP5120GP1", "EMP5120GP2", "EMP7620SX0", "HG6045EYAI2",
        "HM6022EYAI0", "HM6028EYAI0", "HVGP4561YI", "IO905I0", "JGP3036SLSS",
        "JGP5030SLSS", "JGP5530SLSS", "JGP5536SLSS", "JP3530SJSS", "JP3536SJSS",
        "JTS3000SNSS", "JTS5000SNSS", "PGP7030SLSS", "PGP7036SLSS", "PGP75TI0",
        "PGP9030SLSS", "PGP9036SLSS", "PGP95EBG0", "PGP95KBG0", "PM6044PF0",
        "PM6045GV0", "PM6055PF0", "PM8655GV0", "PTS7000SNSS", "PV977NSS",
        "TX5110P1", "TX5110P2", "UVW9361BLTS", "ZET1PHSS", "ZGU36RSLSS",
        "ZSC1202JSS", "ZSC2202JSS", "ZV800SJSS", "ZV850SPSS", "ZV925SLSS",
      ],
      "GLOB": [
        "ALASKAVIT316PG", "ALASKAVIT416PG", "CHM200PB1", "CHM200PB2", "CHM200PB3",
        "CHM300PB2", "CHM300PS2", "CHM320PB1", "CHM320PS1", "CHM430PB2",
        "DAMYPRB0", "GDT225SSLSS", "GDT635HSJSS", "GFC525V", "GWS04HAESS",
        "GXCF05PFS2", "HMM07PBN", "HMM09PNJ", "HMM11PNPO", "HMM20PEB",
        "HMM20PEE", "HMM20PEG", "HMM23PSX", "HMM25PSX", "HMM28PSX",
        "HMM31PSX", "JES1495PSK", "MXCF05PFS", "PCR06WATSS", "PEB7227SLSS",
        "PEB9159SJSS", "RMF04PRB0", "RMF04PRX0", "RMF04PV0", "WDP6001I",
        "ZEB1227SLSS", "ZIDS240HSS", "ZIFS360NHLH",
      ],
      "LAVA": [
        "CLME70204BBB0", "CLMG70204BBB0", "CLMG70204DBB0", "CLPG70204DBB0", "LMA0120WPBB0",
        "LMA100BXI0", "LMA100GXI0", "LMA105BXI0", "LMA1220WDGBB0", "LMA160BXI0",
        "LMA160SXI0", "LMA4120WDGBB0", "LMA4120WPBB0", "LMA48100WDBB0", "LMA6120WDGBB0",
        "LMA6120WPBB0", "LMA70200WDBB1", "LMA72200WDBB1", "LMA72200WDBB2", "LMA8120WDGBB0",
        "LMA9020WGBB0", "LMA95BXI", "LMAP0120WDGBB0", "LMAP1010WBBB0", "LMAP1012WBBB0",
        "LMAP1015WGBB0", "LMAP3120WDGBB0", "LMAP4110WGBB0", "LMAP4120WGABB0", "LMAP4120WGBB0",
        "LMAP6110WBBB0", "LMAP6115WGBB0", "LMAP6120WGBB0", "LMAP9020WGBB0", "LMD3124PBBB0",
        "LMD6124PBBB0", "LME1220WDGAB0", "MCLP2440ESBB0", "MCLP2440PPDG0", "MCLP2440PSBB0",
        "MCLP2440PSDG0", "SEM090VBBB0", "SEM81BDBB", "SEM81BDGB", "SMG17R8MSDBB0",
        "SMG47N8MSBBB0", "SMG47N8MSDBB0", "SMG47N8MSGBB0",
      ],
      "REFR": [
        "MSC518LKRSS0", "MSD480LMRPS0", "MSD480LMRSS0", "MSD480LPRPS0", "MSD480LPRSS0",
        "MSD504SORBS0", "MSD518LKRSS0", "MSD525SERBS0", "MSD565QMLSP0", "MSD565QMLSS0",
        "MSD631LKLNG0", "MTD442LKRSS0", "PFR26JSRFFS", "PRD22LEKFSS", "RMA230FVPL1",
        "RMA230PJPG", "RMA250FVPG1", "RMA250FVPL1", "RMA250FYPG", "RMA255FYPG",
        "RMA264PYPC", "RMA300FBPG1", "RMA305FBPU", "RMA305FWPC", "RMA305FWPT",
        "RMA310FZPC", "RMA313FJPC", "RMA520FVPG1", "RMB300IZPRP0", "RMB315PTPRO0",
        "RMB400IAPRP0", "RMB432PXPRP0", "RMB432PXPRS0", "RMB520IBPRP0", "RMC320FAPG",
        "RMC390FAPG", "RMN220PVPRX0", "RMP360FJPC1", "RMP360FYPU", "RMP389JPG",
        "RMP405FJPC", "RMP405FYPU", "RMP410FZPC", "RMP415GPG", "RMP415YPC",
        "RMP415ZPC", "RMP420FLPG1", "RMP425FJPC", "RMP425FJPT", "RMP470YPC",
        "RMP942FLPG1", "RMU202PXPRS0", "RMU202PXPRS1",
      ],
      "CALE": [
      ],
      "AIAC": [
        "MMI09CDBWCCC1", "MMI12CDBWCCBC1", "MMT09CDBWCCC1", "MMT12CDBWCCBC1", "MMT12CDBWCCC8",
        "MMT12CDBWCCCE8", "MMT18CDBWCCC8", "MMT18CDBWCCCE8",
      ],
      "ACCE": [
      ]
    },
    "CL": {
      "COCC": [
        "ANDES60TX3", "ANDES7620AG0", "ANDES7650FX0", "ANDES7650FX1", "ANDES7670FX0",
        "ANDES7670FX1", "ANDES76HG0", "CG6003TX0", "CM6045XV0", "CM6048PIX0",
        "CM6048PNX0", "CMC20ABX-6", "CMC20ABX-7", "CMC20AXX-1", "CMC20AXX-2",
        "CMC5100NA0", "CMC5100NA1", "CMC5110AX0", "CMC5110AX1", "CMC5115AX0",
        "CMC5515GCH-2", "CMC5530AG0", "CMC5530AG1", "CMC5540FX0", "CMC5540FX1",
        "CMC5550AX0", "CMC5560FX0", "CMC5560FX1", "CMC7660FX1", "CMG6044LD-1CL",
        "CMG6044SD-0CL", "CMG6044SD-1CL", "HM6018EXAI0", "HM6031EXAI0", "HM6045EXN0",
        "PG6040EVN0",
      ],
      "GLOB": [
        "FDHM150BY0", "FDHM150BY1", "FDHM150BY2", "FDHM200BY0", "FDHM200BY1",
        "FDHM200BY2", "GLV14FSITSS0", "HMM07CHBN", "HMM09CHNJ", "MLV14FSITSS0",
        "RMF02LRX0", "RMF04HV0", "RMF04LRX0",
      ],
      "LAVA": [
        "LMA0920WBCL0", "LMA0920WGCL0", "LMA2120WDGCL0", "LMA4120WDGCL0", "LMA5120WDGCL0",
        "LMA6120WDGCL0", "LMA6120WGCL0", "LMA7120WDGCL0", "LMA8120WDGCL0", "LMA8120WGCL0",
        "LMA9020WDGCL0", "LMA9120WDGCL0", "LMA9520WDGCL0", "MCL2040EEBBY0", "SEM010VBCL0",
        "SEM010VDCL0", "SEM011VBCL0", "SEM011VDCL0", "SEM101BDBY", "SEM101BDBY0",
        "SEM81BDBY", "SEM81BDGY", "SME26N5MNBCL0", "SMG26N5MNBCL1",
      ],
      "REFR": [
        "GRC22LFKFSS", "GRC26FGKFSS", "GRC26FGMFPS", "MSC480LKRPS0", "MSC518LKRSS0",
        "MSC525SERBS0", "MSC631LKLNG0", "MTC442LKRSS0", "PFO26JSRFFS", "PWO19JSRFFS",
        "RMA250PHUG1", "RMA250PVUG", "RMA255PJUC", "RMA255PYUU", "RMA300FWUC",
        "RMA300FWUT", "RMB176PXLCX0", "RMB1952BLCP0", "RMB276PXLCX0", "RMB300IZLRP0",
        "RMB300IZLRX0", "RMB302PXLRS0", "RMB426PXLRS0", "RMB432PXLRS0", "RMN220PVLRX0",
        "RMN222PXLRS0", "RMP400FHUG1", "RMP400FYUC", "RMP400FYUT", "RMP410FZUC",
        "RMP410FZUU", "RMS510IBLRP0",
      ],
      "CALE": [
      ],
      "AIAC": [
        "MMI09HDBWCA32CH1", "MMI12HDBWCA32CH1", "MMI18HDBWCA32CH1", "MMI24HDBWCA32CH1",
      ],
      "ACCE": [
      ]
    },
    "AR": {
      "COCC": [
        "AEDR60CNV", "AEGE62PV", "AEGE62VN0", "AGDR60CNV", "AGDR60EIA",
        "AGDR60EIA1", "AGDR76CIA", "AGGE62IV", "AGGE62VN0", "AGGE76I0",
        "CD5003MI", "CD5502AB", "CD5502AI", "CD5502MB", "CD5502MI",
        "CD5505AI", "CD5507AI", "CD5507MI", "CD5602AB0", "CD5602AI0",
        "CD5602AN0", "CD5603AB0", "CD5603AI0", "CD5603AN0", "CD5614AI0",
        "CD5617AI0", "CD6007MI", "CG756I", "CG760I", "CP6855AB",
        "CP6855AI", "CP6855B", "CP6855I", "CP756AI", "CP9656AI",
        "CP9656I", "CP9750I", "CRDR60IA", "CRDR90IA", "CRGE60I",
        "CTGE60I0", "CTGE90I0", "CUDR604BA", "CUDR604IA", "CUDR604NA",
        "CVGE90I", "HD60EGCV0", "HEDR600CI", "HEDR600MI", "HEDR601CN",
        "HEDR601MI", "HEGE6050I", "HEGE6055I", "HG6018EVAI0", "HG6035EVAI0",
        "HGDR601CN", "HM60EGCI0",
      ],
      "GLOB": [
        "601400511", "601400512", "601400592", "601400593", "601400594",
        "601400595", "601400611", "601400612", "601400621", "601400627",
        "601400629", "601400673", "601400674", "601400677", "601400781",
        "601400782", "601400784", "601400785", "601400786", "601400787",
        "601400788", "601400789", "601400790", "601400791", "601400792",
        "601400793", "601400794", "601400796", "601400801", "601400802",
        "601400807", "601400808", "601400809", "601400810", "601400811",
        "601400824", "601400828", "601400829", "601400830", "601400852",
        "601400853", "601400854", "601400855", "601400856", "601400890",
        "601400899", "601400915", "601400916", "601400917", "601400918",
        "601400919", "CVDR08CN0", "CVDR12CN0", "FHDR143CB", "FHDR293CB",
        "FHP220B", "FHP300B", "FHP420B", "HMD20ARBB0", "HMD20ARNJ0",
        "HMD20ARSB0", "HMD25ARSB0", "HMD30ARSJ0", "HPK90B", "LVDR1306CB0",
        "LVDR1306CI0", "LVDR1406CB0", "LVDR1406CI0", "LVDR1506CI0", "RDF04LGAS0",
      ],
      "LAVA": [
        "700100711", "700200378", "700200380", "700200382", "701000860",
        "701000862", "701000964", "701000976", "701100040", "701100108",
        "701100124", "701100150", "701100156", "701100182", "701100196",
        "701100198", "701100204", "701100206", "701100212", "701100278",
        "701100280", "701100282", "701100284", "701100286", "701500000",
        "701500001", "709802016", "709802457", "709802585", "709802587",
        "709802594", "709802832", "709802833", "709802834", "709802836",
        "709802837", "709802838", "709802840", "709802906", "709803246",
        "709803250", "709803251", "709803252", "709803386", "709803398",
        "709803399", "709803422", "709803423", "709803424", "709803430",
        "709803431", "709803443", "709803444", "709803596", "709803598",
        "709803599", "709803600", "709803612", "709803752", "709803766",
        "709803783", "709803804", "709803805", "709803809", "709803812",
        "709803826", "709803827", "709803828", "709803859", "709803860",
        "709803861", "709803862", "709803863", "709803864", "709803903",
        "709803973", "709803988", "709803989", "709803990", "709803995",
        "709803996", "709803997", "709804000", "709804028", "709804035",
        "709804036", "709804037", "709804038", "709804039", "709804052",
        "709804095", "709804199", "709804218", "709804347", "709804348",
        "709804376", "709804406", "709804407", "709804422", "709804442",
        "709804443", "709804444", "709804466", "709804468", "709804543",
        "709804580", "709804581", "709804582", "709804594", "709804612",
        "709804613", "709804614", "709804639", "709804656", "709804659",
        "709804660", "709804673", "709804674", "709804675", "709804676",
        "709804677", "709804678", "709804679", "709804680", "709804681",
        "709804698", "709804699", "709804700", "709804789", "709804824",
        "LCFDR0608LB0", "LCFDR0609LB0", "LCFDR0610LB0", "LCFDR0710SB0", "LCFDR0814SB0",
        "LCFDR0814SG0", "LCFDR1012SB0", "LFDR0606LB0", "LFDR0608LB0", "LFDR0609LB0",
        "LFDR0610ISB0", "LFDR0710ISB0", "LFDR0710ISG0", "LFDR0710SB0", "LFDR0814SB0",
        "LFDR0814SG0", "LFDR0914ISG0", "LFDR1012SB0", "LFDR1012TG0", "LFDR1114ISG0",
        "LFDRI0710SB0", "LFJA0914SB0", "LFMA0709LB0", "LFMA0810SB0", "LFMA1014SB0",
        "LFMA1312SG0", "LPDR0665ILG", "LPDR0865ILG", "LPDR1165LG", "LPDR1165LG0",
        "LRDR56SB0", "LRDR57SB0", "LRJM56SB0", "LRPK56SB0", "LRPK57SB0",
        "LRSH56SB0", "LSCDR0805SB0", "LSCDR0805SG0", "LSCDR1006SG0", "LSCDR1106I",
        "LSCDR1208SG0", "LSCPK1106I", "LSDR0680TB0", "LSDR0680TS0", "LTDR0608PB0",
        "LTDR0610PB0", "LTDR0714PBI0", "LTDR0714PGI0", "LTDR0810PB0", "LTDR0810PI0",
        "LTDR67SB0", "LTDR79SB0", "LTDRI0714PB0", "LTDRI0714PG0", "PRIMMA5N",
        "SCPK07B", "SCPK07M", "SED090VBCL0", "SED090VGCL0",
      ],
      "REFR": [
        "DSP480LKRSS0", "DSP610IORSS0", "DTP458BKRSS0", "DTP469LKRSS0", "GEPS6FGKFSS",
        "HDR120F00B", "HDR120F00N", "HDR120F00S", "HDR280F00B", "HDR280F30PB",
        "HDR280F50B", "HDR280F50PB", "HDR300N00B", "HDR300N00M", "HDR300N30B",
        "HDR300N30M", "HDR320F00N", "HDR320F00S", "HDR320F50E", "HDR320F50N",
        "HDR320F50NE", "HDR320F50S", "HDR370F00B", "HDR370F00S", "HDR370F11S",
        "HDR370F50B", "HDR370F61E", "HDR370F61S", "HDR380N12M", "HDR380N12N",
        "HDR400F00B", "HDR400F00S", "HDR400F11N", "HDR400F11S", "HDR400F30B",
        "HDR400F30E", "HDR400F30S", "HDR400F41E", "HDR400F41N", "HDR400F41S",
        "HDR420N00B", "HDR420N00M", "HDR420N30B", "HDR420N30M", "HDR430N12M",
        "HDR430N42M", "HETOKMAGNA350", "HETOKMAGNA350N", "HETOKMAGNA360", "HGE455M12L",
        "HME280F00B", "HME320F00S", "HPK120P00B", "HPK120P00S", "HPK120P00S02",
        "HPK135B01", "HPK135B01-C", "HPK135M", "HPK135M00B01", "HPK135MA00B01",
        "HPK135P00B01", "HPK136M00N01", "HPK136M00S01", "HPK136S01", "HPK141M00B",
        "HPK141M10S", "HPK151M00B", "HPK151M11N01", "HPK151M11S", "HPK151M11S02",
        "HPK350M00B", "HPK350M00L", "HPK450M00B", "HPK450M00L", "HTH135M00B01",
        "JM350BLANCO", "MD-HFH340MK", "MD-HFH400MK", "MD-HFH400NG", "MD-HFHIN340MK",
        "PQP458BKRSS0", "RDA250FVRT", "RDA300FBRT", "RDA300FHRT", "RDP400FZRT",
        "RDP410ZRT", "RENX24281FHS", "RENX24281FHW", "RENX24301FHS", "RGA300FHRE",
        "RGS1951BGRX0", "RRS1540BGRX0", "RZB210PVARX0", "RZB520IJARX0", "RZD215PVARX0",
        "RZN320PCARX0", "RZS510IBARX0", "YEP26FGTFSS", "YRP26FGTFSS",
      ],
      "CALE": [
      ],
      "AIAC": [
      ],
      "ACCE": [
      ]
    }
  },
  "CEAM": {
    "CR": {
      "REFR": [
        "CFE28TP2MS1", "CFE28TP3MD1", "CFE28TP4MW2", "CWE19SP3ND9", "CWE23SP2MS1",
        "CWE23SP4MW2", "GNM26AEKFSS", "GNM26AETFSS", "HBM425EMNSS0", "HQM458BKNSS0",
        "HSM518HMNSS0", "HSM541HMNSS0", "MSM480LKLSS0", "MSM504SONBS0", "MSM544LMLSS0",
        "MSM631LKLNG0", "MSM631LKLSS0", "MSM746IOLFS0", "MSM746LIOLFS0", "MTM482SENSS0",
        "PDF21EYRCFS", "PDM21ESKCSS", "PFF25LYRCFS", "PFM25LSKCSS", "PNF25FYRCFS",
        "PNM22LETFSS", "PNM25FSKCSS", "PNM26PGKCSS", "PNM26PGLCPS", "PNM26PGTCFS",
        "PNM26PGTFPS", "RMA1230PVCAE", "RMA1230PVCAG1", "RMA1250FACAE", "RMA1250FJCAU",
        "RMA1250PJCAU", "RMA1250PVCAE", "RMA1300FHCAE", "RMA1300FXCAU", "RMA1300FYCAE",
        "RMA230PVCRE", "RMA230PVCRG1", "RMA230PVMRE1", "RMA230PVMRG1", "RMA250FAMRE1",
        "RMA250PJCRE", "RMA250PJCRU", "RMA300FBNG", "RMA300FXCRU", "RMA300FXNU",
        "RMA300FYCRE", "RMA300FYMRE0", "RMA300FYMRE1", "RMA300FZCRU", "RMA300FZMRX0",
        "RMA300FZNU", "RMB300IZMRP0", "RMB300IZMRX0", "RMB400IBMRP0", "RMB400IBMRX0",
        "RMB520IBMRP0", "RMB520IBMRP1", "RMB520IBMRX1", "RMC181PXCRB0", "RMC181PXCRX0",
        "RMC181PXMRX0", "RMC181PYMRX0", "RMD165PVCRB0", "RMD165PVCRS0", "RMP1400FJCAU",
        "RMP370GCAT", "RMP400FHCRU", "RMP400FJCRU", "RMP400FJNU", "RMP400FZNU",
        "RMP410FZNU", "RMP410JCAU", "RMP410ZCAU", "RMP420FYCRU", "RMP420FYNU",
        "RMP435FZNC", "RMP435FZNU", "RMP450ZCAU", "RMS1951AMXE0", "RMS400IAMRE0",
        "RMS400IAMRX0", "RMS400IBMRX0", "RMS510IAMRX0", "RMS510IBMRX0", "RMS510IXMRX0",
        "RMT510RXMRE0", "RMU210FANE", "RMU210FANU", "RTA230FVCRG0", "RTA230FVMRG0",
        "RTA250PJCRG", "RTA250PJNG", "RTA300FHMRE1", "RTA300FYCRE", "RTP400FJCRE",
        "RTP400FJNL", "RTU210NACAE", "RTU210NANB", "RTU210NANE", "RTU290NACRE",
        "RTU290NANE", "ZIF241NPNII", "ZIF361NPRII", "ZIR241NPNII", "ZIR301NPNII",
        "ZIR361NPRII", "ZISS420DNSS", "ZISS480DNSS", "ZWE23NSTSS", "ZWE23NSYSS",
      ],
      "LAVA": [
        "CHAC2186NXGG0", "CPA2412NXDG0", "DME17R8MSDBP1", "DME47N8MSDBP0", "GFD55ESSNWW",
        "GFW550SSNWW", "GFW850SPNRS", "LGA71215CBAB0", "LGA72214CBAB0", "LGA74215WBAB0",
        "LGA79113CBAB0", "LGH72201WBAB0", "LGH73201WBAB0", "LHA9120WGAB0", "LMA0220WDGAB0",
        "LMA46102VBAB0", "LMA5120WPAB0", "LMA6120WDGAB0", "LMA70200WDAB1", "LMA70214CBAB0",
        "LMA70215WBAB0", "LMA72200WDAB0", "LMA72215CBAB0", "LMA72215WBAB0", "LMA74215WBAB1",
        "LMA74215WDAB0", "LMA74215WDAB1", "LMA76102CBAB0", "LMA77113CBAB0", "LMA78113CBAB0",
        "LMA79113VBAB0", "LMA8120WDGAB0", "LMC48100WDAB0", "LMD2200B0", "LMDX1123HBAB0",
        "LMDX2224HBAB0", "LMDX3123HBAB0", "LMDX6124HBAB0", "LMDX8124HBAB0", "LME79104VBAB0",
        "LME79104WBAB1", "LMH72201WBAB0", "LMH72201WBAB1", "LMH74201WDAB0", "LMH74201WDAB1",
        "LMP75201WDAB0", "LMP75205WDAB0", "LMX70214WDAB0", "MCL2040EPDG0", "MCL2040ESBB0",
        "MCL2040ESDG0", "MCL2040PSBB0", "MCL2040PSDG0", "MCL2440EPDG0", "MCL2440ESBB0",
        "MCL2440ESDG0", "MCL2440PSBB0", "MCL2440PSDG0", "PFD87ESPVRS", "PFW870SPVRS",
        "SGE47N5MSSBT0", "SGE47N5XNSBH0", "SGG47N5MSSAB0", "SGG47N5XNBAB0", "SME17R8MSBBP0",
        "SME17R8MSDBP0", "SME27N5MSBBP0", "SME47N8MSBBP0", "SME47N8MSBBT0", "SME47N8MSDBP0",
        "SME47N8MSDBT0", "SMG27N5MSBAB0", "SMG47N8MSBAB0",
      ],
      "GLOB": [
        "AFM38DN", "CCWK15C1WSS", "CCWK15C1WWM", "CDT828P2VS1", "CDT858P3VD1",
        "CDT875P4NW2", "CDT888P4VW2", "CEB515P2NSS", "CEB515P4NWM", "CHC11BPL5",
        "CHC11BPS0", "CHC15BPL4", "CHC25BPL2", "CHC5BPL40", "CHC5BPS1",
        "CHC7BPL30", "CHC7BPS1", "CHC9BPL3", "CHC9BPS1", "CHM11BPL4",
        "CHM11BPL5", "CHM11PHL0", "CHM15BPL4", "CHM15PHL0", "CHM25BPL1",
        "CHM25BPL2", "CHM25PGL0", "CHM5BPL3", "CHM5BPL40", "CHM5PPL0",
        "CHM7BPL2", "CHM7BPL30", "CHM7PPL0", "CHM9BPL4", "CHM9PPL0",
        "CK1UP150RW2", "CVM517P2RS1", "EMM2PB", "EMM2PN", "GBF410SSPSS",
        "GBP655SSPSS", "GLV1460FSS", "GW8XDBB2", "HLV0845FSSS", "HMM07BJ",
        "HMM07PJB", "HMM07PJN", "HMM09NJ", "HMM114SEJ", "HMM70BS",
        "HMM70SEJ", "HMM70SW", "IO110MDI", "IO160MDI", "IO1702LI6",
        "IO1716LI0", "JES1153SFE", "JES11W", "JES14W", "JES70SE",
        "JES70W", "JVM3162RJSS", "MGE07SEJ", "MGE09SEJ", "MGE14XEJG",
        "MXCFS7CCSS", "PBT865SMPES", "PBT865SSPFS", "PCWK22U1WDD", "PEB110SFSS",
        "PEB160SFSS", "PEB7227ANDD", "PES7227SLSS", "PVM9215SKSS", "PW29BS3",
        "QDP225SSPSS", "RMF0260XMXB3", "RMF0260XMXX3", "RMF0411PYMB0", "RMF0411PYMX0",
        "UCC15NPRII", "VM2164LB0", "VM3164LB0", "ZCWK22U2WSS", "ZDT925SINII",
        "ZDT925SPNSS", "ZDT925SSNSS", "ZDWR240NBS", "ZIF301NBRII", "ZIF301NPNII",
      ],
      "COCC": [
        "C2S900P2MS1", "C2Y366P3TD1", "CA20TBX0", "CEP90302TSS", "CEP90361TBB",
        "CES700P2MS1", "CES700P4MW2", "CGP70302NS1", "CGP70362NS1", "CGP9019I6I",
        "CGP9019P6I", "CGP95302MS1", "CGS700P2MS1", "CGS700P4MW2", "CGU366P2TS1",
        "CM6045UIW0", "CM7618PIW0", "CM7645UGW0", "CM7645UIW0", "CM7645UNW0",
        "CM7648PIW0", "CMA3010AG0", "CMA3020FG0", "CMA3020FN0", "CMA3020FX0",
        "CMPU761GX0", "CMPU761NX0", "CMPUV601SSX0", "CMPUV761SSX0", "CTS70DP2NS1",
        "CTS90DP3ND1", "CTS90DP4NW2", "CTS90FP2NS1", "CTS90FP4NW2", "CVW73612MSS",
        "CVW73614MWM", "CVW93044PWM", "EAE5020BSS0", "EM5041BAIS0", "EM5041BAIS1",
        "EM5043BFIS1", "EM5060CFIX0", "EM6032CAIS0", "EM6038CFIX0", "EM7622BAPS2",
        "EM7641BAIS1", "EM7655CSIN0", "EM7657CSIS1", "EM7659BFIX0", "EM7659BFIX2",
        "EM7660CFIX2", "EM7660CFIX3", "EM7690CFIX2", "EMA5105SN0", "EMA5105SN1",
        "EMA5110SG0", "EMA5110SG1", "EMA5130FX0", "EMA6030AG0", "EMA6030SG1",
        "EME5025BSS0", "EME5040BVS0", "EME6063BVX0", "EME7620BSFL0", "EMH7602DSS0",
        "EMH7602JBS0", "EMH7602JS0", "EMH7602JSS0", "EMH7613DATSS0", "EMH7613DTSS0",
        "EMH7614DATBS0", "EMH7614DATMSS0", "EMH7614DATSS0", "HGP6065EWAI0", "HGP6065EWAI1",
        "HGP8050KE0", "HGP8050YE1", "HM6021EWAI0", "HM6031EUAI0", "HM6031EZAI0",
        "IO6040EVN0", "IO6056HEWI1", "IO6056HGWI1", "IO6065HEYR0", "IO64TI0",
        "IO75TI0", "IO7650EVN0", "IO7686SS0", "IO7690ESS0", "IO8042HEYD0",
        "IO8042HEYD1", "IO9014ICSSS0", "IO96TI0", "JBS360RRSS", "JBS360RTSS",
        "JCB810SKSS", "JCB820SKSS", "JCB830SKSS", "JCB830STSS", "JCB840SKSS",
        "JCB840STSS", "JCB870STSS", "JCBS630SVSS", "JCBS631SFSS", "JGB735SPSS",
        "JGBS66REKSS", "JP3030SWSS", "JTS3000SNSS", "JTS5000SNSS", "JTS5000SVSS",
        "P2S930YPFS", "PGP75KMTI0", "PGP75TI0", "PGP95EBG0", "PGP95KBG0",
        "PGP95KMNN0", "PIP8014", "PM302I0", "PM6040EVN0", "PM6044PF0",
        "PM64IV0", "PMI6055PF0", "PP7030SJSS", "PP930SMSS1", "PP936SMSS1",
        "PTS7000SNSS", "UVC9300SLSS", "UVC9360SLSS", "UVC9480SLSS", "WEM5044CAIB0",
        "WEM7643CAIS1", "ZDP366NTSS", "ZDP484NGTSS", "ZDP486NDTSS", "ZGP366NTSS",
        "ZGU30RSLSS", "ZGU364NDTSS", "ZGU366NTSS", "ZGU36ESLSS", "ZHU30RDTBB",
        "ZHU30RSTSS", "ZHU36RSTSS", "ZSB9231NSS", "ZSB9232VSS", "ZTS90DPSNSS",
        "ZTS90DSSNSS", "ZTSX1FPSNSS", "ZVW1480SPSS",
      ],
      "CALE": [
        "CDM40SLP", "CDM80SLP", "CIM062SLP", "CIM102SLP", "CIM11KWCA2SSE",
        "CIM142SLP", "CIM15KWCA2SSE", "CMM11M1FSLP", "CMM16M1FSLP", "CRM06SLP",
        "CRM09SLP",
      ],
      "AIAC": [
        "HS12HFW13MI", "HS18HFB13MI", "HS18HFW13MI", "HS24HFW13MI", "MMI12CABWCC32M1",
        "MMI12CABWCC6M9", "MMI12CDBWCC32M1", "MMI12CDBWCC6M8", "MMI12CDBWCC6M9", "MMI18CDBWCC32M1",
        "MMI18CDBWCC6M8", "MMI24CDBWCC32M1", "MMI24CDBWCC6M8", "MMT12CDBWCCM2", "MMT12CDBWCCTM1",
        "MMT18CDBWCCM1", "MMT18CDBWCCTM1", "PTM12CABWJM2",
      ],
      "ACCE": [
      ]
    },
    "GT": {
      "REFR": [
        "CFE26KP2NS1", "CFE28TP2MS1", "CFE28TP4MW2", "CWE23SP4MW2", "GNM22AETFSS",
        "GNM26AEKFES", "GNM26AEKFSS", "GNM26AETFSS", "HBM425EMNSS0", "HQM458BKNSS0",
        "HSM541HMNSS0", "IOM510MZMRN0", "MSM480LKLSS0", "MSM504SONBS0", "MSM544LMLSS0",
        "MSM631LKLNG0", "MSM631LKLSS0", "MSM746IOLFS0", "MSM746LIOLFS0", "MTM482SENSS0",
        "ONM23WKZGS", "PDF21EYRCFS", "PDM21ESKCSS", "PFF25LYRCFS", "PFM25LSKCSS",
        "PNF25FYRCFS", "PNM22LETFSS", "PNM26PGKCSS", "PNM26PGTCFS", "PNM26PGTFPS",
        "RCC300OVCAE", "RCC300OVNB", "RCC300OVNE", "RCC390OVCAE", "RCC390OVNB",
        "RCC390OVNE", "RMA1230PVCAE", "RMA1230PVCAG1", "RMA1250PJCAG", "RMA1250PJCAU",
        "RMA1250PVCAE", "RMA1300FHCAE", "RMA1300FHCAU", "RMA1300FJCAU", "RMA1300FXCAC",
        "RMA1300FXCAU", "RMA1300FZCAC", "RMA1300FZCAU", "RMA230PVMRE1", "RMA230PVMRG1",
        "RMA250FAMRE1", "RMA250FJMRU1", "RMA250FXMRE0", "RMA250PJMRU1", "RMA250PJNG",
        "RMA300FBNG", "RMA300FHMRE1", "RMA300FHNU", "RMA300FJMRQ0", "RMA300FJMRX0",
        "RMA300FJNU", "RMA300FXNC", "RMA300FXNU", "RMA300FZNC", "RMA300FZNU",
        "RMB300IZMRP0", "RMB300IZMRX0", "RMB400IBMRP0", "RMB400IBMRX0", "RMB520IBMRP1",
        "RMB520IBMRX1", "RMC181PXCRB0", "RMC181PXCRX0", "RMC320FVCAE", "RMC320FVCAG",
        "RMC320FVNE", "RMC320FVNG", "RMC400FVCAE", "RMC400FVCAG", "RMC400FVNB",
        "RMC400FVNE", "RMC400FVNG", "RMD165PVCRB0", "RMD165PVCRS0", "RME360FGMRE0",
        "RME360PVMRE0", "RMN207PVCRX0", "RMN240PVRRX0", "RMP1400FHCAE", "RMP1400FJCAU",
        "RMP370GCAT", "RMP400FHNE", "RMP400FHNU", "RMP400FJNU", "RMP400FLNU",
        "RMP400FZNC", "RMP400FZNU", "RMP410FZNC", "RMP410FZNU", "RMP410HCAT",
        "RMP410HCAU", "RMP410JCAU", "RMP410ZCAU", "RMP420FYCRU", "RMP420FYNU",
        "RMP430FZNC", "RMP430FZNU", "RMP435FZNC", "RMP435FZNU", "RMP450DCAG",
        "RMP450YCAU", "RMP450ZCAC", "RMP450ZCAU", "RMS400IAMRE0", "RMS400IAMRX0",
        "RMS400IVMRE0", "RMS510IAMRE0", "RMS510IAMRX0", "RMS510IBMRX0", "RMS510IVMRE0",
        "RMS510IXMRX0", "RMT400RYMRE0", "RMT510RXMRE0", "RMT510RYMRE0", "RMU1290FACAE",
        "RMU210FANE", "RMU210FANU", "RMU235FANE", "RMU290FANE", "RTA300FYMRE0",
        "ZIF361NPRII", "ZIR361NPRII", "ZISS480DNSS",
      ],
      "LAVA": [
        "CHA1810DXDG0", "CHAC2186NXGG0", "CPA2412NXDG0", "DME17R8MSDBP1", "DME47N8MSDBP0",
        "GFD55ESSNWW", "GFW550SSNWW", "LGA71215CBAB0", "LGA74215WBAB0", "LGA79113CBAB0",
        "LGH73201WBAB0", "LHA9120WGAB0", "LMA4120WDGAB0", "LMA46102VBAB0", "LMA5120WPAB0",
        "LMA70200WBAB1", "LMA70200WDAB1", "LMA70200WGAB0", "LMA70214CBAB0", "LMA70214VBAB0",
        "LMA70215WBAB0", "LMA71214VBAB0", "LMA72215CBAB0", "LMA72215WBAB1", "LMA74215WBAB1",
        "LMA74215WDAB1", "LMA76102CBAB0", "LMA77113CBAB0", "LMA78113CBAB0", "LMA79113VBAB0",
        "LMA79114CBAK0", "LMA8120WDGAB0", "LMC46100WDAB0", "LMDX2224HBAB0", "LME79104VBAB0",
        "LME79104WBAB1", "LMH70211WBAB0", "LMH72201WBAB0", "LMH72201WBAB1", "LMH72205SBAB0",
        "LMH72205WBAB0", "LMH72205WDAB0", "LMH72211WDAB0", "LMH74201WDAB0", "LMH74201WDAB1",
        "LMP75201WDAB0", "LMP75205WDAB0", "LMX70214WDAB0", "MCL2040EPDG0", "MCL2040ESBB0",
        "MCL2040ESDG0", "MCL2040PPDG1", "MCL2040PSBB0", "MCL2440EPDG0", "MCL2440ESBB0",
        "MCL2440ESDG0", "MCL2440PSDG0", "SGE47N5MSSBT0", "SGE47N5XNSBH0", "SGE47N5XSBBH0",
        "SGE47N8MSSBT0", "SME17R8MSBBP0", "SME17R8MSDBP0", "SME26N5MNBBP0", "SME47N8MSBBP0",
        "SME47N8MSBBT0", "SME47N8MSDBP0", "SME47N8MSDBT0", "SMG17R8MSDAB0", "SMG26N5MNBAB0",
        "SMG47N8MSBAB0", "SMG47N8MSDAB0",
      ],
      "GLOB": [
        "AFM38DN", "ALASKAVIT416CEG", "CCWK15C1WSS", "CDT805P2NS1", "CDT828P2VS1",
        "CDT875P4NW2", "CDT888P4VW2", "CEB515P4NWM", "CHC11BPL5", "CHC11BPS0",
        "CHC15BPL4", "CHC25BPL2", "CHC5BPL40", "CHC5BPS1", "CHC7BPL30",
        "CHC7BPS1", "CHC9BPL3", "CHC9BPS1", "CHM11BPL3", "CHM11BPL4",
        "CHM11BPL5", "CHM11PHL0", "CHM15BPL4", "CHM15PHL0", "CHM25BPL1",
        "CHM25BPL2", "CHM25PGL0", "CHM5BPL40", "CHM5PPL0", "CHM7BPL2",
        "CHM7BPL30", "CHM7BPS1", "CHM7PPL0", "CHM9BPL4", "CHM9PPL0",
        "EMDPCCB3", "EMM2PB", "EMM2PN", "FCM5FSWH", "GBF410SSPSS",
        "GBF412SSMSSX", "GBP655SSPSS", "GLV1460FSS", "GW8XDBB2", "HLV0845FSSS",
        "HMM07BJ", "HMM07PJB", "HMM07PJN", "HMM07SJW", "HMM09NJ",
        "HMM111BS", "HMM114SEJ", "HMM11SJW", "HMM11XEB", "HMM15SJW",
        "HMM700WK", "HMM70SEJ", "IO110MDI", "IO160MDI", "IO1702LI6",
        "IO1716LI0", "JVM3162RJSS", "MGE07SEJ", "MGE09SEJ", "MGE11SEJ",
        "MXCBL01D", "MXCFS7CCSS", "PBT865SMPES", "PBT865SSPFS", "PCWK22U1WDD",
        "PEB110SFSS", "PEB160SFSS", "PEB7227ANDD", "PM6040CM6040", "PM7650CM7640",
        "PW29BS3", "QDP225SSPSS", "RMF0260XMXB3", "RMF0260XMXX3", "RMF0411PYMB0",
        "RMF0411PYMX0", "UCC15NPRII", "VC2164LB0", "VC3164LB0", "VM2164LB0",
        "VM3164LB0", "ZDBR240NBS", "ZDT925SINII", "ZDT925SPNSS", "ZDWR240NBS",
        "ZEB1227SLSS", "ZIDS240NSS", "ZIFS240NSS",
      ],
      "COCC": [
        "C2S900P2MS1", "C2Y366P4TW2", "CC20CGX0", "CC20TBX0", "CEM7641BSIS2",
        "CEM7650BSIN3", "CEP90361TBB", "CES700P4MW2", "CGP9019I6I", "CGP9019P6I",
        "CGS700P4MW2", "CGU366P2TS1", "CGU486P2TS1", "CM6045UIW0", "CM7618PIW0",
        "CM7641B", "CM7645UGW0", "CM7645UIW0", "CM7645UNW0", "CM7648PIW0",
        "CMA3020FG1", "CMPU761GX0", "CMPU761NX0", "CMPUV601SSX0", "CMPUV761SSX0",
        "CTS70DP2NS1", "CTS90DP4NW2", "CTS90FP4NW2", "CVW73614MWM", "EC2040DBAIS0",
        "EC3030BAPB2", "EC3030BAPN2", "EC3040BSIF1", "EC7660CFIX0", "ECG5100BIB0",
        "EM5022DBAPN0", "EM5030BFIS0", "EM5032BAPS0", "EM5032BAPS1", "EM5035CFIS0",
        "EM5035CSIS1", "EM5041BAIS1", "EM5041BFIS0", "EM5043BFIS0", "EM5043BFIS1",
        "EM5046CAIX0", "EM5046CAIX1", "EM6032CAIS0", "EM6038CFIX0", "EM7620BAIS2",
        "EM7620BAPN2", "EM7622BAPS1", "EM7622BAPS2", "EM7641BAIB1", "EM7641BAIS2",
        "EM7655CSIN0", "EM7655CSIN1", "EM7658BFIN3", "EM7659BFIS1", "EM7659BFIS3",
        "EM7659BFIX0", "EM7659BFIX2", "EM7674CFIS0", "EM7690CFIX2", "EMA5105SN0",
        "EMA5105SN1", "EMA5110SG0", "EMA5110SG1", "EMA5120SG0", "EMA5120SG1",
        "EMA5130FX0", "EMA5130FX1", "EMA6030SG0", "EMA6030SG1", "EME5025BSB0",
        "EMH7602DSS0", "EMH7602JBS0", "EMH7602JS0", "EMH7602JSS0", "EMH7612DSS0",
        "EMH7612DTSS0", "EMH7612JS0", "EMH7613DATSS0", "EMH7613DBS0", "EMH7613DTSS0",
        "EMH7614DATMSX0", "EMH7614DATSS0", "EMH7616DATMSX0", "HGP6065EWAI1", "HGP8050YE1",
        "HM6021EWAI0", "HM6031EUAI0", "IO6014ICSSS0", "IO6032HEWD0", "IO6040EVN0",
        "IO6056HEWI0", "IO6056HEWI1", "IO6065HEYR1", "IO64TI0", "IO7017CP3I",
        "IO75TI0", "IO7618P2DS", "IO7650EVN0", "IO7680ESS0", "IO7686FES0",
        "IO7686SS0", "IO7686SSC0", "JBS360RTSS", "JCB810SKSS", "JCB820SKSS",
        "JCB840SKSS", "JCBS630SVSS", "JCBS631SFSS", "JGB735SPSS", "JGBS61RPSS",
        "JGBS66REKSS", "JTS3000SNSS", "JTS5000SNSS", "JTS5000SVSS", "P2S930YPFS",
        "PGP75KMTI0", "PGP75TI0", "PGP95KMNN0", "PIO75KMTI0", "PIP8014",
        "PM302I0", "PM6040EVN0", "PM6044PF0", "PM64IV0", "PMI6055PF0",
        "PP930SMSS1", "PP936SMSS1", "PTS7000SNSS", "QCGSS740RNSS", "QCSS740RNSS",
        "UVC9480SLSS", "UVW93642PSS", "WEM7643CAIS1", "WEM7643CSIS0", "WEM7659CFIS3",
        "ZDP366NTSS", "ZDP486NDTSS", "ZGU30RSLSS", "ZGU366NTSS", "ZHU30RSTSS",
        "ZHU36RSTSS", "ZSB9232VSS", "ZTS90DPSNSS", "ZTSX1FPSNSS", "ZVW1480SPSS",
      ],
      "CALE": [
        "CDM40SLP", "CDM80SLP", "CIM062SLP", "CIM102SLP", "CIM11KWCA2SSE",
        "CIM142SLP", "CIM15KWCA2SSE", "CMM11M1FSLP", "CMM16M1FSLP", "CRM06SLP",
        "CRM09SLP",
      ],
      "AIAC": [
        "HS12HFW13MI", "MCI12CABWCCAX9", "MMI12CABWCC32M1", "MMI12CABWCC6M8", "MMI12CABWCC6M9",
        "MMI12CABWCCAX8", "MMI12CDBWCC32M1", "MMI18CDBWCC32M1", "MMI18CDBWCC6M8", "MMI18CDMCCM8",
        "MMI24CDBWCC32M1", "MMI24CDBWCC6M8", "MMI36HDBWCAAXM8", "MMT12CABWCCM2", "MMT12CABWCCTM1",
        "MMT12CDBWCCM2", "MMT12CDBWCCTM1", "MMT18CDBWCC32BC1", "MMT18CDBWCCM1", "MMT24CDBWCCM1",
        "PTM12CABWJM2",
      ],
      "ACCE": [
      ]
    },
    "HN": {
      "REFR": [
        "GNM26AETFSS", "HBM425EMNSS0", "HQM458BKNSS0", "HSM518HMNSS0", "HSM541HMNSS0",
        "MSM480LKLSS0", "MSM504SONBS0", "MSM521HKNSS0", "MSM521LMLSS0", "MSM544LMLSS0",
        "MSM631LKLNG0", "MSM631LKLSS0", "MSM746IOLFS0", "MSM746LIOLFS0", "MTM482SENSS0",
        "ONM23WGTHFS", "PDF21EYRCFS", "PFF25LYRCFS", "PNF25FYRCFS", "PNM22LETFSS",
        "PNM26PGTCFS", "PNM26PGTFPS", "RCA1250OVCAE", "RCA230OVMRE1", "RCA250OVMRE1",
        "RCC300OVNE", "RCC390OVCAE", "RCC390OVNB", "RCC390OVNE", "RCU210NUNE",
        "RCU235TUNS", "RCU290TVNE", "RMA1230PVCAE", "RMA1230PVCAG1", "RMA1250FACAE",
        "RMA1250FJCAU", "RMA1250PJCAG", "RMA1250PJCAU", "RMA1250PVCAE", "RMA1300FHCAE",
        "RMA1300FHCAU", "RMA1300FJCAU", "RMA1300FXCAC", "RMA1300FXCAU", "RMA1300FYCAE",
        "RMA1300FZCAC", "RMA1300FZCAU", "RMA230PVMRE1", "RMA230PVMRG1", "RMA250FAMRE1",
        "RMA250FJMRU1", "RMA250FYMRE0", "RMA250PJMRU1", "RMA250PJNG", "RMA300FHMRE1",
        "RMA300FHNU", "RMA300FJMRQ0", "RMA300FJNU", "RMA300FXNC", "RMA300FXNU",
        "RMA300FYMRE1", "RMA300FZNC", "RMA300FZNU", "RMB300IZMRP0", "RMB300IZMRX0",
        "RMB400IBMRP0", "RMB400IBMRX0", "RMB520IBMRP1", "RMB520IBMRX0", "RMB520IBMRX1",
        "RMC181PXCRB0", "RMC181PXCRX0", "RMC320FVCAE", "RMC320FVNE", "RMC400FVCAE",
        "RMC400FVCAG", "RMC400FVNE", "RMD165PVCRB0", "RMD165PVCRS0", "RMN207PVCRX0",
        "RMN240PVRRX0", "RMP1400FHCAU", "RMP1400FJCAU", "RMP370GCAT", "RMP400FJNU",
        "RMP400FLNU", "RMP400FZNC", "RMP400FZNU", "RMP410FZNC", "RMP410FZNU",
        "RMP410HCAU", "RMP410JCAU", "RMP410ZCAU", "RMP420FYCRU", "RMP420FYNU",
        "RMP430FZNC", "RMP435FZNC", "RMP435FZNU", "RMP450DCAG", "RMP450YCAU",
        "RMP450ZCAU", "RMS400IAMRM0", "RMS400IAMRX0", "RMS400IBMRX0", "RMS400IVMRM0",
        "RMS510IAMRX0", "RMS510IBMRX0", "RMS510IXMRX0", "RMT510RXMRE0", "RMU1290FACAE",
        "RMU210FANE", "RMU210FANU", "RMU210NANG", "RMU235FANE",
      ],
      "LAVA": [
        "CHAC2186NXGG0", "DME17R8MSDBP1", "DME47N8MSDBP0", "LGA71215CBAB0", "LGA72214CBAB0",
        "LGA74215WBAB0", "LGA79113CBAB0", "LGH73201WBAB0", "LHA9120WGAB0", "LMA4120WDGAB0",
        "LMA46102VBAB0", "LMA5120WPAB0", "LMA70213CBAB0", "LMA70214CBAB0", "LMA71214VBAB0",
        "LMA71215WBAB0", "LMA72200WDAB0", "LMA72215CBAB0", "LMA72215WBAB1", "LMA74215WBAB1",
        "LMA76102CBAB0", "LMA77113CBAB0", "LMA78113CBAB0", "LMA79113VBAB0", "LMA79114CBAK0",
        "LMA8120WDGAB0", "LMDX2224HBAB0", "LMH72201WBAB1", "LMH72205WBAB0", "LMH74201WDAB1",
        "LMP75201WDAB0", "LMP75205WDAB0", "MCL2040EPDG0", "MCL2040ESBB0", "MCL2040ESDG0",
        "MCL2040PSBB0", "MCL2440ESBB0", "MCL2440ESDG0", "MCL2440PSBB0", "SGE47N5MSSBT0",
        "SGE47N5XNSBH0", "SGG47N5XNBAB0", "SME26N5MNBBP0", "SME26N5MNBBT0", "SME47N8MSBBP0",
        "SME47N8MSBBT0", "SMG26N5MNBAB0",
      ],
      "GLOB": [
        "AFM38DN", "ALASKAVIT416CEG", "CHC11BPL5", "CHC11BPS0", "CHC15BPL4",
        "CHC25BPL2", "CHC5BPL40", "CHC5BPS1", "CHC7BPL30", "CHC7BPS1",
        "CHC9BPL3", "CHC9BPS1", "CHM11BPL5", "CHM11PHL0", "CHM15BPL3",
        "CHM15BPL4", "CHM15PHL0", "CHM25BPL1", "CHM25BPL2", "CHM25PGL0",
        "CHM5BPL3", "CHM5BPL40", "CHM5PPL0", "CHM7BPL2", "CHM7BPL30",
        "CHM7PPL0", "CHM9BPL4", "CHM9PPL0", "EMDPCCB3", "EMM2PB",
        "EMM2PN", "GBF410SSPSS", "GLV1460FSS", "HLV0845FSSS", "HMM07PJB",
        "HMM07PJN", "HMM09NJ", "HMM111BS", "HMM700WK", "IO110MDI",
        "IO1702LI6", "JES11W", "JES70SE", "JES70W", "JVM3162RJSS",
        "MGE07SEJ", "MGE09SEJ", "MGE11SEJ", "MXCFS7CCSS", "PEB160SFSS",
        "PW29BS3", "QDP225SSPSS", "RMF0260XMXB3", "RMF0260XMXX3", "RMF0411PYMB0",
        "RMF0411PYMX0", "VM2164LB0", "VM3164LB0",
      ],
      "COCC": [
        "CC20CGX0", "CC20TBX0", "CG9014P3I", "CM6045UIW0", "CM7618PIW0",
        "CM7645UGW0", "CM7645UIW0", "CM7645UNW0", "CMA3020FG1", "CMPU761GX0",
        "CMPUV601SSX0", "CMPUV761SSX0", "EC3030BAPB2", "ECG5100FN0", "EM5032BAPS1",
        "EM5035CFIS0", "EM5043BFIS1", "EM6038CFIX0", "EM7620BAIS2", "EM7620BAPN2",
        "EM7622BAPS2", "EM7641BAIN2", "EM7641BAIS2", "EM7655CSIN1", "EM7659BFIX0",
        "EM7659BFIX2", "EMA5105SB0", "EMA5105SN0", "EMA5105SN1", "EMA5110SG0",
        "EMA5110SG1", "EMA5120SG0", "EMA5120SG1", "EMA5130FX0", "EMA5130FX1",
        "EMA6030AG1", "EME5025BSB0", "EME5025BSS0", "EME5030BES0", "EME5030BES1",
        "EME6063BVX0", "EME7620BSFL0", "EME7630BEB1", "EME7630BEFL0", "EME7630BESL1",
        "EMH7602DSS0", "EMH7602JBS0", "EMH7602JS0", "EMH7602JSS0", "EMH7612JS0",
        "EMH7613DTSS0", "EMH7614DATBS0", "EMH7614DATMSS0", "EMH7614DATSS0", "HGP6065EWAI0",
        "HGP8050YE1", "HM6031EUAI0", "IO6040EVN0", "IO6056HEWI1", "IO64TI0",
        "IO75TI0", "IO7650EVN0", "IO7686SS0", "JBS360DMWW", "JBS360RTSS",
        "JCB810SKSS", "JCB820SKSS", "JCB830STSS", "JCB840STSS", "JCB870STSS",
        "JCBS630SVSS", "JCBS631SFSS", "JGB735SPSS", "JGBS66REKSS", "JTS5000SVSS",
        "PGP64KRTI0", "PGP64TI0", "PGP75KMTI0", "PGP75TI0", "PM302I0",
        "PM6040EVN0", "PM64IV0", "PP930SMSS1", "PP936SMSS1", "QCGSS740RNSS",
        "WEM7643CFIS0", "WEM7643CSIS0", "WEM7659CFIS3", "WEM7661CFIX2",
      ],
      "CALE": [
        "CIM11KWCA2SSE", "CIM15KWCA2SSE",
      ],
      "AIAC": [
        "HS12HFW13MI", "HS18HFB13MI", "HS18HFW13MI", "HS24HFW13MI", "MMI12CDBWCC32M1",
        "MMI12CDBWCC6M9", "MMI12CDBWCCTM1", "MMI18CDBWCC32M1", "MMI18CDBWCC6M8", "MMI18CDBWCCTM1",
        "MMI24CDBWCC6M8", "MMI24CDBWCCTM1", "MMT12CDBWCC32BC1", "MMT12CDBWCCM2", "MMT12CDBWCCTM1",
        "MMT18CDBWCCM1", "MMT18CDBWCCTM1", "MMT24CDBWCCM1", "MMT24CDBWCCTM1", "PTM12CABWJM2",
      ],
      "ACCE": [
      ]
    },
    "SV": {
      "REFR": [
        "CFE28TP2MS1", "CFE28TP3MD1", "CFE28TP4MW2", "CWE23SP2MS1", "CWE23SP4MW2",
        "GNM26AETFSS", "HBM425EMNSS0", "HFM410LPLSS0", "HQM458BKNSS0", "HSM541HMNSS0",
        "HTM507JMLSS0", "IOM510MZMRN0", "MSM480LKLSS0", "MSM504SONBS0", "MSM544LMLSS0",
        "MSM631LKLNG0", "MSM631LKLSS0", "MSM746IOLFS0", "MSM746LIOLFS0", "MTM482SENSS0",
        "ONM23WGTHFS", "PDF21EYRCFS", "PDM21ESKCSS", "PFF25LYRCFS", "PNF25FYRCFS",
        "PNM22LETFSS", "PNM26PGTCFS", "PNM26PGTFPS", "RCC300OVCAE", "RCC300OVNE",
        "RCC390OVCAE", "RCC390OVNB", "RCC390OVNE", "RMA1230PVCAG1", "RMA1250PJCAG",
        "RMA1250PJCAU", "RMA1250PVCAE", "RMA1300FHCAE", "RMA1300FHCAU", "RMA1300FJCAU",
        "RMA1300FXCAC", "RMA1300FXCAU", "RMA1300FYCAE", "RMA1300FZCAU", "RMA230PVMRG1",
        "RMA250FAMRE1", "RMA250FJMRU1", "RMA250PJMRU1", "RMA250PJNG", "RMA300FBNG",
        "RMA300FHMRE1", "RMA300FHNU", "RMA300FJMRD0", "RMA300FJMRQ0", "RMA300FJNU",
        "RMA300FXNC", "RMA300FXNU", "RMA300FZNC", "RMA300FZNU", "RMB300IZMRP0",
        "RMB300IZMRX0", "RMB400IBMRP0", "RMB400IBMRX0", "RMB520IBMRX1", "RMC181PXCRB0",
        "RMC181PXCRX0", "RMC320FVCAE", "RMC320FVNE", "RMC400FVCAE", "RMC400FVNE",
        "RMD165PVCRB0", "RMD165PVCRS0", "RME360FZMRP0", "RMN207PVCRX0", "RMN207PVCRX1",
        "RMN240PVRRX0", "RMP1400FHCAU", "RMP1400FJCAU", "RMP370GCAT", "RMP400FHNU",
        "RMP400FJNU", "RMP400FZNC", "RMP400FZNU", "RMP410FZNC", "RMP410FZNU",
        "RMP410HCAT", "RMP410HCAU", "RMP410JCAU", "RMP410ZCAU", "RMP420FDNG",
        "RMP420FYCRU", "RMP420FYNU", "RMP435FZNC", "RMP435FZNU", "RMP450ZCAC",
        "RMP450ZCAU", "RMS400IAMRE0", "RMS400IAMRX0", "RMS510IAMRX0", "RMS510IBMRX0",
        "RMS510IXMRX0", "RMU1290FACAE", "RMU210FANE", "RMU210FANU", "RMU235FANE",
        "RMU290FANE", "ZICS360NNLH", "ZICS360NNRH", "ZIF361NPRII", "ZISB480DNII",
        "ZISS480DNSS",
      ],
      "LAVA": [
        "CHAC2186NXGG0", "DME17R8MSDBP1", "DME47N8MSDBP0", "GFD55ESSNWW", "GFW550SSNWW",
        "LGA71215CBAB0", "LGA72214CBAB0", "LGA74215WBAB0", "LGA79113CBAB0", "LGH73201WBAB0",
        "LHA9120WGAB0", "LMA0220WDGAB0", "LMA4120WDGAB0", "LMA46102VBAB0", "LMA5120WPAB0",
        "LMA6120WDGAB0", "LMA70214CBAB0", "LMA72200WDAB0", "LMA72215CBAB0", "LMA72215WBAB1",
        "LMA74215WBAB1", "LMA74215WDAB1", "LMA76102CBAB0", "LMA77113CBAB0", "LMA78113CBAB0",
        "LMA79113VBAB0", "LMA8120WDGAB0", "LMDX2224HBAB0", "LME79104VBAB0", "LMH72205WBAB0",
        "LMH74201WDAB1", "LMP75201WDAB0", "LMP75205WDAB0", "MCL2040ESBB0", "MCL2040ESDG0",
        "MCL2440ESBB0", "MCL2440ESDG0", "PFD87ESPVRS", "PFW870SPVRS", "SGE47N5MSSBT0",
        "SGE47N5XNSBH0", "SME17R8MSBBP0", "SME17R8MSDBP0", "SME26N5MNBBP0", "SME26N5MNBBT0",
        "SME47N8MSBBP0", "SME47N8MSBBT0", "SMG26N5MNBAB0",
      ],
      "GLOB": [
        "AFM38DN", "ALASKAVIT416CEG", "CCWK15C1WDS", "CCWK15C1WSS", "CDT828P2VS1",
        "CDT875P4NW2", "CEB515P2NSS", "CEB515P4NWM", "CHC11BPL5", "CHC11BPS0",
        "CHC15BPL4", "CHC25BPL2", "CHC5BPL40", "CHC5BPS1", "CHC7BPL30",
        "CHC7BPS1", "CHC9BPL3", "CHC9BPS1", "CHM11BPL5", "CHM11PHL0",
        "CHM15BPL4", "CHM15PHL0", "CHM25BPL1", "CHM25BPL2", "CHM25PGL0",
        "CHM5BPL3", "CHM5BPL40", "CHM5PPL0", "CHM7BPL2", "CHM7BPL30",
        "CHM7PPL0", "CHM9BPL4", "CHM9PPL0", "CK1UP150RS1", "CVM517P2RS1",
        "EMDPCCB3", "EMM2PB", "EMM2PN", "GBF410SSPSS", "GBP655SSPSS",
        "GLV1460FSS", "HLV0845FSSS", "HMM07PJB", "HMM07PJN", "HMM09NJ",
        "HMM700WK", "IO110MDI", "IO110MDI1", "IO160MDI", "IO1702LI6",
        "JES11W", "JES14W", "JES70SE", "JES70W", "JVM3162RJSS",
        "MGE07SEJ", "MGE09SEJ", "MGE11SEJ", "MXCFS7CCSS", "PBT865SMPES",
        "PBT865SSPFS", "PCWK22U1WDD", "PEB110SFSS", "PEB160SFSS", "PEB7227ANDD",
        "PLV1817XSS", "PVM9215SKSS", "PW29BS3", "QDP225SSPSS", "RMF0260XMXB3",
        "RMF0260XMXX3", "RMF0411PYMB0", "RMF0411PYMX0", "UCC15NPRII", "VM2164LB0",
        "VM3164LB0", "ZCWK22U2WSS", "ZDT925SPNSS", "ZEB1227SLSS",
      ],
      "COCC": [
        "C2S900P2MS1", "CC20TBX0", "CEP90361TBB", "CES700P2MS1", "CGP70302NS1",
        "CGP70362NS1", "CGP9019I6I", "CGP9019P6I", "CGS700P2MS1", "CGS700P4MW2",
        "CGU366P2TS1", "CM5021N", "CM6045UIW0", "CM7618PIW0", "CM7645UGW0",
        "CM7645UIW0", "CM7645UNW0", "CMPU761GX0", "CMPU761NX0", "CMPUV601SSX0",
        "CMPUV761SSX0", "CTS70DP2NS1", "CTS90FP2NS1", "CVW73612MSS", "EC3040BSIF1",
        "EM5022DBAPN0", "EM5032BAPS1", "EM5043BFIS1", "EM6038CFIX0", "EM7622BAPS1",
        "EM7622BAPS2", "EM7641BAIS2", "EM7655CSIN0", "EM7655CSIN1", "EM7658BFIN2",
        "EM7658BFIN3", "EM7659BFIX0", "EM7659BFIX2", "EMA5105SN0", "EMA5105SN1",
        "EMA5110SG0", "EMA5110SG1", "EMA5130FX0", "EMA5130FX1", "EMA6030FX0",
        "EMA6030FX1", "EMA6030SG0", "EMA6030SG1", "EME6063BVX0", "EMH7602DSS0",
        "EMH7602JBS0", "EMH7602JS0", "EMH7602JSS0", "EMH7613DTSS0", "HGP6065EWAI0",
        "HGP6065EWAI1", "HGP8050K0", "HGP8050YE1", "HM6021EWAI0", "HM6031EUAI0",
        "IO312DVI0", "IO6014ICSSS0", "IO6032HEWD0", "IO6040EVN0", "IO6056HEWI0",
        "IO6056HEWI1", "IO614PVI0", "IO64BG0", "IO64TI0", "IO75TI0",
        "IO7650EVN0", "IO7686SS0", "IO8042HEYD0", "IO8042HEYD1", "IO9014ICSSS0",
        "IO9017CP3I", "IO96TI0", "JCB810SKSS", "JCB820SKSS", "JCB840STSS",
        "JCBS631SFSS", "JGB735SPSS", "JGBS66REKSS", "JTS3000SNSS", "JTS5000SVSS",
        "P2S930YPFS", "PGP64TI0", "PGP75KMTI0", "PGP75TI0", "PGP95KMNN0",
        "PIO64KRTI0", "PIO75KMTI0", "PIP8014", "PM302I0", "PM6040EVN0",
        "PM64IV0", "PMI6055PF0", "PP930SMSS1", "PP936SMSS1", "QCGSS740RNSS",
        "QCSS740RNSS", "UVW93642PSS", "WDP8000K0", "WEM7659CFIS3", "ZGU366NTSS",
        "ZGU36ESLSS", "ZTS90DPSNSS", "ZVW1480SPSS",
      ],
      "CALE": [
        "CIM11KWCA2SSE", "CIM15KWCA2SSE",
      ],
      "AIAC": [
        "HS12HFW13MI", "MMI12CABWCC32M1", "MMI12CABWCC6M9", "MMI12CDBWCC32M1", "MMI12CDBWCC6M9",
        "MMI12CDMCCM9", "MMI18CDBWCC32M1", "MMI18CDMCCM9", "MMI24CDBWCC32M1", "MMI24CDBWCC6M8",
        "MMT12CDBWCCTM1", "PTM12CABWJM2",
      ],
      "ACCE": [
      ]
    }
  },
  "NORTEAMERICA": {
    "CA": {
      "REFR": [
        "CGE29DM5TS5", "CHE23DM5WS5", "CJE23DM5WS5", "CJE23DP2WS1", "CJE23DP4WW2",
        "GBE17HYRFS", "GLE12HSPSS", "GPE12FGKBB", "GPE12FGKWW", "GPE12FSKSB",
        "GTE18FSLKSS", "GTE18FTLKBB", "GTE18FTLKWW", "GTS18FSLKSS", "GTS18FTLKBB",
        "GTS18FTLKWW", "HRB15N3BGS", "HRF15N3AGS", "HRQ16N3BGS", "M2E9FPMKII",
        "MBE11DSVSS", "MBE19DSNKSS", "MBE19DTNKWW", "MDE19DSNKSS", "MDE19DTNKWW",
        "MNE18DYTNFS", "MPE12FGKLWW", "MPE12FGKWW", "MPE12FSKSB", "MTE18GSKSS",
        "MTE18GTKWW", "MTE18HSKRSS", "MTE18HTKBB", "MTE18HTKRWW", "MWE22FYPKFS",
        "MWS21FSKSS", "MYE22HYPKFS", "PAD28BYTFS", "PGE29BYTFS", "QHE16HYPFS",
        "QJS15HYRFS",
      ],
      "LAVA": [
        "GFD14JSINWW", "GFQ14ESSNWW", "GFT14JSIMWW", "GFW148SSMWW", "GFW450SPMDG",
        "GFW550SMNWW", "GFW550SPRRS", "GFW650SPNSN", "GFW655SPVDS", "GFW850SPNRS",
        "GNW128PSMWW", "GNW128SSMWW", "PCVH480EKWW", "PFQ83HSHWWW", "PFQ83HSLWWW",
        "PFQ83HSSWWW", "PFQ97HSPVDS", "PFW870SPVRS", "QFD15ESMNWW", "QFW150SSNWW",
        "WCVH4800KWW",
      ],
      "GLOB": [
        "CCP06BP2PS1", "CCP06BP3PD1", "CCP06BP4PW2", "CCP06DP2PS1", "CCP06DP4PW2",
        "CCR06BM2PS5", "CDE06RP2NS1", "CDE06RP3ND1", "CDE06RP4NW2", "CVM721M2NCS5",
        "CWLC12P2RS1", "CWLC12P4RW5", "DBP655SSTSS", "DBT655SSNSS", "DVM2185SMSS",
        "FCM16SLWW", "FCM22DLWW", "FCM5STWW", "FCM7STWW", "FUF14DLRWW",
        "FUF14SMRWW", "FUF17DLRWW", "FUF17SMRWW", "FUF21DLRWW", "FUF21SMRWW",
        "GBF180SGMWW", "GBF180SSMSS", "GBF410SGPBB", "GBF410SGPWW", "GBF410SSPSS",
        "GBF532SGPBB", "GBF532SGPWW", "GBF532SSPSS", "GBF630SMLES", "GBF655SGPWW",
        "GBF655SMPES", "GBF655SSPSS", "GBP534SGPWW", "GBP534SSPSS", "GBP655SSPSS",
        "GBT412SIMII", "GBT500SGVWW", "GBT500SSVSS", "GBT600SSVFS", "GBT632SSMSS",
        "GBT640SGPWW", "GBT640SMPES", "GBT640SSPSS", "GCE06GGHWW", "GCE06GSHSB",
        "GDE03GLKLB", "GDT225SGLWW", "GDT225SSLSS", "GDT226SILII", "GDT226SSLSS",
        "GPT225SGLWW", "GPT225SSLSS", "GVS04BQNSS", "GWS04HAESS", "HC45SG42SB",
        "HEBF100BXS", "HEN30ET", "HMV1472BHS", "JE1140STC", "JEB2167RMSS",
        "JES1140STC", "JES1145WTC", "JVM1635SFC", "JVM1635SLJC", "JVM2160DMBB",
        "JVM2160DMWW", "JVM2162SMSS", "JVM2165SMSS", "JVM2185SMSS", "MBF420SGPWW",
        "MBT425SGVWW", "MUF06DMRWW", "PBF665SMPES", "PBF665SSPFS", "PBP665SGPWW",
        "PBP665SSPFS", "PBT660SSLSS", "PBT700SSVFS", "PBT860SMMES", "PBT865SMPES",
        "PBT865SSPFS", "PCR06WATSS", "PDT145SGLWW", "PDT145SSLSS", "PDT660SSFSS",
        "PEM10SFC", "PEM10SLFC", "PVM1899SJC", "PVM2188DSMC", "PVM2188SJC",
        "PVM2188SLJC", "PXR03FLMFSC", "QDP225SSPSS", "QDT125SSKSS", "QDT125SSLSS",
        "QVM7167RNCSS", "UBT410SGVBB", "UBT410SGVWW", "UBT410SSVSS", "UDT165SIVII",
      ],
      "COCC": [
        "BIL616TI2-B5-09", "MCP2024DXBB", "MER247CWBS", "UVC7300SLSS", "UVC9300SLSS",
        "UVC9360SLSS", "UVW8301SLSS", "UVW9301SLSS", "UVW9361SLSS",
      ],
      "CALE": [],
      "AIAC": [],
      "ACCE": [
        "GFA24KITL", "IM18000", "IM19000", "JX10PEM", "JX1124STC",
        "JX30ASSC", "JX827SFC", "JX827SLFC", "JX830SFC", "JX830SLFC",
      ],
    },
  },
  "MEXICO": {
    "MX": {
      "LAVA": [
        "CHA1810DXDG0", "CHAC2186NXGG0", "CPA2412NXDG0", "LHA9120WGAB0", "LIQ1220B0",
        "LIQ1320B0", "LMDX1123HBAB0", "LMDX1123PBAB0", "LMDX2224HBAB0", "LMDX2224PBAB0",
        "LMDX3123HBAB0", "LMDX3123PBAB0", "LMDX3124PBAB0", "LMDX6123PBAB0", "LMDX6124HBAB0",
        "LMDX6124PBAB0", "LMDX8124HBAB0", "LMDX8124PBAB0", "LMDXC1123HBAB0", "LMDXC2224HBAB0",
      ],
      "COCC": [
        "CHP90362TSS", "CM7618PIW0", "CM7648PIW0", "CM9018P2DS", "CMG6018V0",
        "CMG6018V1", "CSB913P2NS1", "CSB913P2VS1", "CSB913P3ND1", "CSB913P3VD1",
        "CSB913P4NW2", "CSB913P4VW2", "CTS90DP2NS1", "CTS90DP3ND1", "CTS90DP4NW2",
        "CTS90FP2NS1", "CTS90FP3ND1", "CTS90FP4NW2", "CV966TSS", "HM6027GWAI0",
        "HM6031EWAI0", "IO311DGI0", "IO312DVI0", "IO604I0", "IO614PVI0",
        "IO705I0", "IOT6002I", "IOT8002I1", "PGP95IV0", "PIP8014",
        "PM6040EVN0", "PM64IV0", "PM7615I1", "PM7655GPV0", "PM8615I1",
        "PP930SMSS", "PP930SMSS1", "PP936SMSS1", "PTP401DI", "PVP302",
        "PVP3021", "PVP6014S1", "UVC9360SLSS", "UVC9480SLSS", "ZDP304NPSS",
        "ZET1SHSS", "ZET2PHSS", "ZHU36RDTBB", "ZSB9231NSS", "ZSB9232NSS",
        "ZSB9232VSS", "ZTD90DPSNSS", "ZTD90DSSNSS", "ZTS90DPSNSS", "ZTS90DSSNSS",
        "ZTSX1FPSNSS", "ZTW900PSNSS", "ZTW900SSNSS", "ZV1050SFSS", "ZV48RSFSS",
        "ZV750SPSS", "ZV800SJSS",
      ],
      "GLOB": [
        "ADT521PGJBS", "AFM38DN", "CAMCT1500N1", "CCP06BP2PS1", "CCP06BP3PD1",
        "CCP06BP4PW2", "CCP06DP2PS1", "CCP06DP3PD1", "CCP06DP4PW2", "CCWK15C1WWM",
        "CDT845P2NS1", "CDT845P3ND1", "CDT845P4NW2", "CDT858P2VS1", "CDT858P3VD1",
        "CDT858P4VW2", "CHM11BPL5", "CHM11BPS0", "CHM11PPL0", "CHM11PPL06",
        "CHM15BPL1", "CHM15BPL4", "CHM15PGL0", "CHM25BPL2", "CHM25PGL0",
        "CHM5BPL2", "CHM5BPL3", "CHM5BPL4", "CHM5BPS0", "CHM5BPS1",
        "CHM5PPL0", "CHM7BPL2", "CHM7BPL3", "CHM7BPL36", "CHM7BPS0",
        "CHM7BPS1", "CHM7PPL0", "CHM7PPL06", "CHM9BPL3", "CHM9BPL4",
        "CHM9BPS1", "CHM9PPL0", "CK1UP150RD1", "CK1UP150RS1", "CK1UP150RW2",
        "CMM20M1FSLP", "CVM517P2MS1", "CVM517P4MW2", "EMBL01S", "EMBL1TB",
        "EMBL1TN", "EMDPCCB1", "EMDPCCB2", "EMDPCCB3", "EMM2PB",
        "EMM2PN", "EMM2PS", "EMMCHB", "EMTL3CGG", "GBF410SSPSS",
        "GBP655SSPSS", "GDF650SMJES", "GLV1460FSS", "GLV1890XSS0", "GW12XDBB",
        "GW12XDBB2", "GW12XDZBB", "GW18XDZBB", "GW6XDBB", "GW8XDBB",
        "GW8XDBB2", "GXCFS7W", "H43K700UX", "H43S80FUX", "H50K700UX",
        "H50P752UX", "H50S80FUX", "H55K700UX", "H55P752UX", "H55S80FUX",
        "H65P752UX", "H65S80FUX", "H70K85EUX", "H75S80FUX", "H85S800UX",
        "HLV0845FSSS", "HMM07BB", "HMM07BBW", "HMM07BR", "HMM07PJB",
        "HMM07SBW", "HMM07SJW", "HMM09NJ", "HMM09NJ1", "HMM09NJC",
        "HMM09PJNX", "HMM09SJ1", "HMM111BS", "HMM111BS6", "HMM111JSS",
        "HMM111SEJ", "HMM114SEJ", "HMM11PJNX", "HMM11RPO", "HMM11SJW",
        "HMM11XPO", "HMM15SJW", "HMM15XPO", "HMM16XEBI", "HMM700WK",
        "HMM70SEJ", "HMM70SW", "HTM10LN", "HTM10LR", "HTM22LSS",
        "HWS42DZ0", "IO110MDI", "IO110MDI1", "IO160MDI", "IO160MDI1",
        "IO16MCJI", "IO16MDI2", "IO1702LI6", "IO1716LI0", "JES11W",
        "JES14W", "JES70SE", "JVM6172DKWW", "JVM6172SKSS", "MGE07SEJ",
        "MGE07SEJ6", "MGE09SEJ", "MGE11SEJ", "MGE11SEJG", "MGE11XAF",
        "MGE11XEJI", "MGE14SEJG", "MGE14XAF", "MGE14XEJG", "MGE14XEJI",
        "MGE16XNEJS", "MW6XDBB", "MXCBL01D", "MXCBL01S", "MXCFS7CCSS",
        "PBP665SSPFS", "PBT700SSVFS", "PBT865SMPES", "PBT865SMWDS", "PBT865SSPFS",
        "PBT865SSWFS", "PCWK22U1WDD", "PEB110SFSS", "PEB160SFSS", "PEB7227ANDD",
        "PLV1817XSS", "PM6040CM6040", "PM6040CM6048N", "PM7650CM7640", "PM7650CM7648N",
        "PVM9005SJSS", "PW29BS3", "QDP225SSPSS", "RMF0260XMXB3", "RMF0260XMXB4",
        "RMF0260XMXX3", "RMF0260XMXX4", "RMF032PYMXB", "RMF032PYMXX", "RMF0411PYMB0",
        "RMF0411PYMB1", "RMF0411PYMX0", "RMF0411PYMX1", "RMF0411YMXB1", "RMF0411YMXS1",
        "RMF04LGMXS0", "RWU430NVMRX0", "UCC15NPRII", "WDP6001I", "ZCWK22U2WSS",
        "ZDBR240NBS", "ZDT870SSFSS", "ZDT925SINII", "ZDT925SPNSS", "ZDT925SSNSS",
        "ZDWR240NBS", "ZEB1227SLSS", "ZES1227SLSS", "ZIDI240HII", "ZIDS240NSS",
        "ZIP80SS",
      ],
      "REFR": [
        "CFE28TP2MS1", "CFE28TP3MD1", "CFE28TP4MW2", "CSB48WP2NS1", "HBL283BKNSS0",
        "HBM425EMNSS0", "HFM410LPLSS0", "HQM458BKNSS0", "HSM518HMNSS0", "HSM541HMNSS0",
        "HTM507JMLSS0", "MSM480LKLSS0", "MSM521LMLSS0", "MSM689LKLBS0", "MSM689LKLSS0",
        "MTM482SENSS0", "MTM600JKLBG0", "RWU505NVMRX0", "ZIC360NHRH", "ZIC360NNRH",
        "ZIC363IPVLH", "ZIC363IPVRH", "ZIF241NPNII", "ZIF361NPRII", "ZIR241NPNII",
        "ZIR361NPRII", "ZISB360DNII", "ZISB420DNII", "ZISS360DNSS", "ZISS420DNSS",
        "ZISS480DNSS", "ZWE23NSYSS",
      ],
      "CALE": [
        "CDM40MPESA", "CDM40MPESD", "CDM40SLP", "CDM40SNA", "CDM80MPESD",
        "CDM80SLP", "CDM80SNA", "CIM062BLP", "CIM062BNA", "CIM062SLP",
        "CIM062SNA", "CIM063SLP1", "CIM063SNA1", "CIM102SLP", "CIM102SNA",
        "CIM142SLP", "CIM142SNA", "CMBM11M1FSLP", "CMBM11M1FSNA", "CMBM16M1FSLP",
        "CMBM16M1FSNA", "CMM11M1FSLP", "CMM11M1FSNA", "CMM16M1FSLP", "CMM16M1FSNA",
        "CMM20M1FSNA", "CMP60TNBN", "CRM06SLP", "CRM06SNA", "CRM09SLP",
        "CRM09SNA",
      ],
      "AIAC": [
        "CMI36HDBWCMIMXE1", "CMI60HDBWCMIMXE1", "DMI24HDBWCMIMXE1", "DMI36HDBWCMIMXE1", "DMI48HDBWCMIMXE1",
        "DMI60HDBWCMIMXE1", "HS12HFW13MIE", "HS18HFB13MIE", "HS18HFW13MIE", "HS24HFW13MIE",
        "MGI12CDBE2", "MHI12CDBWCA6ME8", "MMI12CABWCA32BME2", "MMI12CABWCA32MCE1", "MMI12CABWCA32MCE2",
        "MMI12CABWCA32ME1", "MMI12CABWCA32ME2", "MMI12CABWCA6ME8", "MMI12CABWCA6ME9", "MMI12CABWCAAXME8",
        "MMI12CABWCAME10", "MMI12CABWCAME9", "MMI12CABWCATME1", "MMI12CABWCAX32ME1", "MMI12CAMCAME10",
        "MMI12CAMCAME8", "MMI12CAMCAME9", "MMI12CDBWCA32BME2", "MMI12CDBWCA32MCE2", "MMI12CDBWCA32ME1",
        "MMI12CDBWCA32ME2", "MMI12CDBWCA6ME8", "MMI12CDBWCA6ME9", "MMI12CDBWCAAXME8", "MMI12CDBWCAAXME9",
        "MMI12CDBWCAME10", "MMI12CDBWCAME9", "MMI12CDBWCATME1", "MMI12CDBWCAX32ME1", "MMI12CDMCAME10",
        "MMI12CDMCAME8", "MMI12CDMCAME9", "MMI12HABWCA32BME2", "MMI12HABWCA32MCE2", "MMI12HABWCA32ME1",
        "MMI12HABWCA32ME2", "MMI12HABWCA6ME8", "MMI12HABWCA6ME9", "MMI12HABWCAAXME8", "MMI12HABWCAME10",
        "MMI12HABWCAME9", "MMI12HABWCATME1", "MMI12HABWCAX32ME1", "MMI12HAMCAME10", "MMI12HAMCAME9",
        "MMI12HDBWCA32BME2", "MMI12HDBWCA32MCE2", "MMI12HDBWCA32ME1", "MMI12HDBWCA32ME2", "MMI12HDBWCA6ME8",
        "MMI12HDBWCA6ME9", "MMI12HDBWCAAXME8", "MMI12HDBWCAAXME9", "MMI12HDBWCAME10", "MMI12HDBWCAME9",
        "MMI12HDBWCATME1", "MMI12HDBWCAX32ME1", "MMI12HDMCAME10", "MMI12HDMCAME8", "MMI12HDMCAME9",
        "MMI18CDBWCA32ME1", "MMI18CDBWCA32ME2", "MMI18CDBWCA6ME8", "MMI18CDBWCAAXME8", "MMI18CDBWCAAXME9",
        "MMI18CDBWCAME8", "MMI18CDBWCATME1", "MMI18CDBWCAX32ME1", "MMI18CDMCAME10", "MMI18CDMCAME8",
        "MMI18HDBWCA32ME1", "MMI18HDBWCA32ME2", "MMI18HDBWCA6ME8", "MMI18HDBWCAAXME8", "MMI18HDBWCAME10",
        "MMI18HDBWCAME9", "MMI18HDBWCATME1", "MMI18HDBWCAX32ME1", "MMI18HDMCAME10", "MMI18HDMCAME9",
        "MMI24CDBWCA32ME1", "MMI24CDBWCA32ME2", "MMI24CDBWCA6ME8", "MMI24CDBWCAAXME8", "MMI24CDBWCAAXME9",
        "MMI24CDBWCAME9", "MMI24CDBWCATME1", "MMI24CDBWCAX32ME1", "MMI24CDMCAME10", "MMI24CDMCAME8",
        "MMI24CDMCAME9", "MMI24HDBWCA32ME1", "MMI24HDBWCA32ME2", "MMI24HDBWCA6ME8", "MMI24HDBWCAAXME8",
        "MMI24HDBWCAME10", "MMI24HDBWCAME8", "MMI24HDBWCAME9", "MMI24HDBWCATME1", "MMI24HDBWCAX32ME1",
        "MMI24HDMCAME10", "MMI24HDMCAME8", "MMI24HDMCAME9", "MMI36HDBWCA32ME1", "MMI36HDBWCAAXME8",
        "MMT12CABWCA32BME1", "MMT12CABWCAAXME8", "MMT12CABWCAME2", "MMT12CABWCAME3", "MMT12CABWCATME1",
        "MMT12CDBWCA32BME1", "MMT12CDBWCAAXME8", "MMT12CDBWCAME2", "MMT12CDBWCAME3", "MMT12CDBWCATME1",
        "MMT12HABWCA32BME1", "MMT12HABWCAAXME8", "MMT12HABWCAME2", "MMT12HABWCAME3", "MMT12HABWCAMEC3",
        "MMT12HABWCATME1", "MMT12HDBWCA32BME1", "MMT12HDBWCAAXME8", "MMT12HDBWCAME2", "MMT12HDBWCAME3",
        "MMT12HDBWCAMEC3", "MMT12HDBWCATME1", "MMT18CDBWCA32BME1", "MMT18CDBWCAAXME8", "MMT18CDBWCAME1",
        "MMT18CDBWCAME3", "MMT18CDBWCATME1", "MMT18HDBWCA32BME1", "MMT18HDBWCAAXME8", "MMT18HDBWCAME1",
        "MMT18HDBWCAME3", "MMT18HDBWCATME1", "MMT24CDBWCA32BME1", "MMT24CDBWCAAXME8", "MMT24CDBWCAME1",
        "MMT24CDBWCAME3", "MMT24CDBWCATME1", "MMT24HDBWCA32BME1", "MMT24HDBWCAAXME8", "MMT24HDBWCAME1",
        "MMT24HDBWCAME3", "MMT24HDBWCATME1", "MMT36CDBWCAAXME8", "MMT36HDBWCAAXME8", "PMI36HDBWCMIMXE1",
        "PMI48HDBWCMIMXE1", "PMI60HDBWCMIMXE1", "PTM12CABWAXM1", "PTM12CABWJM2", "PTM12HABWJM2",
      ],
      "ACCE": [
      ],
      "PURF": [
        "PMO050X2BB0", "PMO050Z3SP0", "PMO075Z3NS0", "PMO100Y5BB0", "PMO400Z4BB0",
        "PMO600Z6BB0", "PMU001Z3SS0", "PMU002Y4BB0",
      ]
    }
  }
}
# ANDINO: 1605 SKUs
# CEAM: 1625 SKUs
# NORTEAMERICA: 926 SKUs
# MEXICO: 509 SKUs
# TOTAL: 4665 SKUs
# Out:
# StatementMeta(, 39d21195-a990-4930-8dfa-0a4cf2989f2b, 7, Finished, Available, Finished)

# %%
  # -*- coding: utf-8 -*-
dict_skus = {
  "ANDINO": {
    "CO": {
      "LAVA": [
        "LMA0220WDGAB0", "LMA4120WDGAB0", "LMA6120WDGAB0", "LMA8120WDGAB0", "LMA9020WDGAB0",
        "LMA9020WGAB0", "LMD1123HBAB0", "LMD3123HBAB0", "LMD3124PBAB0", "LMD6124HBAB0",
        "LMA180GZI0", "LCA13SZI1", "LCA80GZI1", "LMA180BZI0", "LMD7023PBAB0","LMA1120WDGAB0"
      ],
      "COCC": [
        "1S2HE/16", "CG6012TX0", "CG9014P3I", "CG9016I3I", "CGCI400I0",
        "CGG6020V0", "CGG6020V1", "CGG6025V0", "CGG6025V1", "CGG7710I2",
        "CGG7715V2", "CGG8610I1", "CGG8610I2", "CGG8615V1", "CGG8615V2",
        "CGP95302MS1", "CGP95362MS1", "CHP90302TSS", "CHP90362TSS", "CHP95302MSS",
        "CHP95362MSS", "CM6018PI0", "CM6030N", "CM6030PI0", "CM6035NV0",
        "CM6035XV0", "CM6040NV0", "CM6040XV0", "CM9025II0", "CMG6015V0",
        "CMG6015V1", "CMG6018V0", "CMG6018V1", "CMG6044V0", "CSB913P2NS1",
        "CSB913P3ND1", "CSB923M2NS5", "CSB923P2NS1", "CSB923P3ND1", "CSB923P4NW2",
        "CTC912P2NS1", "CTG6010AI0", "CTM6011IX", "CTS70DM2NS5", "CTS70DP2NS1",
        "CTS90DP2NS1", "CTS90DP3ND1", "CTS90DP4NW2", "CTS90FP2NS1", "CTS90FP3ND1",
        "CTS90FP4NW2", "CVW93613MDS", "CVW93614MWM", "HM6014EUAI0", "HM6027GWAI0",
        "HM6028EUAI0", "HM6028EWN0", "HM6031EUAI0", "IO312DVI0", "IO614PVI0",
        "IOT8002I1", "PGP7030SLSS", "PGP7036SLSS", "PGP75TI0", "PGP95EBG0",
        "PGP95IV0", "PGP95KBG0", "PGP96TI0", "PHP9030SJSS", "PHP9036SJSS",
        "PHP9036STSS", "PIP6014S", "PM302I0", "PM6042GV0", "PM6046V0",
        "PM6048GV0", "PM64IV0", "PM7650GV0", "PM7655GNV0", "PP9036SJSS",
        "PSB9120BLTS", "PT7800SHSS", "PTS7000SNSS", "PV970NSS", "PV977NSS",
        "UVB30SKSS", "UVB36SKSS", "UVC7300SLSS", "UVD6361DPBB", "UVH13012MSS",
        "UVW9361BLTS", "ZGU30RSLSS", "ZGU36ESLSS", "ZHU30RSTSS", "ZHU36RSJSS",
        "ZHU36RSTSS", "ZSB9231NSS", "ZSB9232NSS", "ZTS90DPSNSS", "ZTS90DSSNSS",
        "ZV950SDSS", "ZVC48LSS", "ZWL1126SJSS","CM6048PIW0","CM7648PIW0"
      ],
      "GLOB": [
    "AFM38DN", "ALASKA11", "ALASKA14!", "ALASKA145B4", "ALASKA145B5",
    "ALASKA145BH", "ALASKA145BH1", "ALASKA19!", "ALASKA195BH", "ALASKA195BH1",
    "ALASKA200B4", "ALASKA200B5", "ALASKA30()", "ALASKA300B3", "ALASKA300B4",
    "ALASKA300BH", "ALASKA300BH1", "ALASKA43()", "ALASKA430B H", "ALASKA430B3",
    "ALASKA430BH", "ALASKA52()", "ALASKA520BH", "ALASKAV2()", "ALASKAV200S0",
    "ALASKAVIT", "ALASKAVIT220B1", "ALASKAVIT316CEG", "ALASKAVIT320B1", "ALASKAVIT416CEG",
    "CCP06BP2PS1", "CCP06BP3PD1", "CCP06BP4PW2", "CCP06DP2PS1", "CCP06DP4PW2",
    "CCR06BM2PS5", "CDE06RP3ND1", "CDT845P2NS1", "CDT845P3ND1", "CDT845P4NW2",
    "CDT858P3VD1", "CEB515P3NDS", "CEB515P4NWM", "CVM9179SLSS", "DM1260TPSS",
    "DM1460TPSS", "EMBL3TGS", "EMM2PB", "EMM2PN", "EMMCHB",
    "EMTLP3TB", "EMTLP3TBB", "GBF410SSPSS", "GBF412SSMSSX", "GBT632SSMSSEC",
    "GDT226SILII", "GFC525N", "GLV1460FSS", "GLV1890XSS0", "GW12XDB",
    "GW12XDBB", "GW8XDBB", "GXCFS7CCSS", "HMM07BB", "HMM07BR",
    "HMM07CE", "HMM07CEBN", "HMM07SB", "HMM07SBW", "HMM07SJW",
    "HMM07SN", "HMM09NJ1", "HMM11NP", "HMM11NPO", "HMM11SJW",
    "HMM11SN", "HMM15SJW", "HMM15SN", "HMM70SEJ", "ICMK12X0",
    "IO110MDI", "IO110MDI1", "JES11G1", "JES70G", "JVM3160RFSS",
    "MGE07SEJ", "MGE09SEJ", "MGE11SEJ", "MGE11XAF", "MGE14SEJG",
    "MXCBL01D", "MXCFS7W1", "PBT865SSPFS", "PBT865SSWFS", "PCWK22U1WDD",
    "PDT145SSLSS", "PDT715SYNFS", "PDT715SYVFS", "PEB110SFSS", "PEB160SFSS",
    "PEB7227ANDD", "PEB9159SJSS", "PLV1817XSS", "PVS06BSPSS", "PW29BS3",
    "PWS06DSPSS", "RMF02BRX", "RMF02BRX0", "RMF04BRX", "RMF04BRX0",
    "UCC15NPRII", "ZCWK22U2WSS", "ZDBI240HII", "ZDBR240NBS", "ZDT165SSLSS",
    "ZDT800SIFII", "ZDT915SSJSS", "ZDT975SSJSS", "ZDT985SINII", "ZDT985SPNSS",
    "ZDT985SSNSS", "ZDWI240HII", "ZEB1227SLSS", "ZIF301NPNII"
      ],
      "REFR": [
        "CFE28TP2MS1", "CFE28TP3MD1", "MSL480LMLPS0", "MSL480LMLSS0", "MSL480LPLPS0",
        "MSL480LPLSS0", "MSL504SONBS0", "MSL521QMLSS0", "MSL565QMLSP0", "MSL631LKLNG0",
        "MSL631LKLSG0", "MSL631LKLSS0", "MSL746IOLFS0", "MTL442LKLSS0", "RMB432PXBQP0",
        "RMB432PXBQS0", "RMF04BRX0", "ZIC30GNNII", "ZIK303NPPII", "ZIR301NPNII",
        "ZIR361NPRII", "ZISS480DNSS", "ZIW303NPPII","MSL631LKLSP0"
      ],
      "CALE": [
        "CAGLM1005AN1", "CAGLM1505AN1", "CAGLM2005AN1", "CAGM10ANS0", "CAGM15ANS0",
        "CAGM20ANS0", "CAGM30ANS0", "CAGM35ANS0", "CIM06C2SSNA", "CIM10C2NSNA",
        "CIM12C2NSNA", "CMD10TFBC", "CMD14TFBC", "CMD6TFBC", "CMM11C1FSNA",
        "CMM16C1FSNA", "CMM20C1FSNA", "CMP10TNBC", "CMP12TNBC", "CPGM1630BN"
      ],
      "AIAC": [
        "MGI18CDBC3", "MMI09CABWCCC1", "MMI09CABWCCC8", "MMI09CDBWCCC1", "MMI12CABWCCAXC9",
        "MMI12CABWCCBC1", "MMI12CABWCCC8", "MMI12CABWCCC9", "MMI12CABWCCCHI8", "MMI12CDBWCCAXC9",
        "MMI12CDBWCCBC1", "MMI12CDBWCCC8", "MMI12CDBWCCC9", "MMI12CDMCCC10", "MMI12CDMCCC8",
        "MMI18CDBWCCAXC9", "MMI18CDBWCCC8", "MMI18CDBWCCC9", "MMI18CDBWCCCHI8", "MMI18CDMCCC10",
        "MMI18CDMCCC8", "MMI24CDBWCCAXC9", "MMI24CDBWCCC8", "MMI24CDBWCCC9", "MMI24CDMCCC10",
        "MMI36HDBWCC32C1", "MMT09CABWCCC1", "MMT09CABWCCC8", "MMT09CDBWCCC1", "MMT12CABWCCAXC8",
        "MMT12CABWCCBC1", "MMT12CABWCCC8", "MMT12CABWCCCHI8", "MMT12CDBWCCAXC8", "MMT12CDBWCCBC1",
        "MMT12CDBWCCC8", "MMT18CDBWCCAXC8", "MMT18CDBWCCC8", "MMT24CDBWCCAXC8", "MMT24CDBWCCC8",
        "MMT24CDBWCCCHI8", "PTM12CABWJM2"
      ]
    },
    "EC": {
      "COCC": [
        "CDM6010AI0", "CGG7710IP0", "CGG8610IP0", "CMP9002I", "HM6027GWAI0",
        "HM6028EZAI0", "HM6031EZAI0", "PGP95IV0", "PHP774DMBB", "PM6032EV0",
        "PM64IV0", "PP932SMSS"
      ],
      "GLOB": [
        "AFM38DNEC", "ALASKA145B5", "ALASKA145BH", "ALASKA195BH", "ALASKA200B5",
        "ALASKA300B4", "ALASKA300BH", "ALASKA300BH1", "ALASKA430BH", "ALASKAH145B0",
        "ALASKAH200B2", "ALASKAH320B2", "ALASKAVIT220B1", "ALASKAVIT316CEG", "ALASKAVIT320B1",
        "ALASKAVIT416CEG", "CEB515P2NSS", "EMBL1TN", "EMBL3TGS", "EMDPCCB1",
        "EMM2PB", "EMM2PN", "FUF14SVRWW", "GBF410SSPSS", "GBF412SSMSSX",
        "GBT632SSMSSEC", "GFC720N", "GW12XDBB2", "GW8XDBB2", "GXCFS7CCSS",
        "H,TM09N", "HMM07CEBN", "HMM09NJ1", "HMM11NPO", "HTM10LN",
        "JES11SG", "JES14SG", "JES70SE", "JES70W", "JVM3670SK",
        "MGE07SEJ", "MGE09SEJ", "MGE11SEJ", "MGE11XAF", "MGE14SEJG",
        "MXCBL01D", "MXCFS7CCSS", "PBT865SSPFS", "PEB110SFSS", "PEB160SFSS",
        "PLV1817XSS", "RMF0260XMXX3", "RMF04ERB0", "RMF04ERX0", "XO1120MD1",
        "ZEB1227SLSS","HTM10LN1"
      ],
      "LAVA": [
        "LMD6124PBAB0", "LMDE3124PBAB0", "LMDE7023PBAB0", "LMDX1123HBAB0", "LMDX3123HBAB0",
        "LMDX6124HBAB0", "LMDX8124HBAB0", "LME7120WDGAB0", "LME9120WDGAB0"
      ],
      "REFR": [
        "LMD6124PBAB0", "LMDE3124PBAB0", "LMDE7023PBAB0", "LMDX1123HBAB0", "LMDX3123HBAB0",
        "LMDX6124HBAB0", "LMDX8124HBAB0", "LME7120WDGAB0", "LME9120WDGAB0", "MSE480LPLPS0",
        "MSE480LPLSS0", "MSE521QMLSS0", "MSL631LKLNG0", "MTL442LKLSS0", "RMB432PXBQS0"
      ],
      "AIAC": [
        "MMI12CDBWCCE8", "MMI24CDBWCCE8", "MMT12CDBWCCAX8", "MMT12CDBWCCE8", "MMT18CDBWCCAX8",
        "MMT18CDBWCCE8", "MMT24CDBWCCAX8", "MMT24CDBWCCE8", "PTM12CABWJM2"
      ]
    },
    "PE": {
      "COCC": [
        "CGG6025V0", "CGG6025V1", "CGG8610I1", "CGG8610I2", "CGG8615V1",
        "CGG8615V2", "CGP9536SLSS", "CGPI9007IP0", "CM6016PI0", "CM6018PI0",
        "CM6018PIY0", "CM9016PI0", "CM9018PIY0", "CMG6015V0", "CMU6020PB0",
        "CMU6020PI0", "CMU9020PI0", "HM6028EYAI0", "HVGP4561YI", "IO905I0",
        "JGP3036SLSS", "JGP5030SLSS", "JGP5530SLSS", "JGP5536SLSS", "JP3530SJSS",
        "JP3536SJSS", "JTS3000SNSS", "JTS5000SNSS", "PGP7030SLSS", "PGP7036SLSS",
        "PGP75TI0", "PGP9030SLSS", "PGP9036SLSS", "PGP95EBG0", "PGP95KBG0",
        "PM6045GV0", "PM8655GV0", "PTS7000SNSS", "PV977NSS", "UVW9361BLTS",
        "ZET1PHSS", "ZGU36RSLSS", "ZSC1202JSS", "ZSC2202JSS", "ZV800SJSS",
        "ZV850SPSS", "ZV925SLSS"
      ],
      "GLOB": [
        "ALASKAVIT316PG", "ALASKAVIT416PG", "CHM200PB1", "CHM200PB2", "CHM200PB3",
        "CHM300PB2", "CHM300PS2", "CHM320PB1", "CHM320PS1", "CHM430PB2",
        "DAMYPRB0", "GDT225SSLSS", "GDT635HSJSS", "GFC525V", "GWS04HAESS",
        "GXCF05PFS2", "HMM07PBN", "HMM09PNJ", "HMM11PNPO", "HMM20PEB",
        "HMM20PEE", "HMM20PEG", "HMM23PSX", "HMM25PSX", "HMM28PSX",
        "HMM31PSX", "JES1495PSK", "MXCF05PFS", "PCR06WATSS", "PEB7227SLSS",
        "PEB9159SJSS", "RMF04PRB0", "RMF04PRX0", "RMF04PV0", "WDP6001I",
        "ZEB1227SLSS", "ZIDS240HSS", "ZIFS360NHLH"
      ],
      "LAVA": [
        "LMA0120WPBB0", "LMA100BXI0", "LMA100GXI0", "LMA105BXI0", "LMA1220WDGBB0",
        "LMA160BXI0", "LMA160SXI0", "LMA4120WDGBB0", "LMA4120WPBB0", "LMA6120WDGBB0",
        "LMA6120WPBB0", "LMA8120WDGBB0", "LMA9020WGBB0", "LMA95BXI", "LMAP1010WBBB0",
        "LMAP1012WBBB0", "LMAP1015WGBB0", "LMAP4110WGBB0", "LMAP4120WGABB0", "LMAP4120WGBB0",
        "LMAP6110WBBB0", "LMAP6115WGBB0", "LMAP6120WGBB0", "LMAP9020WGBB0", "LMD3124PBBB0",
        "LMD6124PBBB0", "SEM090VBBB0", "SEM81BDBB", "LME1220WDGAB0", "SEM81BDGB"
      ],
      "REFR": [
        "MSC518LKRSS0", "MSD480LMRPS0", "MSD480LMRSS0", "MSD480LPRPS0", "MSD480LPRSS0",
        "MSD504SORBS0", "MSD518LKRSS0", "MSD525SERBS0", "MSD565QMLSP0", "MSD565QMLSS0",
        "MSD631LKLNG0", "MTD442LKRSS0", "RMB315PTPRO0", "RMB432PXPRP0", "RMB432PXPRS0",
        "RMN220PVPRX0", "RMU202PXPRS0", "RMU202PXPRS1"
      ],
      "AIAC": [
        "MMI09CDBWCCC1", "MMI12CDBWCCBC1", "MMT09CDBWCCC1", "MMT12CDBWCCBC1", "MMT12CDBWCCC8",
        "MMT12CDBWCCCE8", "MMT18CDBWCCC8", "MMT18CDBWCCCE8"
      ]
    },
    "CL": {
      "COCC": [
        "CG6003TX0", "CM6045XV0", "CM6048PIX0", "CM6048PNX0", "HM6031EXAI0",
        "HM6045EXN0", "PG6040EVN0"
      ],
      "GLOB": [
        "FDHM150BY0", "FDHM150BY1", "FDHM150BY2", "FDHM200BY0", "FDHM200BY1",
        "FDHM200BY2", "GLV14FSITSS0", "HMM07CHBN", "HMM09CHNJ", "MLV14FSITSS0",
        "RMF02LRX0", "RMF04HV0", "RMF04LRX0"
      ],
      "LAVA": [
        "LMA0920WBCL0", "LMA0920WGCL0", "LMA4120WDGCL0", "LMA5120WDGCL0", "LMA6120WDGCL0",
        "LMA6120WGCL0", "LMA7120WDGCL0", "LMA8120WDGCL0", "LMA8120WGCL0", "LMA9020WDGCL0",
        "LMA9120WDGCL0", "LMA9520WDGCL0", "SEM010VBCL0", "SEM010VDCL0", "SEM101BDBY",
        "SEM101BDBY0", "SEM81BDBY", "SEM81BDGY","LMA2120WDGCL0"
      ],
      "REFR": [
        "MSC480LKRPS0", "MSC518LKRSS0", "MSC525SERBS0", "MSC631LKLNG0", "MTC442LKRSS0",
        "RMB176PXLCX0", "RMB276PXLCX0", "RMB302PXLRS0", "RMB426PXLRS0", "RMB432PXLRS0",
        "RMN220PVLRX0", "RMN222PXLRS0"
      ]
    },
    "AR": {
      "COCC": [
        "AEDR60CNV", "AEGE62PV", "AEGE62VN0", "AGDR60CNV", "AGDR60EIA",
        "AGDR60EIA1", "AGDR76CIA", "AGGE62IV", "AGGE62VN0", "AGGE76I0",
        "CD5003MI", "CD5502AB", "CD5502AI", "CD5502MB", "CD5502MI",
        "CD5505AI", "CD5507AI", "CD5507MI", "CD5602AB0", "CD5602AI0",
        "CD5602AN0", "CD5603AB0", "CD5603AI0", "CD5603AN0", "CD5614AI0",
        "CD5617AI0", "CD6007MI", "CG756I", "CG760I", "CP6855AB",
        "CP6855AI", "CP6855B", "CP6855I", "CP756AI", "CP9656AI",
        "CP9656I", "CP9750I", "CRDR60IA", "CRDR90IA", "CRGE60I",
        "CTGE60I0", "CTGE90I0", "CUDR604BA", "CUDR604IA", "CUDR604NA",
        "CVGE90I", "HD60EGCV0", "HEDR600CI", "HEDR600MI", "HEDR601CN",
        "HEDR601MI", "HEGE6050I", "HEGE6055I", "HG6018EVAI0", "HG6035EVAI0",
        "HGDR601CN", "HM60EGCI0"
      ],
      "GLOB": [
        "601400511", "601400512", "601400592", "601400593", "601400594",
        "601400595", "601400611", "601400612", "601400621", "601400627",
        "601400629", "601400673", "601400674", "601400677", "601400781",
        "601400782", "601400784", "601400785", "601400786", "601400787",
        "601400788", "601400789", "601400790", "601400791", "601400792",
        "601400793", "601400794", "601400796", "601400801", "601400802",
        "601400807", "601400808", "601400809", "601400810", "601400811",
        "601400824", "601400828", "601400829", "601400830", "601400852",
        "601400853", "601400854", "601400855", "601400856", "601400890",
        "601400899", "601400915", "601400916", "601400917", "601400918",
        "601400919", "CVDR08CN0", "CVDR12CN0", "FHDR143CB", "FHDR293CB",
        "FHP220B", "FHP300B", "FHP420B", "HMD20ARBB0", "HMD20ARNJ0",
        "HMD20ARSB0", "HMD25ARSB0", "HMD30ARSJ0", "HPK90B", "LVDR1306CB0",
        "LVDR1306CI0", "LVDR1406CB0", "LVDR1406CI0", "LVDR1506CI0", "RDF04LGAS0"
      ],
      "LAVA": [
        "700100711", "700200378", "700200380", "700200382", "701000860",
        "701000862", "701000964", "701000976", "701100040", "701100108",
        "701100124", "701100150", "701100156", "701100182", "701100196",
        "701100198", "701100204", "701100206", "701100212", "701100278",
        "701100280", "701100282", "701100284", "701100286", "701500000",
        "701500001", "709802016", "709802457", "709802585", "709802587",
        "709802594", "709802832", "709802833", "709802834", "709802836",
        "709802837", "709802838", "709802840", "709802906", "709803246",
        "709803250", "709803251", "709803252", "709803386", "709803398",
        "709803399", "709803422", "709803423", "709803424", "709803430",
        "709803431", "709803443", "709803444", "709803596", "709803598",
        "709803599", "709803600", "709803612", "709803752", "709803766",
        "709803783", "709803804", "709803805", "709803809", "709803812",
        "709803826", "709803827", "709803828", "709803859", "709803860",
        "709803861", "709803862", "709803863", "709803864", "709803903",
        "709803973", "709803988", "709803989", "709803990", "709803995",
        "709803996", "709803997", "709804000", "709804028", "709804035",
        "709804036", "709804037", "709804038", "709804039", "709804052",
        "709804095", "709804199", "709804218", "709804347", "709804348",
        "709804376", "709804406", "709804407", "709804422", "709804442",
        "709804443", "709804444", "709804466", "709804468", "709804543",
        "709804580", "709804581", "709804582", "709804594", "709804612",
        "709804613", "709804614", "709804639", "709804656", "709804659",
        "709804660", "709804673", "709804674", "709804675", "709804676",
        "709804677", "709804678", "709804679", "709804680", "709804681",
        "709804698", "709804699", "709804700", "709804789", "709804824",
        "LCFDR0608LB0", "LCFDR0609LB0", "LCFDR0610LB0", "LCFDR0710SB0",
        "LCFDR0814SB0", "LCFDR0814SG0", "LCFDR1012SB0", "LFDR0606LB0",
        "LFDR0608LB0", "LFDR0609LB0", "LFDR0610ISB0", "LFDR0710ISB0",
        "LFDR0710ISG0", "LFDR0710SB0", "LFDR0814SB0", "LFDR0814SG0",
        "LFDR0914ISG0", "LFDR1012SB0", "LFDR1012TG0", "LFDR1114ISG0",
        "LFDRI0710SB0", "LFJA0914SB0", "LFMA0709LB0", "LFMA0810SB0",
        "LFMA1014SB0", "LFMA1312SG0", "LPDR0665ILG", "LPDR0865ILG",
        "LPDR1165LG", "LPDR1165LG0", "LRDR56SB0", "LRDR57SB0",
        "LRJM56SB0", "LRPK56SB0", "LRPK57SB0", "LRSH56SB0",
        "LSCDR0805SB0", "LSCDR0805SG0", "LSCDR1006SG0", "LSCDR1106I",
        "LSCDR1208SG0", "LSCPK1106I", "LSDR0680TB0", "LSDR0680TS0",
        "LTDR0608PB0", "LTDR0610PB0", "LTDR0714PBI0", "LTDR0714PGI0",
        "LTDR0810PB0", "LTDR0810PI0", "LTDR67SB0", "LTDR79SB0",
        "LTDRI0714PB0", "LTDRI0714PG0", "PRIMMA5N", "SCPK07B",
        "SCPK07M", "SED090VBCL0", "SED090VGCL0"
      ],
      "REFR": [
        "DSP480LKRSS0", "DSP610IORSS0", "DTP458BKRSS0", "DTP469LKRSS0",
        "GEPS6FGKFSS", "HDR120F00B", "HDR120F00N", "HDR120F00S",
        "HDR280F00B", "HDR280F30PB", "HDR280F50B", "HDR280F50PB",
        "HDR300N00B", "HDR300N00M", "HDR300N30B", "HDR300N30M",
        "HDR320F00N", "HDR320F00S", "HDR320F50E", "HDR320F50N",
        "HDR320F50NE", "HDR320F50S", "HDR370F00B", "HDR370F00S",
        "HDR370F11S", "HDR370F50B", "HDR370F61E", "HDR370F61S",
        "HDR380N12M", "HDR380N12N", "HDR400F00B", "HDR400F00S",
        "HDR400F11N", "HDR400F11S", "HDR400F30B", "HDR400F30E",
        "HDR400F30S", "HDR400F41E", "HDR400F41N", "HDR400F41S",
        "HDR420N00B", "HDR420N00M", "HDR420N30B", "HDR420N30M",
        "HDR430N12M", "HDR430N42M", "HETOKMAGNA350", "HETOKMAGNA350N",
        "HETOKMAGNA360", "HGE455M12L", "HME280F00B", "HME320F00S",
        "HPK120P00B", "HPK120P00S", "HPK120P00S02", "HPK135B01",
        "HPK135B01-C", "HPK135M", "HPK135M00B01", "HPK135MA00B01",
        "HPK135P00B01", "HPK136M00N01", "HPK136M00S01", "HPK136S01",
        "HPK141M00B", "HPK141M10S", "HPK151M00B", "HPK151M11N01",
        "HPK151M11S", "HPK151M11S02", "HPK350M00B", "HPK350M00L",
        "HPK450M00B", "HPK450M00L", "HTH135M00B01", "JM350BLANCO",
        "MD-HFH340MK", "MD-HFH400MK", "MD-HFH400NG", "MD-HFHIN340MK",
        "PQP458BKRSS0", "RDA250FVRT", "RDA300FBRT", "RDA300FHRT",
        "RDP400FZRT", "RDP410ZRT", "RENX24281FHS", "RENX24281FHW",
        "RENX24301FHS", "RGA300FHRE", "RGS1951BGRX0", "RRS1540BGRX0",
        "RZB210PVARX0", "RZB520IJARX0", "RZD215PVARX0", "RZN320PCARX0",
        "RZS510IBARX0", "YEP26FGTFSS", "YRP26FGTFSS"
      ]
    }
  },
  "CEAM": {
    "CR": {
      "REFR": [
        "CFE28TP2MS1", "CFE28TP3MD1", "CFE28TP4MW2", "CWE23SP2MS1", "CWE23SP4MW2",
        "HBM425EMNSS0", "HQM458BKNSS0", "HSM518HMNSS0", "HSM541HMNSS0", "MSM504SONBS0",
        "MSM544LMLSS0", "MSM631LKLNG0", "MSM631LKLSS0", "MSM746IOLFS0", "MSM746LIOLFS0",
        "MTM482SENSS0", "RMC181PXCRB0", "RMC181PXCRX0", "RMC181PXMRX0", "RMC181PYMRX0",
        "RMD165PVCRB0", "RMD165PVCRS0", "ZIF241NPNII", "ZIF361NPRII", "ZIR241NPNII",
        "ZIR301NPNII", "ZIR361NPRII", "ZISS420DNSS", "ZISS480DNSS", "ZWE23NSTSS","MSM480LKLSS0"
      ],
      "LAVA": [
        "CHAC2186NXGG0", "CPA2412NXDG0", "GFD55ESSNWW", "GFW550SSNWW", "LHA9120WGAB0",
        "LMA5120WPAB0", "LMA6120WDGAB0", "LMA8120WDGAB0", "LMD2200B0", "LMDX1123HBAB0",
        "LMDX2224HBAB0", "LMDX3123HBAB0", "LMDX6124HBAB0", "LMDX8124HBAB0"
      ],
      "GLOB": [
        "AFM38DN", "CCWK15C1WSS", "CCWK15C1WWM", "CDT828P2VS1", "CDT858P3VD1",
        "CDT875P4NW2", "CDT888P4VW2", "CEB515P2NSS", "CEB515P4NWM", "CHC11BPL5",
        "CHC11BPS0", "CHC15BPL4", "CHC25BPL2", "CHC5BPL40", "CHC5BPS1",
        "CHC7BPL30", "CHC7BPS1", "CHC9BPL3", "CHC9BPS1", "CHM11BPL4",
        "CHM11BPL5", "CHM11PHL0", "CHM15BPL4", "CHM15PHL0", "CHM25BPL1",
        "CHM25BPL2", "CHM25PGL0", "CHM5BPL3", "CHM5BPL40", "CHM5PPL0",
        "CHM7BPL30", "CHM7PPL0", "CHM9BPL4", "CHM9PPL0", "CVM517P2RS1",
        "EMM2PB", "EMM2PN", "GBF410SSPSS", "GBP655SSPSS", "GLV1460FSS",
        "GW8XDBB2", "HLV0845FSSS", "HMM07BJ", "HMM07PJB", "HMM07PJN",
        "HMM09NJ", "HMM114SEJ", "HMM70BS", "HMM70SEJ", "HMM70SW",
        "IO110MDI", "IO160MDI", "IO1702LI6", "IO1716LI0", "JES1153SFE",
        "JES11W", "JES14W", "JES70SE", "JES70W", "JVM3162RJSS",
        "MGE07SEJ", "MGE09SEJ", "MGE14XEJG", "MXCFS7CCSS", "PBT865SMPES",
        "PBT865SSPFS", "PCWK22U1WDD", "PEB110SFSS", "PEB160SFSS", "PEB7227ANDD",
        "PVM9215SKSS", "PW29BS3", "QDP225SSPSS", "RMF0260XMXB3", "RMF0260XMXX3",
        "RMF0411PYMB0", "RMF0411PYMX0", "VM2164LB0", "VM3164LB0", "ZCWK22U2WSS",
        "ZDT925SINII", "ZDT925SPNSS", "ZDWR240NBS", "ZIF301NPNII"
      ],
      "COCC": [
        "CEP90302TSS", "CEP90361TBB", "CGP70302NS1", "CGP95302MS1", "CM6045UIW0",
        "CM7618PIW0", "CM7645UGW0", "CM7645UIW0", "CM7645UNW0", "CM7648PIW0",
        "CTS70DP2NS1", "CTS90DP3ND1", "CTS90DP4NW2", "CTS90FP4NW2", "HM6031EUAI0",
        "IO6040EVN0", "IO7650EVN0", "JP3030SWSS", "JTS3000SNSS", "JTS5000SVSS",
        "PIP8014", "PM302I0", "PM6040EVN0", "PM64IV0", "PP7030SJSS",
        "PP930SMSS1", "PP936SMSS1", "UVC9480SLSS", "ZGU36ESLSS", "ZHU30RDTBB",
        "ZHU30RSTSS", "ZHU36RSTSS", "ZSB9231NSS", "ZTS90DPSNSS", "ZTS90DSSNSS",
        "ZVW1480SPSS"
      ],
      "CALE": [
        "CDM40SLP", "CDM80SLP", "CIM062SLP", "CIM102SLP", "CIM11KWCA2SSE",
        "CIM142SLP", "CIM15KWCA2SSE", "CMM11M1FSLP", "CMM16M1FSLP", "CRM06SLP",
        "CRM09SLP"
      ],
      "AIAC": [
        "HS12HFW13MI", "HS18HFB13MI", "HS18HFW13MI", "HS24HFW13MI", "MMI12CABWCC32M1",
        "MMI12CABWCC6M9", "MMI12CDBWCC32M1", "MMI12CDBWCC6M8", "MMI12CDBWCC6M9", "MMI18CDBWCC32M1",
        "MMI18CDBWCC6M8", "MMI24CDBWCC32M1", "MMI24CDBWCC6M8", "MMT12CDBWCCM2", "MMT12CDBWCCTM1",
        "MMT18CDBWCCM1", "MMT18CDBWCCTM1", "PTM12CABWJM2"
      ]
    },
    "GT": {
      "REFR": [
        "CFE28TP2MS1", "CFE28TP4MW2", "CWE23SP4MW2", "HBM425EMNSS0", "HQM458BKNSS0",
        "HSM541HMNSS0", "MSM504SONBS0", "MSM544LMLSS0", "MSM631LKLNG0", "MSM631LKLSS0",
        "MSM746IOLFS0", "MSM746LIOLFS0", "MTM482SENSS0", "RMC181PXCRB0", "RMC181PXCRX0",
        "RMD165PVCRB0", "RMD165PVCRS0", "RMN207PVCRX0", "RMN240PVRRX0","MSM480LKLSS0"
      ],
      "LAVA": [
        "CHAC2186NXGG0", "CPA2412NXDG0", "GFD55ESSNWW", "GFW550SSNWW", "LHA9120WGAB0",
        "LMA4120WDGAB0", "LMA5120WPAB0", "LMA8120WDGAB0", "LMDX2224HBAB0"
      ],
      "GLOB": [
        "AFM38DN", "ALASKAVIT416CEG", "CCWK15C1WSS", "CDT805P2NS1", "CDT828P2VS1",
        "CDT875P4NW2", "CEB515P4NWM", "CHC11BPL5", "CHC11BPS0", "CHC15BPL4",
        "CHC25BPL2", "CHC5BPL40", "CHC5BPS1", "CHC7BPL30", "CHC7BPS1",
        "CHC9BPL3", "CHC9BPS1", "CHM11BPL4", "CHM11BPL5", "CHM11PHL0",
        "CHM15BPL4", "CHM15PHL0", "CHM25BPL1", "CHM25BPL2", "CHM25PGL0",
        "CHM5BPL40", "CHM5PPL0", "CHM7BPL2", "CHM7BPL30", "CHM7BPS1",
        "CHM7PPL0", "CHM9BPL4", "CHM9PPL0", "EMDPCCB3", "EMM2PB",
        "EMM2PN", "FCM5FSWH", "GBF410SSPSS", "GBP655SSPSS", "GLV1460FSS",
        "GW8XDBB2", "HLV0845FSSS", "HMM07BJ", "HMM07PJB", "HMM07PJN",
        "HMM09NJ", "HMM111BS", "HMM11XEB", "HMM700WK", "HMM70SEJ",
        "IO110MDI", "IO160MDI", "IO1702LI6", "JVM3162RJSS", "MGE07SEJ",
        "MGE09SEJ", "MGE11SEJ", "MXCBL01D", "MXCFS7CCSS", "PBT865SMPES",
        "PBT865SSPFS", "PEB110SFSS", "PEB160SFSS", "PEB7227ANDD", "PW29BS3",
        "QDP225SSPSS", "RMF0260XMXB3", "RMF0260XMXX3", "RMF0411PYMB0", "RMF0411PYMX0",
        "UCC15NPRII", "VC2164LB0", "VC3164LB0", "VM2164LB0", "VM3164LB0",
        "ZDBR240NBS", "ZDT925SINII", "ZDT925SPNSS", "ZDWR240NBS", "ZEB1227SLSS",
        "ZIDS240NSS"
      ],
      "COCC": [
        "CEP90361TBB", "CM6045UIW0", "CM7618PIW0", "CM7645UGW0", "CM7645UIW0",
        "CM7645UNW0", "CM7648PIW0", "CTS70DP2NS1", "CTS90DP4NW2", "HM6031EUAI0",
        "IO6040EVN0", "IO7650EVN0", "JTS3000SNSS", "JTS5000SNSS", "JTS5000SVSS",
        "PIP8014", "PM302I0", "PM6040EVN0", "PM64IV0", "PP930SMSS1",
        "PP936SMSS1", "UVC9480SLSS", "UVW93642PSS", "ZGU30RSLSS", "ZHU30RSTSS",
        "ZTS90DPSNSS", "ZVW1480SPSS"
      ],
      "CALE": [
        "CDM40SLP", "CDM80SLP", "CIM062SLP", "CIM102SLP", "CIM11KWCA2SSE",
        "CIM142SLP", "CIM15KWCA2SSE", "CMM11M1FSLP", "CMM16M1FSLP", "CRM06SLP",
        "CRM09SLP"
      ],
      "AIAC": [
        "HS12HFW13MI", "MCI12CABWCCAX9", "MMI12CABWCC32M1", "MMI12CABWCC6M8", "MMI12CABWCC6M9",
        "MMI12CABWCCAX8", "MMI12CDBWCC32M1", "MMI18CDBWCC32M1", "MMI18CDBWCC6M8", "MMI18CDMCCM8",
        "MMI24CDBWCC32M1", "MMI24CDBWCC6M8", "MMI36HDBWCAAXM8", "MMT12CABWCCM2", "MMT12CABWCCTM1",
        "MMT12CDBWCCM2", "MMT12CDBWCCTM1", "MMT18CDBWCCM1", "MMT24CDBWCCM1", "PTM12CABWJM2"
      ]
    },
    "HN": {
      "REFR": [
        "HBM425EMNSS0", "HQM458BKNSS0", "HSM518HMNSS0", "HSM541HMNSS0", "MSM504SONBS0",
        "MSM521HKNSS0", "MSM544LMLSS0", "MSM631LKLNG0", "MSM631LKLSS0", "MSM746IOLFS0",
        "MSM746LIOLFS0", "MTM482SENSS0", "RMC181PXCRB0", "RMC181PXCRX0", "RMD165PVCRB0",
        "RMD165PVCRS0", "RMN207PVCRX0", "RMN240PVRRX0"
      ],
      "LAVA": [
        "CHAC2186NXGG0", "LHA9120WGAB0", "LMA4120WDGAB0", "LMA5120WPAB0", "LMA8120WDGAB0",
        "LMDX2224HBAB0"
      ],
      "GLOB": [
        "AFM38DN", "ALASKAVIT416CEG", "CHC11BPL5", "CHC11BPS0", "CHC15BPL4",
        "CHC25BPL2", "CHC5BPL40", "CHC5BPS1", "CHC7BPL30", "CHC7BPS1",
        "CHC9BPL3", "CHC9BPS1", "CHM11BPL5", "CHM11PHL0", "CHM15BPL3",
        "CHM15BPL4", "CHM15PHL0", "CHM25BPL1", "CHM25BPL2", "CHM25PGL0",
        "CHM5BPL3", "CHM5BPL40", "CHM5PPL0", "CHM7BPL2", "CHM7BPL30",
        "CHM7PPL0", "CHM9BPL4", "CHM9PPL0", "EMDPCCB3", "EMM2PB",
        "EMM2PN", "GBF410SSPSS", "GLV1460FSS", "HLV0845FSSS", "HMM07PJB",
        "HMM07PJN", "HMM09NJ", "HMM111BS", "HMM700WK", "IO110MDI",
        "IO1702LI6", "JES11W", "JES70SE", "JES70W", "JVM3162RJSS",
        "MGE07SEJ", "MGE09SEJ", "MGE11SEJ", "MXCFS7CCSS", "PEB160SFSS",
        "PW29BS3", "QDP225SSPSS", "RMF0260XMXB3", "RMF0260XMXX3", "RMF0411PYMB0",
        "RMF0411PYMX0", "VM2164LB0", "VM3164LB0"
      ],
      "COCC": [
        "CM6045UIW0", "CM7618PIW0", "CM7645UGW0", "CM7645UIW0", "CM7645UNW0",
        "HM6031EUAI0", "IO6040EVN0", "IO7650EVN0", "JTS5000SVSS", "PM302I0",
        "PM6040EVN0", "PM64IV0", "PP930SMSS1"
      ],
      "CALE": [
        "CIM11KWCA2SSE", "CIM15KWCA2SSE"
      ],
      "AIAC": [
        "HS12HFW13MI", "HS18HFB13MI", "HS18HFW13MI", "HS24HFW13MI", "MMI12CDBWCC32M1",
        "MMI12CDBWCC6M9", "MMI12CDBWCCTM1", "MMI18CDBWCC6M8", "MMI18CDBWCCTM1", "MMI24CDBWCC6M8",
        "MMI24CDBWCCTM1", "MMT12CDBWCCM2", "MMT12CDBWCCTM1", "MMT18CDBWCCM1", "MMT18CDBWCCTM1",
        "MMT24CDBWCCM1", "MMT24CDBWCCTM1", "PTM12CABWJM2"
      ]
    },
    "SV": {
      "REFR": [
        "CFE28TP2MS1", "CFE28TP3MD1", "CFE28TP4MW2", "HBM425EMNSS0", "HFM410LPLSS0",
        "HQM458BKNSS0", "HSM541HMNSS0", "HTM507JMLSS0", "MSM504SONBS0", "MSM544LMLSS0",
        "MSM631LKLNG0", "MSM631LKLSS0", "MSM746IOLFS0", "MSM746LIOLFS0", "MTM482SENSS0",
        "RMC181PXCRB0", "RMC181PXCRX0", "RMD165PVCRB0", "RMD165PVCRS0", "RMN207PVCRX0",
        "RMN240PVRRX0", "ZICS360NNLH", "ZICS360NNRH", "ZISS480DNSS","MSM480LKLSS0"
      ],
      "LAVA": [
        "CHAC2186NXGG0", "GFD55ESSNWW", "GFW550SSNWW", "LHA9120WGAB0", "LMA4120WDGAB0",
        "LMA5120WPAB0", "LMA6120WDGAB0", "LMA8120WDGAB0", "LMDX2224HBAB0"
      ],
      "GLOB": [
        "AFM38DN", "ALASKAVIT416CEG", "CCWK15C1WSS", "CDT828P2VS1", "CDT875P4NW2",
        "CEB515P2NSS", "CEB515P4NWM", "CHC11BPL5", "CHC11BPS0", "CHC15BPL4",
        "CHC25BPL2", "CHC5BPL40", "CHC5BPS1", "CHC7BPL30", "CHC7BPS1",
        "CHC9BPL3", "CHC9BPS1", "CHM11BPL5", "CHM11PHL0", "CHM15BPL4",
        "CHM15PHL0", "CHM25BPL1", "CHM25BPL2", "CHM25PGL0", "CHM5BPL3",
        "CHM5BPL40", "CHM5PPL0", "CHM7BPL2", "CHM7BPL30", "CHM7PPL0",
        "CHM9BPL4", "CHM9PPL0", "CVM517P2RS1", "EMDPCCB3", "EMM2PB",
        "EMM2PN", "GBF410SSPSS", "GBP655SSPSS", "GLV1460FSS", "HLV0845FSSS",
        "HMM07PJB", "HMM07PJN", "HMM09NJ", "HMM700WK", "IO110MDI",
        "IO160MDI", "IO1702LI6", "JES11W", "JES14W", "JES70SE",
        "JES70W", "JVM3162RJSS", "MGE07SEJ", "MGE09SEJ", "MGE11SEJ",
        "MXCFS7CCSS", "PBT865SMPES", "PBT865SSPFS", "PCWK22U1WDD", "PEB110SFSS",
        "PEB160SFSS", "PEB7227ANDD", "PLV1817XSS", "PVM9215SKSS", "PW29BS3",
        "QDP225SSPSS", "RMF0260XMXB3", "RMF0260XMXX3", "RMF0411PYMB0", "RMF0411PYMX0",
        "UCC15NPRII", "VM2164LB0", "VM3164LB0", "ZCWK22U2WSS", "ZDT925SPNSS",
        "ZEB1227SLSS"
      ],
      "COCC": [
        "CGP70302NS1", "CGP70362NS1", "CM6045UIW0", "CM7618PIW0", "CM7645UGW0",
        "CM7645UIW0", "CM7645UNW0", "CTS70DP2NS1", "CTS90FP2NS1", "HM6031EUAI0",
        "IO312DVI0", "IO6040EVN0", "IO7650EVN0", "JTS3000SNSS", "JTS5000SVSS",
        "PIP8014", "PM302I0", "PM6040EVN0", "PM64IV0", "PP930SMSS1",
        "PP936SMSS1", "UVW93642PSS", "ZGU36ESLSS", "ZTS90DPSNSS", "ZVW1480SPSS"
      ],
      "CALE": [
        "CIM11KWCA2SSE", "CIM15KWCA2SSE"
      ],
      "AIAC": [
        "MMI12CABWCC32M1", "MMI12CABWCC6M9", "MMI12CDBWCC32M1", "MMI12CDBWCC6M9", "MMI18CDBWCC32M1",
        "MMI24CDBWCC32M1", "MMI24CDBWCC6M8", "MMT12CDBWCCTM1", "PTM12CABWJM2"
      ]
    }
  },
  "NORTEAMERICA": {
    "CA": {
      "REFR": [
        "MPE12FGKWW", "MTE18GTKWW", "GTE16DTNRWW", "MBE11DSVSS", "MDE19DTNKWW", "GBE17HYRFS",
        "GTE17GTNRWW", "MDE19DSNKSS", "MTE18HSKRSS", "GTE17GSNRSS", "HPE16BTNRWW", "GTS18FTLKWW",
        "MTE18HTKBB", "MPE12FSKSB", "MTE18GSKSS", "MNE18DYTNFS", "GTE18FTLKWW", "GTS18FSLKSS",
        "GTE18FSLKSS", "MTE18HTKRWW", "M2E9FPMKII", "GPE12FSKSB", "GTE17DTNRWW", "GPE12FGKWW",
        "CJE23DP4WW2", "CJE23DP2WS1", "HRB15N3BGS", "GLE12HSPSS", "QHE16HYPFS", "QJS15HYRFS",
        "MPE12FGKLWW", "GTE18GMNRES", "CWE23SP4MW2", "GTE18DTNRWW", "CXE22DP4PW2", "PGE29BYTFS",
        "GTE18FTLKBB", "CVE28DP4NW2", "CWE23SP2MS1", "GTS18FTLKBB", "PAD28BYTFS", "CYE22TP4MW2",
        "CVE28DP2NS1", "CJE23DM5WS5", "MBE19DTNKWW", "CXE22DP2PS1", "MBE19DSNKSS", "MYE22HYPKFS",
        "CVE28DP3ND1", "CWE23SP3MD1", "CYE22TP2MS1", "CXE22DP3PD1", "ZISS480DNSS", "PYD22KYNFS",
        "CSB48WP2NS1", "CYE22TP3MD1", "CXE22DM5PS5", "ZIR301NPNII", "MWE22FYPKFS", "ZIS480NNII",
        "ZIC303NPPII", "ZIR361NPRII", "ZIS420NNII", "ZISS420DNSS", "ZISS480NNSS", "ZIF241NPNII",
        "ZIR301NBRII", "ZIP364IPVII", "ZIK303NPPII", "ZISB480DNII", "ZIW303NPPII", "CSB42WP2NS1",
        "CYE22UP2MS1", "ZISS420NNSS", "ZIC363IPVRH", "ZIF361NPRII", "ZIR241NPNII", "ZISB420DNII",
        "ZWE23NSTSS", "ZIC363IPVLH", "ZIR361NBRII", "GTE18GSNRSS", "ZIF361NBRII", "ZIC363NBVRH",
        "ZIP364NBVII", "ZISB360DNII", "ZWE23NSYSS", "ZISS360DNSS", "ZIR241NBRII", "CGE29DM5TS5",
        "CQE28DM5NS5", "GPE12FGKBB", "GTE16DTNLWW", "GTE17GTNRBB", "GTE21GSHSS", "GTE21GTHWW",
        "GTS19KYNRFS", "GWE23GMNES", "GWE23GYNFS", "GYE22GMNES", "GYE22GYNFS", "HRF15N3AGS",
        "HRQ16N3BGS", "MBE11DSLSS", "MWS21FSKSS", "PFE28PYNFS", "PWE23KYNFS", "PYD22KBLTS",
        "ZIC363NBVLH", "ZICP360NHRH", "ZICS360NNRH", "ZICS360NVLH", "ZICS360NVRH", "ZIPS360NNSS",
        "ZISS420DHSS", "ZWE23PSNSS"
      ],
      "LAVA": [
        "GFW148SSMWW", "GFD14JSINWW", "PFQ97HSPVDS", "GFQ14ESSNWW", "GFW550SMNWW", "GFW655SPVDS",
        "GFD65ESMVDS", "GFD55ESMNWW", "PFW870SPVRS", "PFD87ESMVRS", "GFW550SPRRS", "GFT14JSIMWW",
        "GFD55ESMRRS", "PFQ83HSLWWW", "PFQ83HSHWWW", "PTW600BSRWS", "PTW705BSTWS", "GNW128PSMWW",
        "PTW800BPWRS", "PTW600BPRDG", "PTW700BPTDG", "GFD55GSSNWW", "PFQ83HSSWWW", "PTW900BPTRS",
        "GFD45GSMMDG", "GFD65ESMNSN", "GFD85ESMNRS", "GFW450SPMDG", "GFW650SPNSN", "GFW850SPNRS",
        "GNW128SSMWW", "GTW720BPNDG", "GTW750CPLDG", "GTW750CSLWS", "PCVH480EKWW", "QFD15ESMNWW",
        "QFW150SSNWW", "WCVH4800KWW"
      ],
      "GLOB": [
        "GDF511PSRSS", "GBP534SSPSS", "JVM2165SMSS", "JVM2162SMSS", "HMV1472BHS", "GPT225SGLWW",
        "GDT226SILII", "JVM2160DMWW", "GDT225SSLSS", "JE1140STC", "JVM1635SFC", "GPT225SSLSS",
        "FUF14DLRWW", "GBF180SSMSS", "GBT632SSMSS", "UBT410SSVSS", "JES1140STC", "QDT125SSLSS",
        "GDF511PGRBB", "CDT888P4VW2", "PDT145SSLSS", "GBT500SSVSS", "GBT600SSVFS", "FUF14SMRWW",
        "GBP534SGPWW", "GDF511PGRWW", "GDF510PSRSS", "PBT700SSVFS", "FCM7STWW", "FUF17DLRWW",
        "GBT500SGVWW", "FUF21DLRWW", "JVM1635SLJC", "GBF655SMPES", "FUF21SMRWW", "FCM16SLWW",
        "FCM5STWW", "GCE06GSHSB", "FUF17SMRWW", "JVM2185SMSS", "GDT225SGLWW", "PVM2188SJC",
        "PDP715SYVFS", "GDT635HSRSS", "GDE03GLKLB", "GDT670SMVES", "GDF510PGRWW", "GBF655SSPSS",
        "GDT670SYVFS", "GDT650SYVFS", "GDT226SSLSS", "PDP755SYVFS", "UBT410SGVBB", "JES1145WTC",
        "HEBF100BXS", "GDT650SMVES", "JVM2160DMBB", "CVM517P4RW2", "GBF180SGMWW", "FCM22DLWW",
        "GBF655SGPWW", "MBT425SGVWW", "MUF06DMRWW", "JEB2167RMSS", "CDT888P2VS1", "CDT858P2VS1",
        "GVS04BQNSS", "PVM2188SLJC", "GBF410SGPBB", "HC45SG42SB", "PDT145SGLWW", "GWS04HAESS",
        "GCE06GGHWW", "PVM1899SJC", "QVM7167RNCSS", "CVM517P2RS1", "UBT410SGVWW", "PXR03FLMFSC",
        "PBT865SSPFS", "GBT412SIMII", "PEM10SFC", "PDT705SYWFS", "DVM2185SMSS", "PBT865SMPES",
        "CCP06BP4PW2", "GDP630PYRFS", "GDF650SYVFS", "CVM721M2NCS5", "CDT858P3VD1", "GDP630PGRWW",
        "CCP06DP4PW2", "ZDT985SINII", "CWLC12P2RS1", "PEM10SLFC", "UDT165SIVII", "CCP06BP2PS1",
        "CWLC12P4RW5", "CVM517P3RD1", "ZWL1126SRSS", "CCP06BP3PD1", "CDE06RP2NS1", "CDE06RP4NW2",
        "ZDT925SINII", "ZDT985SPNSS", "CCP06DP2PS1", "CDT888P3VD1", "ZDT925SPNSS", "CDE06RP3ND1",
        "FORGE02PACK", "GBT640SSPSS", "ZDT985SSNSS", "ZIDI240HII", "ZIF301NBRII", "CTW900P4PW2",
        "ZIF181NPNII", "PVS06BSPSS", "PWS06DSPSS", "UCC15NPRII", "ZIF301NPNII", "CCR06BM2PS5",
        "CTW900P3PD1", "PTW9000SPSS", "ZDWR240NBS", "ZIBC24PWII", "ZIBS240NSS", "ZIBI240HII",
        "ZIFI240HII", "GBF410SSPSS", "ZIWD24PWII", "CDP888M5VS5", "UNC15NPRII", "ZDBR240NBS",
        "ZDBI240HII", "ZDWI240HII", "ZIFS240NSS", "ZIF241NBRII", "CDT875P2NS1", "ZIF181NBRII",
        "CDT875M5NS5", "ZIDS240NSS", "CDT845P2NS1", "CDT845P3ND1", "CDT875P4NW2", "CEB515P4NWM",
        "CVM517P2MS1", "CVM517P3MD1", "CVM517P4MW2", "DBP655SSTSS", "DBT655SSNSS", "G8H1AASSPSS",
        "GBF410SGPWW", "GBF532SGPBB", "GBF532SGPWW", "GBF532SSPSS", "GBF630SMLES", "GBP420SSPSS",
        "GBP655SMPES", "GBP655SSPSS", "GBT640SGPWW", "GBT640SMPES", "GDF645SGNWW", "GDF670SYVFS",
        "GDT410SIFII", "GDT635HSMSS", "GDT665SMNES", "GDT665SSNSS", "HCM5SMWW", "HCM9DMWW",
        "MBF420SGPWW", "MBF422SGMWW", "PBF665SMPES", "PBF665SSPFS", "PBP665SGPWW", "PBP665SSPFS",
        "PBT660SGLWW", "PBT660SSLSS", "PBT860SMMES", "PBT860SSMSS", "PCR06BATSS", "PCR06WATSS",
        "PDP715SYNFS", "PDP755SYRFS", "PDT660SSFSS", "PDT715SMNES", "PDT715SYNFS", "PDT715SYVFS",
        "PDT755SYRFS", "PDT785SYNFS", "PEB3228RMSS", "PVM2155SHC", "QDP225SSPSS", "QDP555SYNFS",
        "ZDT925SSNSS", "ZDT975SPJSS", "ZWL1126SJSSC"
      ],
      "COCC": [
        "UVC9300SLSS", "MCP2024DXBB", "UVC9360SLSS", "UVW9301SLSS", "JKS3000SNSS", "JP3030DWBB",
        "JP3021DPBB", "BIL616TI2-B5-09", "PHP7030DTBB", "PTS7000SNSS", "JTS3000SNSS", "MER247CWBS",
        "JTS5000SVSS", "JKS5000SVSS", "JKS3000DNWW", "PHP7036DTBB", "UVC7300SLSS", "JEP5030STSS",
        "PEP7030DTBB", "CTS90DP4NW2", "CSB913P4VW2", "CHP90361TBB", "UVW9361SLSS", "CHP90362TSS",
        "PTD7000SNSS", "UVW8301SLSS", "CHP90302TSS", "JP3030SWSS", "PEP7036DTBB", "CHP90301TBB",
        "PT7800SHSS", "CTD90FP2NS1", "CTC912P2NS1", "UVC9480SLSS", "CTS90FP2NS1", "CGP95362MS1",
        "CTS90DP2NS1", "JKS5000DVBB", "JTS5000DVBB", "JEP5030DTBB", "UVC9420SLSS", "CSB923P2VS1",
        "CTS70DP2NS1", "JGP3030SLSS", "ZTS90DPSNSS", "CSB913P2VS1", "CTD90DP2NS1", "CTD90FP4NW2",
        "CEP90302TSS", "ZHP365ETVSS", "CTS90DM2NS5", "PTS9000SNSS", "CTS90DP3ND1", "JTS5000EVES",
        "ZSB9232VSS", "ZTS90DSSNSS", "CGP95302MS1", "CSB913P3VD1", "JBS86SPSS", "CSB913M2VS5",
        "CTD90DP4NW2", "ZSB9232NSS", "CEP90362TSS", "CTD90DM2NS5", "ZHU36RSTSS", "JT3800SHSS",
        "CHS90XM2NS5", "PGP9036SLSS", "ZTSX1DPSNSS", "CTS90FP3ND1", "JGP5036SLSS", "JGP5030SLSS",
        "CEP90361TBB", "ZTW900PSNSS", "CTS90FP4NW2", "JP3036DLBB", "PHS93XYPFS", "PGP9030SLSS",
        "PTS9200SNSS", "ZHU36RDTBB", "CTD90FP3ND1", "CSB913P4NW2", "ZGU36ESLSS", "ZSB9231NSS",
        "ZTSX1DSSNSS", "JGP3036SLSS", "ZSB9132VSS", "CEP90301TBB", "ZHP304ETVSS", "ZTD90DPSNSS",
        "ZSB9231VSS", "CTD90DP3ND1", "PTS700LSNSS", "PSS93YPFS", "ZGU36RSLSS", "ZTSX1FPSNSS",
        "CSB913P3ND1", "CTW900P2PS1", "JP3036SLSS", "ZGU30RSLSS", "ZHU30RDTBB", "ZHU30RSTSS",
        "ZMB9031SNSS", "PTS700RSNSS", "CSB913M2NS5", "JP3030SJSS", "ZTW900SSNSS", "ZTD90DSSNSS",
        "ZSB9131VSS", "ZTDX1DPSNSS", "ZMB9032SNSS", "ZTDX1FPSNSS", "CSB913P2NS1", "ZEP30FRSS",
        "ZTDX1DSSNSS", "CSB923P2NS1", "ZVW8301SWSS", "JGP3030DLBB", "ZSB9132NSS", "ZV48SSJSS",
        "ZV800SJSS", "ZVC48DTB1", "CHP95362MSS", "CHS900M2NS5", "CSB923M2NS5", "CSB923P3ND1",
        "CTS70DM2NS5", "CTS90DP3MD1", "HCW225LAES", "HCW225RAES", "HCW2360AES", "JCGB660DPWW",
        "JCT5000SFSS", "JGP5030DLBB", "JKS5000DNBB", "JKS5000SNSS", "JP3030DJBB", "JP5030SJSS",
        "JTS3000DNWW", "JTS3000ENES", "JTS5000DNBB", "JTS5000ENES", "JTS5000SNSS", "PB935YPFS",
        "PCS940DMWW", "PP9030DJBB", "ZGP304NRSS", "ZHU30RDPBB", "ZHU36RSPSS", "ZSB9131NSS",
        "ZV36SSJSS", "ZV830SMSS", "ZV925SLSS", "ZV950SDSS", "ZVC53DWB1"
      ],
      "CALE": [],
      "AIAC": [
        "QPFA08YBMW", "APWA14YBMW", "APCA10YBMW", "APCA14YBMW", "AWAS05BWFC", "AWCS06BWFC",
        "HPP10XCT", "HPP10XCT-G"
      ]
    }
  }
}
# Out:
# StatementMeta(, 721e92d9-cd61-4a65-acfb-88f0c1102745, 6, Finished, Available, Finished)

# %%
df_entregas = spark.sql("SELECT * FROM LH_INTELLIGENT_VISIBILITY_CARATULAS.continental_entregas")
df_compras = spark.sql("SELECT * FROM LH_INTELLIGENT_VISIBILITY_CARATULAS.continental_compras")
# Out:
# StatementMeta(, 39d21195-a990-4930-8dfa-0a4cf2989f2b, 8, Finished, Available, Finished)

# %%
# Variables faltantes
ano_actual = 2026
paises_permitidos = ["CR","GT","HN","SV","PE","CO","EC","CL","AR","CA","MX"]

# Extraer SKUs del diccionario
skus_validos = []
for region in dict_skus.values():
    for pais in region.values():
        for familia in pais.values():
            skus_validos.extend(familia)

# Tabla de meses
df_meses = spark.createDataFrame([
    (1, "ENE"), (2, "FEB"), (3, "MAR"), (4, "ABR"),
    (5, "MAY"), (6, "JUN"), (7, "JUL"), (8, "AGO"),
    (9, "SEP"), (10, "OCT"), (11, "NOV"), (12, "DIC")
], ["mes_numero", "Attribute"])
# Out:
# StatementMeta(, 39d21195-a990-4930-8dfa-0a4cf2989f2b, 9, Finished, Available, Finished)

# %%
from pyspark.sql.functions import col, year, month, sum as spark_sum, current_timestamp

# 1. Filtrar entregas
df_entregas_prep = df_entregas.filter(
    (col("Material").isin(skus_validos)) &
    (year(col("Fecha_entrega_confirmada")) >= ano_actual) &
    (col("Pais").isin(paises_requeridos))
).select(
    col("Pais"),
    col("Grupo_Articulos").alias("Familia"),
    year(col("Fecha_entrega_confirmada")).alias("Ano"),
    month(col("Fecha_entrega_confirmada")).alias("mes_numero"),
    col("Cantidad_Entregada_Efectivamente").alias("Entregas_total")
)

df_entregas_agg = df_entregas_prep.groupBy(
    "Pais", "Familia", "Ano", "mes_numero"
).agg(
    spark_sum("Entregas_total").alias("Entregas_total")
)

# 2. Filtrar compras
df_compras_prep = df_compras.filter(
    (col("Material").isin(skus_validos)) &
    (year(col("Fecha_Final")) >= ano_actual) &
    (col("Pais").isin(paises_requeridos))
).select(
    col("Pais"),
    col("Grupo_articulos").alias("Familia"),
    year(col("Fecha_Final")).alias("Ano"),
    month(col("Fecha_Final")).alias("mes_numero"),
    col("Qty_sin_EE").alias("Compras_total")
)

df_compras_agg = df_compras_prep.groupBy(
    "Pais", "Familia", "Ano", "mes_numero"
).agg(
    spark_sum("Compras_total").alias("Compras_total")
)

# 3. Unir entregas y compras
df_llegadas_desglosadas = df_entregas_agg.join(
    df_compras_agg,
    on=["Pais", "Familia", "Ano", "mes_numero"],
    how="outer"
).fillna(0)

# 4. Agregar columna de timestamp
df_llegadas_desglosadas = df_llegadas_desglosadas.withColumn("ultima_actualizacion", current_timestamp())

# 5. Agregar columna fiscal (Attribute) desde df_meses
df_llegadas_desglosadas = df_llegadas_desglosadas.join(
    df_meses.select("mes_numero", "Attribute"),
    on="mes_numero",
    how="left"
)

# 6. Guardar en Lakehouse
df_llegadas_desglosadas.write.mode("overwrite").option("overwriteSchema", "true").saveAsTable("continental_llegadas_desglosadas")

print("✅ Tabla 'continental_llegadas_desglosadas' guardada exitosamente en el Lakehouse con columna fiscal 'Attribute'.")
# Out:
# StatementMeta(, 39d21195-a990-4930-8dfa-0a4cf2989f2b, 10, Finished, Available, Finished)
# ✅ Tabla 'continental_llegadas_desglosadas' guardada exitosamente en el Lakehouse con columna fiscal 'Attribute'.

# %%
df = spark.sql("SELECT * FROM LH_INTELLIGENT_VISIBILITY_CARATULAS.continental_llegadas_desglosadas LIMIT 1000")
display(df)
# Out:
# StatementMeta(, 39d21195-a990-4930-8dfa-0a4cf2989f2b, 11, Finished, Available, Finished)
# SynapseWidget(Synapse.DataFrame, 80e2addc-3b0f-4b84-8d82-2efc7939853d)

# %%
# ================================================================
# INVESTIGACIÓN: ¿Por qué NO HAY datos de SV en facturación?
# ================================================================

from pyspark.sql.functions import col, count, countDistinct

# Cargar tabla de facturación
spark_df_facturacion_gov = spark.sql(
    "SELECT * FROM LH_INTELLIGENT_VISIBILITY_CARATULAS.CONTINENTAL_FACTURIACION_CDV_1"
).withColumnRenamed("País Sociedad", "País")

print("\n" + "="*70)
print("INVESTIGACIÓN 1: ¿Qué columnas tiene la tabla?")
print("="*70)
print("Columnas disponibles:")
for col_name in spark_df_facturacion_gov.columns:
    print(f"  - {col_name}")

print("\n" + "="*70)
print("INVESTIGACIÓN 2: ¿Qué países EXISTEN en la tabla?")
print("="*70)
print("Países únicos encontrados (con conteo de registros):")
spark_df_facturacion_gov.groupBy("País").agg(
    count("*").alias("Total_Registros")
).orderBy(col("Total_Registros").desc()).show(50, truncate=False)

print("\n" + "="*70)
print("INVESTIGACIÓN 3: ¿SV aparece con otro nombre?")
print("="*70)
print("Buscando variantes de SV (SLV, El Salvador, SALVADOR, etc.):")
paises_all = spark_df_facturacion_gov.select("País").distinct().collect()
paises_list = [row["País"] for row in paises_all]

sv_variantes = [p for p in paises_list if p and (
    "SV" in str(p).upper() or 
    "SALV" in str(p).upper() or 
    "EL SALV" in str(p).upper()
)]

if sv_variantes:
    print("✅ Se encontraron estas variantes:")
    for variante in sv_variantes:
        count_var = spark_df_facturacion_gov.filter(col("País") == variante).count()
        print(f"   - '{variante}' ({count_var} registros)")
else:
    print("❌ NO se encontró ninguna variante de SV")

print("\n" + "="*70)
print("INVESTIGACIÓN 4: ¿Existe otra columna de país?")
print("="*70)
# Buscar columnas que contengan "país", "pais", "country", "sociedad"
columnas_pais = [c for c in spark_df_facturacion_gov.columns if 
                 any(x in c.lower() for x in ["país", "pais", "country", "soc"])]
print("Columnas relacionadas con país/sociedad:")
for c in columnas_pais:
    print(f"  - {c}")
    # Mostrar valores únicos de cada columna similar
    valores_unicos = spark_df_facturacion_gov.select(c).distinct().count()
    print(f"    (Valores únicos: {valores_unicos})")

print("\n" + "="*70)
print("INVESTIGACIÓN 5: Comparar con otras fuentes de datos")
print("="*70)
print("Verificando si SV existe en OTRAS tablas...")

# Verificar en entregas
try:
    df_entregas = spark.sql("SELECT * FROM LH_INTELLIGENT_VISIBILITY_CARATULAS.continental_entregas")
    sv_entregas = df_entregas.filter(col("Pais") == "SV").count()
    print(f"✅ Entregas: {sv_entregas} registros de SV")
except Exception as e:
    print(f"❌ Error al verificar entregas: {e}")

# Verificar en compras
try:
    df_compras = spark.sql("SELECT * FROM LH_INTELLIGENT_VISIBILITY_CARATULAS.continental_compras")
    sv_compras = df_compras.filter(col("Pais") == "SV").count()
    print(f"✅ Compras: {sv_compras} registros de SV")
except Exception as e:
    print(f"❌ Error al verificar compras: {e}")

print("\n" + "="*70)
print("INVESTIGACIÓN 6: Revisar la tabla ORIGINAL (sin renombrar)")
print("="*70)
spark_df_original = spark.sql(
    "SELECT * FROM LH_INTELLIGENT_VISIBILITY_CARATULAS.CONTINENTAL_FACTURIACION_CDV_1"
)
print("\nColumnas de la tabla ORIGINAL:")
for col_name in spark_df_original.columns:
    print(f"  - {col_name}")

print("\nBuscando SV en columna 'País Sociedad' (original):")
if "País Sociedad" in spark_df_original.columns:
    sv_original = spark_df_original.filter(col("País Sociedad") == "SV").count()
    print(f"Registros encontrados: {sv_original}")
    
    if sv_original == 0:
        print("\n¿Qué valores HAY en 'País Sociedad'?")
        spark_df_original.groupBy("País Sociedad").agg(
            count("*").alias("Total")
        ).orderBy(col("Total").desc()).show(20, truncate=False)
else:
    print("❌ La columna 'País Sociedad' no existe en la tabla original")

print("\n" + "="*70)
print("INVESTIGACIÓN 7: ¿Cuántos registros tienen período >= 2025001?")
print("="*70)
df_2025 = spark_df_facturacion_gov.filter(col("Ejercicio/Período") >= 2025001)
total_2025 = df_2025.count()
print(f"Total de registros con período >= 2025001: {total_2025}")

if total_2025 > 0:
    print("\n¿Qué países SÍ tienen datos en 2025?")
    df_2025.groupBy("País").agg(
        count("*").alias("Registros_2025")
    ).orderBy(col("Registros_2025").desc()).show(50, truncate=False)
else:
    print("❌ NO HAY DATOS de ningún país con período >= 2025001")
    print("\n¿Cuál es el período máximo en la tabla?")
    spark_df_facturacion_gov.select(
        max("Ejercicio/Período").alias("Max_Periodo")
    ).show()

print("\n" + "="*70)
print("🎯 CONCLUSIONES Y RECOMENDACIONES")
print("="*70)
print("Posibles soluciones:")
print("1. SV no está cargado en la tabla de facturación")
print("2. SV tiene otro código de país (verifica tabla de referencia)")
print("3. Los datos de SV están en otra tabla o fuente")
print("4. Hay que revisar el proceso ETL que carga facturación")
print("="*70)
# Out:
# StatementMeta(, 39d21195-a990-4930-8dfa-0a4cf2989f2b, 12, Finished, Available, Finished)
# ...
# INVESTIGACIÓN 1: ¿Qué columnas tiene la tabla?
# ...
# Columnas disponibles:
#   - Volumen Ventas
#   - Año natural/Semana
#   - Año natural
#   - País
#   - Ejercicio/Período
#   - Material
#   - Grupo Artículos
#   - Planificador Necesidades
#   - Planificador Necesidades Descripción
#   - Almacén
#
# ...
# INVESTIGACIÓN 2: ¿Qué países EXISTEN en la tabla?
# ...
# Países únicos encontrados (con conteo de registros):
# +----+---------------+
# |País|Total_Registros|
# +----+---------------+
# |MX  |68767          |
# |CA  |61194          |
# |CO  |23379          |
# |PE  |13486          |
# |EC  |13385          |
# |AR  |11917          |
# |CL  |7459           |
# |CR  |6803           |
# |GT  |6647           |
# |SV  |5062           |
# |HN  |3831           |
# +----+---------------+
#
#
# ...
# INVESTIGACIÓN 3: ¿SV aparece con otro nombre?
# ...
# Buscando variantes de SV (SLV, El Salvador, SALVADOR, etc.):
# ...
